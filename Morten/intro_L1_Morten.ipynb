# %% [markdown]
# # SWMAL Exercise
#
# ## Intro
#
#
# We startup by reusing parts of `01_the_machine_learning_landscape.ipynb` from Géron [GITHOML]. So we begin with what Géron says about life satisfactions vs GDP per capita.
#
# Halfway down this notebook, a list of questions for SWMAL is presented.

# %% [markdown]
# ## Chapter 1 – The Machine Learning landscape
#
# _This is the code used to generate some of the figures in chapter 1._

# %% [markdown]
# ### Setup
#
# First, let's make sure this notebook works well in both python 2 and 3, import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures:

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("IGNORING: Saving figure", fig_id) # SWMAL: I've disabled saving of figures
    #if tight_layout:
    #    plt.tight_layout()
    #plt.savefig(path, format='png', dpi=300)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %% [markdown]
# ### Code example 1-1
#
# This function just merges the OECD's life satisfaction data and the IMF's GDP per capita data. It's a bit too long and boring and it's not specific to Machine Learning, which is why I left it out of the book.

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

print("OK")
# Out:
# OK

# %% [markdown]
# The code in the book expects the data files to be located in the current directory. I just tweaked it here to fetch the files in datasets/lifesat.

# %%
import os
datapath = os.path.join("../DataSets/lifesat/")

# NOTE: a ! prefix makes us able to run system commands..
# (command 'dir' for windows, 'ls' for Linux or Macs)
#

! dir
print("\nOK")
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is B0F0-9C0A
#
#  Directory of c:\Users\mkeri\Desktop\MLFolderRepo\MLKursus\Morten
#
# 13-02-2024  13:54    <DIR>          .
# 13-02-2024  13:54    <DIR>          ..
# 30-01-2024  12:28    <DIR>          .idea
# 12-02-2024  18:12            38.603 cost_function_01_Morten.ipynb
# 30-01-2024  13:09    <DIR>          datasets
# 12-02-2024  18:14             9.060 dummy_classifier_O1_Morten.ipynb
# 30-01-2024  13:56               916 FirstFile.ipynb
# 12-02-2024  18:12           306.796 intro_L1_Morten.ipynb
# 13-02-2024  13:54            14.670 k-fold_demo_Morten.ipynb
# 13-02-2024  13:11            13.078 modules_and_classes.ipynb
# 13-02-2024  13:54                 0 O1_Morten.ipynb
# 26-11-2023  15:59             8.312 PytorchCourse.ipynb
# 26-11-2023  15:59            35.824 PyTorchWorkflow.ipynb
# 30-01-2024  12:28                10 README.txt
# 13-02-2024  13:01             4.317 supergruppe_diskussion_Morten.ipynb
# 30-01-2024  12:28                 0 temp.py
#               12 File(s)        431.586 bytes
#                4 Dir(s)  282.470.285.312 bytes free
#
# OK

# %%
# Code example
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
try:
    oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
    gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
except Exception as e:
    print(f"SWMAL NOTE: well, you need to have the 'datasets' dir in path, please unzip 'datasets.zip' and make sure that its included in the datapath='{datapath}' setting in the cell above..")
    raise e
    
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
y_pred = model.predict(X_new)
print(y_pred) # outputs [[ 5.96242338]]

print("OK")
# Out:
# [[5.96242338]]
# OK

# %% [markdown]
# ## SWMAL
#
# Now we plot the linear regression result.
#
# Just ignore all the data plotter code mumbo-jumbo here (code take dirclty from the notebook, [GITHOML])...and see the final plot.

# %%
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
#oecd_bli.head(2)

gdp_per_capita = pd.read_csv(datapath+"gdp_per_capita.csv", thousands=',', delimiter='\t',
                             encoding='latin1', na_values="n/a")
gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_per_capita.set_index("Country", inplace=True)
#gdp_per_capita.head(2)

full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita, left_index=True, right_index=True)
full_country_stats.sort_values(by="GDP per capita", inplace=True)
#full_country_stats

remove_indices = [0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36)) - set(remove_indices))

sample_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]
#missing_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[remove_indices]

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
position_text = {
    "Hungary": (5000, 1),
    "Korea": (18000, 1.7),
    "France": (29000, 2.4),
    "Australia": (40000, 3.0),
    "United States": (52000, 3.8),
}
for country, pos_text in position_text.items():
    pos_data_x, pos_data_y = sample_data.loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(country, xy=(pos_data_x, pos_data_y), xytext=pos_text,
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")
#save_fig('money_happy_scatterplot')
plt.show()

from sklearn import linear_model
lin1 = linear_model.LinearRegression()
Xsample = np.c_[sample_data["GDP per capita"]]
ysample = np.c_[sample_data["Life satisfaction"]]
lin1.fit(Xsample, ysample)

t0 = 4.8530528
t1 = 4.91154459e-05

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
M=np.linspace(0, 60000, 1000)
plt.plot(M, t0 + t1*M, "b")
plt.text(5000, 3.1, r"$\theta_0 = 4.85$", fontsize=14, color="b")
plt.text(5000, 2.2, r"$\theta_1 = 4.91 \times 10^{-5}$", fontsize=14, color="b")
#save_fig('best_fit_model_plot')
plt.show()

print("OK")
# Out:
# OK

# %% [markdown]
# ## Ultra-brief Intro to the Fit-Predict Interface in Scikit-learn
#
# OK, the important lines in the cells above are really just
# ```python
# #Select a linear model
# model = sklearn.linear_model.LinearRegression()
#
# # Train the model
# model.fit(X, y)
#
# # Make a prediction for Cyprus
# X_new = [[22587]]  # Cyprus' GDP per capita
# y_pred = model.predict(X_new)
# print(y_pred) # outputs [[ 5.96242338]]
#
# ```
#
# What happens here is that we create  model, called LinearRegression (for now just a 100% black-box method), put in our data training $\mathbf{X}$ matrix and corresponding desired training ground thruth vector $\mathbf{y}$ (aka $\mathbf{y}_{true})$, and then train the model.
#
# After training we extract a _predicted_ $\mathbf{y}_{pred}$ vector from the model, for some input scalar $x$=22587.
#
#
# ### Supervised Training via Fit-predict
#
# The train-predict (or train-fit) process on some data can be visualized as
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/supervised_learning.png" alt="WARNING: could not get image from server." style="height:250px">
#
# In this figure the untrained model is a `sklearn.linear_model.LinearRegression` python object. When trained via  `model.fit()`, using some know answers for the data, $\mathbf{y}_{true}~$, it becomes a blue-boxed trained model.
#
# The trained model can be used to _predict_ values from new, yet-unseen, data, via the `model.predict()` function.
#
# In other words, how high is life-satisfaction for Cyprus' GDP=22587 USD?
#
# Just call `model.predict()` on a matrix with one single numerical element, 22587, well, not a matrix really, but a python list-of-lists, `[[22587]]`
#
# ```y_pred = model.predict([[22587]])```
#
# Apparently 5.96 the models answers!
#
# (you get used to the python built-in containers and numpy on the way..)

# %% [markdown]
# ### Qa) The $\theta$ parameters and the $R^2$ Score
#
# Géron uses some $\theta$ parameter from this linear regression model, in his examples and plots above.
#
# How do you extract the $\theta_0$ and $\theta_1$ coefficients in his life-satisfaction figure form the linear regression model, via the models python attributes?
#
# Read the documentation for the linear regressor at
#
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# Extract the score=0.734 for the model using data (X,y) and explain what $R^2$ score measures in broad terms
#
# $$
# \begin{array}{rcll}
#     R^2 &=& 1 - u/v\\
#     u   &=& \sum (y_{true} - y_{pred}~)^2   ~~~&\small \textrm{residual sum of squares}\\
#     v   &=& \sum (y_{true} - \mu_{true}~)^2 ~~~&\small \textrm{total sum of squares}
# \end{array}
# $$
#
# with $y_{true}~$ being the true data, $y_{pred}~$ being the predicted data from the model and $\mu_{true}~$ being the true mean of the data.
#
# What are the minimum and maximum values for $R^2~$?
#
# Is it best to have a low $R^2$ score or a high $R^2$ score? This means, is $R^2$ a loss/cost function or a function that measures of fitness/goodness?
#
# NOTE$_1$: the $R^2$ is just one of many scoring functions used in ML, we will see plenty more other methods later.
#
# NOTE$_2$: there are different definitions of the $R^2$, 'coefficient of determination', in linear algebra. We stricly use the formulation above.
#
# OPTIONAL: Read the additional in-depth literature on $R^2~$:
#
# > https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# TODO: add your code here..

model.score(X,y), model.coef_, model.intercept_ 
# The R^2 value describes how well the data is fitted, 1 being best
# The higher the better R^2, measuring goodness of fit
# Coeffient parameter is the slope, and intercept is, well, the intercept with the y-axis

# assert False, "TODO: solve Qa, and remove me.."
# Out:
# (0.7344414355437031, array([[4.91154459e-05]]), array([4.8530528]))

# %% [markdown]
# ## The Merits of the Fit-Predict Interface
#
# Now comes the really fun part: all methods in Scikit-learn have this fit-predict interface, and you can easily interchange models in your code just by instantiating a new and perhaps better ML model.
#
# There are still a lot of per-model parameters to tune, but fortunately, the built-in default values provide you with a good initial guess for good model setup.
#
# Later on, you might want to go into the parameter detail trying to optimize some params (opening the lid of the black-box ML algo), but for now, we pretty much stick to the default values.
#
# Let's try to replace the linear regression now, let's test a _k-nearest neighbour algorithm_ instead (still black boxed algorithm-wise)...
#
#
# ### Qb) Using k-Nearest Neighbors
#
# Change the linear regression model to a `sklearn.neighbors.KNeighborsRegressor` with k=3 (as in [HOML:p.26]), and rerun the `fit` and `predict` using this new model.
#
# What do the k-nearest neighbors (KNN) estimate for Cyprus, compared to the linear regression (it should yield=5.77)?
#
# What _score-method_ does the KNN model use, and is it comparable to the linear regression model?
#
# Seek out the documentation in Scikit-learn, if the scoring methods are not equal, can they be compared to each other at all then?
#
# Remember to put pointer/text from the Sckikit-learn documentation in the journal...(did you find the right KNN model etc.)

# %%
# this is our raw data set:
sample_data
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# and this is our preprocessed data
country_stats
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# Prepare the data

X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

print("X.shape=",X.shape)
print("y.shape=",y.shape)

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select and train a model

# TODO: add your code here..
import sklearn.neighbors

#assert False, "TODO: add you instatiation and training of the knn model here.."
k_model = sklearn.neighbors.KNeighborsRegressor(3)

k_model.fit(X,y)

pred = [[22587]]
k_y_pred = k_model.predict(pred)

print(f"\nKnn value = {k_y_pred}")
k_model.score(X,y)
# K model: R^2
# Linear model: R^2
# Can be compared
# Out:
# X.shape= (29, 1)
# y.shape= (29, 1)
# Knn value = [[5.76666667]]
# 0.8525732853499179

# %% [markdown]
# ### Qc) Tuning Parameter for k-Nearest Neighbors and A Sanity Check
#
# But that not the full story. Try plotting the prediction for both models in the same graph and tune the `k_neighbor` parameter of the `KNeighborsRegressor` model.
#
# Choosing `k_neighbor=1` produces a nice `score=1`, that seems optimal...but is it really so good?
#
# Plotting the two models in a 'Life Satisfaction-vs-GDP capita' 2D plot by creating an array in the range 0 to 60000 (USD) (the `M` matrix below) and then predict the corresponding y value will sheed some light to this.
#
# Now reusing the plots stubs below, try to explain why the k-nearest neighbour with `k_neighbor=1` has such a good score.
#
# Does a score=1 with `k_neighbor=1`also mean that this would be the prefered estimator for the job?
#
# Hint here is a similar plot of a KNN for a small set of different k's:
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/regression_with_knn.png"  alt="WARNING: could not get image from server." style="height:150px">

# %%
sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])

# create an test matrix M, with the same dimensionality as X, and in the range [0;60000] 
# and a step size of your choice
m=np.linspace(0, 60000, 1000)
M=np.empty([m.shape[0],1])
M[:,0]=m

# from this test M data, predict the y values via the lin.reg. and k-nearest models
y_pred_lin = model.predict(M)
y_pred_knn = k_model.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 

# use plt.plot to plot x-y into the sample_data plot..
#plt.plot(m, y_pred_lin, "r")
#plt.plot(m, y_pred_knn, "b")

# TODO: add your code here..
# assert False, "TODO: try knn with different k_neighbor params, that is re-instantiate knn, refit and replot.."
k_model = sklearn.neighbors.KNeighborsRegressor(15)

k_model.fit(X,y)

pred = [[22587]]
k_y_pred = k_model.predict(pred)


# from this test M data, predict the y values via the lin.reg. and k-nearest models
y_pred_lin = model.predict(M)
y_pred_knn2 = k_model.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 

# use plt.plot to plot x-y into the sample_data plot..
plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")

k_model.score(X,y)
# Out:
# 0.7148759457896103

# %% [markdown]
# ### Qd) Trying out a Neural Network
#
# Let us then try a Neural Network on the data, using the fit-predict interface allows us to replug a new model into our existing code.
#
# There are a number of different NN's available, let's just hook into Scikit-learns Multi-Layer Perceptron for regression, that is an 'MLPRegressor'.
#
# Now, the data-set for training the MLP is really not well scaled, so we need to tweak a lot of parameters in the MLP just to get it to produce some sensible output: with out preprocessing and scaling of the input data, `X`, the MLP is really a bad choice of model for the job since it so easily produces garbage output.
#
# Try training the `mlp` regression model below, predict the value for Cyprus, and find the `score` value for the training set...just as we did for the linear and KNN models.
#
# Can the `MLPRegressor` score function be compared with the linear and KNN-scores?

# %%
from sklearn.neural_network import MLPRegressor

# Setup MLPRegressor
mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(X, y.ravel())

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(M) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")

# TODO: add your code here..
#assert False, "TODO: predict value for Cyprus and fetch the score() from the fitting."
pred = [[22875]]
y_pred = mlp.predict(pred)

y_pred, mlp.score(X, y)
# Out:
# Iteration 1, loss = 290434295.23044360
# Iteration 2, loss = 286926974.91845930
# Iteration 3, loss = 283445091.80120468
# Iteration 4, loss = 279989007.88284469
# Iteration 5, loss = 276559070.05886549
# Iteration 6, loss = 273155609.32856679
# Iteration 7, loss = 269778940.07033998
# Iteration 8, loss = 266429359.38609853
# Iteration 9, loss = 263107146.52031821
# Iteration 10, loss = 259812562.35816029
# Iteration 11, loss = 256545849.00610602
# Iteration 12, loss = 253307229.45747611
# Iteration 13, loss = 250096907.34413815
# Iteration 14, loss = 246915066.77466324
# Iteration 15, loss = 243761872.25819016
# Iteration 16, loss = 240637468.71230754
# Iteration 17, loss = 237541981.55239332
# Iteration 18, loss = 234475516.85906243
# Iteration 19, loss = 231438161.61967906
# Iteration 20, loss = 228429984.03930050
# Iteration 21, loss = 225451033.91592681
# Iteration 22, loss = 222501343.07455081
# Iteration 23, loss = 219580925.85422322
# Iteration 24, loss = 216689779.64216983
# Iteration 25, loss = 213827885.44891000
# Iteration 26, loss = 210995208.51833686
# Iteration 27, loss = 208191698.96679541
# Iteration 28, loss = 205417292.44535619
# Iteration 29, loss = 202671910.81969425
# Iteration 30, loss = 199955462.86225185
# Iteration 31, loss = 197267844.95167446
# Iteration 32, loss = 194608941.77484995
# Iteration 33, loss = 191978627.02724859
# Iteration 34, loss = 189376764.10764292
# Iteration 35, loss = 186803206.80367702
# Iteration 36, loss = 184257799.96514288
# Iteration 37, loss = 181740380.16221160
# Iteration 38, loss = 179250776.32624131
# Iteration 39, loss = 176788810.37114519
# Iteration 40, loss = 174354297.79365045
# Iteration 41, loss = 171947048.25110015
# Iteration 42, loss = 169566866.11575758
# Iteration 43, loss = 167213551.00484595
# Iteration 44, loss = 164886898.28581721
# Iteration 45, loss = 162586699.55657041
# Iteration 46, loss = 160312743.10055020
# Iteration 47, loss = 158064814.31683558
# Iteration 48, loss = 155842696.12549382
# Iteration 49, loss = 153646169.34860966
# Iteration 50, loss = 151475013.06751981
# Iteration 51, loss = 149329004.95688277
# Iteration 52, loss = 147207921.59629363
# Iteration 53, loss = 145111538.76022065
# Iteration 54, loss = 143039631.68709087
# Iteration 55, loss = 140991975.32838824
# Iteration 56, loss = 138968344.57865524
# Iteration 57, loss = 136968514.48730263
# Iteration 58, loss = 134992260.45313826
# Iteration 59, loss = 133039358.40252548
# Iteration 60, loss = 131109584.95206928
# Iteration 61, loss = 129202717.55671819
# Iteration 62, loss = 127318534.64414711
# Iteration 63, loss = 125456815.73626374
# Iteration 64, loss = 123617341.55865660
# Iteration 65, loss = 121799894.13876976
# Iteration 66, loss = 120004256.89356244
# Iteration 67, loss = 118230214.70737669
# Iteration 68, loss = 116477554.00070480
# Iteration 69, loss = 114746062.79051290
# Iteration 70, loss = 113035530.74274606
# Iteration 71, loss = 111345749.21760385
# Iteration 72, loss = 109676511.30814496
# Iteration 73, loss = 108027611.87274542
# Iteration 74, loss = 106398847.56190486
# Iteration 75, loss = 104790016.83986317
# Iteration 76, loss = 103200920.00146291
# Iteration 77, loss = 101631359.18466166
# Iteration 78, loss = 100081138.37907493
# Iteration 79, loss = 98550063.43090008
# Iteration 80, loss = 97037942.04455309
# Iteration 81, loss = 95544583.78132014
# Iteration 82, loss = 94069800.05530959
# Iteration 83, loss = 92613404.12696616
# Iteration 84, loss = 91175211.09439014
# Iteration 85, loss = 89755037.88268732
# Iteration 86, loss = 88352703.23155566
# Iteration 87, loss = 86968027.68130204
# Iteration 88, loss = 85600833.55746408
# Iteration 89, loss = 84250944.95419993
# Iteration 90, loss = 82918187.71659584
# Iteration 91, loss = 81602389.42202777
# Iteration 92, loss = 80303379.36070359
# Iteration 93, loss = 79020988.51550117
# Iteration 94, loss = 77755049.54120794
# Iteration 95, loss = 76505396.74325842
# Iteration 96, loss = 75271866.05605870
# Iteration 97, loss = 74054295.02097797
# Iteration 98, loss = 72852522.76408070
# Iteration 99, loss = 71666389.97366714
# Iteration 100, loss = 70495738.87768234
# Iteration 101, loss = 69340413.22104985
# Iteration 102, loss = 68200258.24297996
# Iteration 103, loss = 67075120.65429863
# Iteration 104, loss = 65964848.61483803
# Iteration 105, loss = 64869291.71092643
# Iteration 106, loss = 63788300.93301106
# Iteration 107, loss = 62721728.65344451
# Iteration 108, loss = 61669428.60446204
# Iteration 109, loss = 60631255.85637417
# Iteration 110, loss = 59607066.79599745
# Iteration 111, loss = 58596719.10534196
# Iteration 112, loss = 57600071.74057401
# Iteration 113, loss = 56616984.91126954
# Iteration 114, loss = 55647320.05997168
# Iteration 115, loss = 54690939.84206531
# Iteration 116, loss = 53747708.10597887
# Iteration 117, loss = 52817489.87372303
# Iteration 118, loss = 51900151.32177443
# Iteration 119, loss = 50995559.76231126
# Iteration 120, loss = 50103583.62480697
# Iteration 121, loss = 49224092.43798707
# Iteration 122, loss = 48356956.81215288
# Iteration 123, loss = 47502048.42187629
# Iteration 124, loss = 46659239.98906756
# Iteration 125, loss = 45828405.26641855
# Iteration 126, loss = 45009419.02122276
# Iteration 127, loss = 44202157.01957307
# Iteration 128, loss = 43406496.01093756
# Iteration 129, loss = 42622313.71311320
# Iteration 130, loss = 41849488.79755717
# Iteration 131, loss = 41087900.87509485
# Iteration 132, loss = 40337430.48200314
# Iteration 133, loss = 39597959.06646779
# Iteration 134, loss = 38869368.97541259
# Iteration 135, loss = 38151543.44169848
# Iteration 136, loss = 37444366.57169053
# Iteration 137, loss = 36747723.33318929
# Iteration 138, loss = 36061499.54372469
# Iteration 139, loss = 35385581.85920878
# Iteration 140, loss = 34719857.76294434
# Iteration 141, loss = 34064215.55498595
# Iteration 142, loss = 33418544.34184999
# Iteration 143, loss = 32782734.02656958
# Iteration 144, loss = 32156675.29909116
# Iteration 145, loss = 31540259.62700796
# Iteration 146, loss = 30933379.24662697
# Iteration 147, loss = 30335927.15436451
# Iteration 148, loss = 29747797.09846660
# Iteration 149, loss = 29168883.57104910
# Iteration 150, loss = 28599081.80045349
# Iteration 151, loss = 28038287.74391323
# Iteration 152, loss = 27486398.08052623
# Iteration 153, loss = 26943310.20452822
# Iteration 154, loss = 26408922.21886230
# Iteration 155, loss = 25883132.92903953
# Iteration 156, loss = 25365841.83728523
# Iteration 157, loss = 24856949.13696606
# Iteration 158, loss = 24356355.70729241
# Iteration 159, loss = 23863963.10829058
# Iteration 160, loss = 23379673.57603967
# Iteration 161, loss = 22903390.01816720
# Iteration 162, loss = 22435016.00959824
# Iteration 163, loss = 21974455.78855223
# Iteration 164, loss = 21521614.25278156
# Iteration 165, loss = 21076396.95604661
# Iteration 166, loss = 20638710.10482106
# Iteration 167, loss = 20208460.55522152
# Iteration 168, loss = 19785555.81015583
# Iteration 169, loss = 19369904.01668377
# Iteration 170, loss = 18961413.96358429
# Iteration 171, loss = 18559995.07912303
# Iteration 172, loss = 18165557.42901421
# Iteration 173, loss = 17778011.71457046
# Iteration 174, loss = 17397269.27103463
# Iteration 175, loss = 17023242.06608719
# Iteration 176, loss = 16655842.69852301
# Iteration 177, loss = 16294984.39709119
# Iteration 178, loss = 15940581.01949180
# Iteration 179, loss = 15592547.05152283
# Iteration 180, loss = 15250797.60637148
# Iteration 181, loss = 14915248.42404303
# Iteration 182, loss = 14585815.87092119
# Iteration 183, loss = 14262416.93945337
# Iteration 184, loss = 13944969.24795465
# Iteration 185, loss = 13633391.04052399
# Iteration 186, loss = 13327601.18706645
# Iteration 187, loss = 13027519.18341484
# Iteration 188, loss = 12733065.15154476
# Iteration 189, loss = 12444159.83987650
# Iteration 190, loss = 12160724.62365762
# Iteration 191, loss = 11882681.50541995
# Iteration 192, loss = 11609953.11550478
# Iteration 193, loss = 11342462.71265005
# Iteration 194, loss = 11080134.18463337
# Iteration 195, loss = 10822892.04896490
# Iteration 196, loss = 10570661.45362386
# Iteration 197, loss = 10323368.17783287
# Iteration 198, loss = 10080938.63286410
# Iteration 199, loss = 9843299.86287133
# Iteration 200, loss = 9610379.54574223
# Iteration 201, loss = 9382105.99396509
# Iteration 202, loss = 9158408.15550429
# Iteration 203, loss = 8939215.61467916
# Iteration 204, loss = 8724458.59304044
# Iteration 205, loss = 8514067.95023934
# Iteration 206, loss = 8307975.18488352
# Iteration 207, loss = 8106112.43537511
# Iteration 208, loss = 7908412.48072557
# Iteration 209, loss = 7714808.74134230
# Iteration 210, loss = 7525235.27978237
# Iteration 211, loss = 7339626.80146846
# Iteration 212, loss = 7157918.65536230
# Iteration 213, loss = 6980046.83459133
# Iteration 214, loss = 6805947.97702397
# Iteration 215, loss = 6635559.36578939
# Iteration 216, loss = 6468818.92973753
# Iteration 217, loss = 6305665.24383542
# Iteration 218, loss = 6146037.52949602
# Iteration 219, loss = 5989875.65483572
# Iteration 220, loss = 5837120.13485700
# Iteration 221, loss = 5687712.13155279
# Iteration 222, loss = 5541593.45392930
# Iteration 223, loss = 5398706.55794408
# Iteration 224, loss = 5258994.54635637
# Iteration 225, loss = 5122401.16848696
# Iteration 226, loss = 4988870.81988471
# Iteration 227, loss = 4858348.54189740
# Iteration 228, loss = 4730780.02114440
# Iteration 229, loss = 4606111.58888890
# Iteration 230, loss = 4484290.22030786
# Iteration 231, loss = 4365263.53365746
# Iteration 232, loss = 4248979.78933253
# Iteration 233, loss = 4135387.88881833
# Iteration 234, loss = 4024437.37353312
# Iteration 235, loss = 3916078.42356042
# Iteration 236, loss = 3810261.85626962
# Iteration 237, loss = 3706939.12482427
# Iteration 238, loss = 3606062.31657690
# Iteration 239, loss = 3507584.15134995
# Iteration 240, loss = 3411457.97960219
# Iteration 241, loss = 3317637.78048037
# Iteration 242, loss = 3226078.15975571
# Iteration 243, loss = 3136734.34764542
# Iteration 244, loss = 3049562.19651905
# Iteration 245, loss = 2964518.17849018
# Iteration 246, loss = 2881559.38289353
# Iteration 247, loss = 2800643.51364831
# Iteration 248, loss = 2721728.88650806
# Iteration 249, loss = 2644774.42619820
# Iteration 250, loss = 2569739.66344175
# Iteration 251, loss = 2496584.73187455
# Iteration 252, loss = 2425270.36485105
# Iteration 253, loss = 2355757.89214180
# Iteration 254, loss = 2288009.23652427
# Iteration 255, loss = 2221986.91026821
# Iteration 256, loss = 2157654.01151748
# Iteration 257, loss = 2094974.22056970
# Iteration 258, loss = 2033911.79605584
# Iteration 259, loss = 1974431.57102147
# Iteration 260, loss = 1916498.94891168
# Iteration 261, loss = 1860079.89946193
# Iteration 262, loss = 1805140.95449668
# Iteration 263, loss = 1751649.20363845
# Iteration 264, loss = 1699572.28992923
# Iteration 265, loss = 1648878.40536701
# Iteration 266, loss = 1599536.28635959
# Iteration 267, loss = 1551515.20909837
# Iteration 268, loss = 1504784.98485476
# Iteration 269, loss = 1459315.95520161
# Iteration 270, loss = 1415078.98716261
# Iteration 271, loss = 1372045.46829229
# Iteration 272, loss = 1330187.30168933
# Iteration 273, loss = 1289476.90094614
# Iteration 274, loss = 1249887.18503743
# Iteration 275, loss = 1211391.57315076
# Iteration 276, loss = 1173963.97946186
# Iteration 277, loss = 1137578.80785774
# Iteration 278, loss = 1102210.94661042
# Iteration 279, loss = 1067835.76300441
# Iteration 280, loss = 1034429.09792062
# Iteration 281, loss = 1001967.26037998
# Iteration 282, loss = 970427.02204948
# Iteration 283, loss = 939785.61171373
# Iteration 284, loss = 910020.70971492
# Iteration 285, loss = 881110.44236420
# Iteration 286, loss = 853033.37632730
# Iteration 287, loss = 825768.51298742
# Iteration 288, loss = 799295.28278823
# Iteration 289, loss = 773593.53955979
# Iteration 290, loss = 748643.55483030
# Iteration 291, loss = 724426.01212659
# Iteration 292, loss = 700922.00126583
# Iteration 293, loss = 678113.01264161
# Iteration 294, loss = 655980.93150670
# Iteration 295, loss = 634508.03225548
# Iteration 296, loss = 613676.97270847
# Iteration 297, loss = 593470.78840164
# Iteration 298, loss = 573872.88688300
# Iteration 299, loss = 554867.04201892
# Iteration 300, loss = 536437.38831278
# Iteration 301, loss = 518568.41523807
# Iteration 302, loss = 501244.96158855
# Iteration 303, loss = 484452.20984756
# Iteration 304, loss = 468175.68057883
# Iteration 305, loss = 452401.22684076
# Iteration 306, loss = 437115.02862661
# Iteration 307, loss = 422303.58733226
# Iteration 308, loss = 407953.72025383
# Iteration 309, loss = 394052.55511696
# Iteration 310, loss = 380587.52463956
# Iteration 311, loss = 367546.36112998
# Iteration 312, loss = 354917.09112219
# Iteration 313, loss = 342688.03004979
# Iteration 314, loss = 330847.77696028
# Iteration 315, loss = 319385.20927133
# Iteration 316, loss = 308289.47757040
# Iteration 317, loss = 297550.00045922
# Iteration 318, loss = 287156.45944437
# Iteration 319, loss = 277098.79387543
# Iteration 320, loss = 267367.19593172
# Iteration 321, loss = 257952.10565899
# Iteration 322, loss = 248844.20605701
# Iteration 323, loss = 240034.41821925
# Iteration 324, loss = 231513.89652550
# Iteration 325, loss = 223274.02388839
# Iteration 326, loss = 215306.40705476
# Iteration 327, loss = 207602.87196253
# Iteration 328, loss = 200155.45915390
# Iteration 329, loss = 192956.41924562
# Iteration 330, loss = 185998.20845683
# Iteration 331, loss = 179273.48419510
# Iteration 332, loss = 172775.10070123
# Iteration 333, loss = 166496.10475323
# Iteration 334, loss = 160429.73142987
# Iteration 335, loss = 154569.39993423
# Iteration 336, loss = 148908.70947748
# Iteration 337, loss = 143441.43522318
# Iteration 338, loss = 138161.52429237
# Iteration 339, loss = 133063.09182953
# Iteration 340, loss = 128140.41712955
# Iteration 341, loss = 123387.93982578
# Iteration 342, loss = 118800.25613933
# Iteration 343, loss = 114372.11518928
# Iteration 344, loss = 110098.41536419
# Iteration 345, loss = 105974.20075439
# Iteration 346, loss = 101994.65764525
# Iteration 347, loss = 98155.11107106
# Iteration 348, loss = 94451.02142945
# Iteration 349, loss = 90877.98115603
# Iteration 350, loss = 87431.71145899
# Iteration 351, loss = 84108.05911347
# Iteration 352, loss = 80902.99331520
# Iteration 353, loss = 77812.60259315
# Iteration 354, loss = 74833.09178088
# Iteration 355, loss = 71960.77904597
# Iteration 356, loss = 69192.09297731
# Iteration 357, loss = 66523.56972967
# Iteration 358, loss = 63951.85022503
# Iteration 359, loss = 61473.67741035
# Iteration 360, loss = 59085.89357102
# Iteration 361, loss = 56785.43769963
# Iteration 362, loss = 54569.34291936
# Iteration 363, loss = 52434.73396153
# Iteration 364, loss = 50378.82469664
# Iteration 365, loss = 48398.91571830
# Iteration 366, loss = 46492.39197945
# Iteration 367, loss = 44656.72048021
# Iteration 368, loss = 42889.44800671
# Iteration 369, loss = 41188.19892029
# Iteration 370, loss = 39550.67299630
# Iteration 371, loss = 37974.64331193
# Iteration 372, loss = 36457.95418232
# Iteration 373, loss = 34998.51914431
# Iteration 374, loss = 33594.31898701
# Iteration 375, loss = 32243.39982866
# Iteration 376, loss = 30943.87123895
# Iteration 377, loss = 29693.90440610
# Iteration 378, loss = 28491.73034802
# Iteration 379, loss = 27335.63816680
# Iteration 380, loss = 26223.97334588
# Iteration 381, loss = 25155.13608900
# Iteration 382, loss = 24127.57970048
# Iteration 383, loss = 23139.80900582
# Iteration 384, loss = 22190.37881216
# Iteration 385, loss = 21277.89240764
# Iteration 386, loss = 20401.00009918
# Iteration 387, loss = 19558.39778774
# Iteration 388, loss = 18748.82558053
# Iteration 389, loss = 17971.06643932
# Iteration 390, loss = 17223.94486430
# Iteration 391, loss = 16506.32561261
# Iteration 392, loss = 15817.11245098
# Iteration 393, loss = 15155.24694175
# Iteration 394, loss = 14519.70726153
# Iteration 395, loss = 13909.50705197
# Iteration 396, loss = 13323.69430174
# Iteration 397, loss = 12761.35025929
# Iteration 398, loss = 12221.58837552
# Iteration 399, loss = 11703.55327593
# Iteration 400, loss = 11206.41976136
# Iteration 401, loss = 10729.39183687
# Iteration 402, loss = 10271.70176803
# Iteration 403, loss = 9832.60916408
# Iteration 404, loss = 9411.40008723
# Iteration 405, loss = 9007.38618759
# Iteration 406, loss = 8619.90386311
# Iteration 407, loss = 8248.31344388
# Iteration 408, loss = 7891.99840035
# Iteration 409, loss = 7550.36457467
# Iteration 410, loss = 7222.83943487
# Iteration 411, loss = 6908.87135107
# Iteration 412, loss = 6607.92889331
# Iteration 413, loss = 6319.50015045
# Iteration 414, loss = 6043.09206958
# Iteration 415, loss = 5778.22981545
# Iteration 416, loss = 5524.45614935
# Iteration 417, loss = 5281.33082707
# Iteration 418, loss = 5048.43001528
# Iteration 419, loss = 4825.34572598
# Iteration 420, loss = 4611.68526848
# Iteration 421, loss = 4407.07071845
# Iteration 422, loss = 4211.13840366
# Iteration 423, loss = 4023.53840580
# Iteration 424, loss = 3843.93407814
# Iteration 425, loss = 3672.00157846
# Iteration 426, loss = 3507.42941685
# Iteration 427, loss = 3349.91801806
# Iteration 428, loss = 3199.17929789
# Iteration 429, loss = 3054.93625323
# Iteration 430, loss = 2916.92256554
# Iteration 431, loss = 2784.88221707
# Iteration 432, loss = 2658.56911979
# Iteration 433, loss = 2537.74675644
# Iteration 434, loss = 2422.18783348
# Iteration 435, loss = 2311.67394546
# Iteration 436, loss = 2205.99525065
# Iteration 437, loss = 2104.95015746
# Iteration 438, loss = 2008.34502139
# Iteration 439, loss = 1915.99385218
# Iteration 440, loss = 1827.71803087
# Iteration 441, loss = 1743.34603649
# Iteration 442, loss = 1662.71318200
# Iteration 443, loss = 1585.66135934
# Iteration 444, loss = 1512.03879319
# Iteration 445, loss = 1441.69980322
# Iteration 446, loss = 1374.50457461
# Iteration 447, loss = 1310.31893646
# Iteration 448, loss = 1249.01414804
# Iteration 449, loss = 1190.46669240
# Iteration 450, loss = 1134.55807732
# Iteration 451, loss = 1081.17464325
# Iteration 452, loss = 1030.20737799
# Iteration 453, loss = 981.55173806
# Iteration 454, loss = 935.10747635
# Iteration 455, loss = 890.77847592
# Iteration 456, loss = 848.47258987
# Iteration 457, loss = 808.10148685
# Iteration 458, loss = 769.58050225
# Iteration 459, loss = 732.82849474
# Iteration 460, loss = 697.76770800
# Iteration 461, loss = 664.32363759
# Iteration 462, loss = 632.42490262
# Iteration 463, loss = 602.00312215
# Iteration 464, loss = 572.99279616
# Iteration 465, loss = 545.33119094
# Iteration 466, loss = 518.95822871
# Iteration 467, loss = 493.81638134
# Iteration 468, loss = 469.85056810
# Iteration 469, loss = 447.00805716
# Iteration 470, loss = 425.23837086
# Iteration 471, loss = 404.49319453
# Iteration 472, loss = 384.72628879
# Iteration 473, loss = 365.89340510
# Iteration 474, loss = 347.95220461
# Iteration 475, loss = 330.86218011
# Iteration 476, loss = 314.58458088
# Iteration 477, loss = 299.08234054
# Iteration 478, loss = 284.32000763
# Iteration 479, loss = 270.26367887
# Iteration 480, loss = 256.88093502
# Iteration 481, loss = 244.14077925
# Iteration 482, loss = 232.01357787
# Iteration 483, loss = 220.47100346
# Iteration 484, loss = 209.48598017
# Iteration 485, loss = 199.03263116
# Iteration 486, loss = 189.08622820
# Iteration 487, loss = 179.62314319
# Iteration 488, loss = 170.62080160
# Iteration 489, loss = 162.05763788
# Iteration 490, loss = 153.91305248
# Iteration 491, loss = 146.16737074
# Iteration 492, loss = 138.80180337
# Iteration 493, loss = 131.79840849
# Iteration 494, loss = 125.14005531
# Iteration 495, loss = 118.81038914
# Iteration 496, loss = 112.79379797
# Iteration 497, loss = 107.07538029
# Iteration 498, loss = 101.64091432
# Iteration 499, loss = 96.47682842
# Iteration 500, loss = 91.57017278
# Iteration 501, loss = 86.90859226
# Iteration 502, loss = 82.48030033
# Iteration 503, loss = 78.27405411
# Iteration 504, loss = 74.27913046
# Iteration 505, loss = 70.48530304
# Iteration 506, loss = 66.88282033
# Iteration 507, loss = 63.46238462
# Iteration 508, loss = 60.21513180
# Iteration 509, loss = 57.13261206
# Iteration 510, loss = 54.20677144
# Iteration 511, loss = 51.42993403
# Iteration 512, loss = 48.79478507
# Iteration 513, loss = 46.29435472
# Iteration 514, loss = 43.92200244
# Iteration 515, loss = 41.67140219
# Iteration 516, loss = 39.53652816
# Iteration 517, loss = 37.51164113
# Iteration 518, loss = 35.59127543
# Iteration 519, loss = 33.77022648
# Iteration 520, loss = 32.04353886
# Iteration 521, loss = 30.40649487
# Iteration 522, loss = 28.85460361
# Iteration 523, loss = 27.38359058
# Iteration 524, loss = 25.98938766
# Iteration 525, loss = 24.66812356
# Iteration 526, loss = 23.41611472
# Iteration 527, loss = 22.22985658
# Iteration 528, loss = 21.10601525
# Iteration 529, loss = 20.04141953
# Iteration 530, loss = 19.03305331
# Iteration 531, loss = 18.07804829
# Iteration 532, loss = 17.17367705
# Iteration 533, loss = 16.31734639
# Iteration 534, loss = 15.50659103
# Iteration 535, loss = 14.73906751
# Iteration 536, loss = 14.01254846
# Iteration 537, loss = 13.32491706
# Iteration 538, loss = 12.67416175
# Iteration 539, loss = 12.05837127
# Iteration 540, loss = 11.47572978
# Iteration 541, loss = 10.92451237
# Iteration 542, loss = 10.40308060
# Iteration 543, loss = 9.90987840
# Iteration 544, loss = 9.44342808
# Iteration 545, loss = 9.00232653
# Iteration 546, loss = 8.58524158
# Iteration 547, loss = 8.19090859
# Iteration 548, loss = 7.81812717
# Iteration 549, loss = 7.46575797
# Iteration 550, loss = 7.13271980
# Iteration 551, loss = 6.81798668
# Iteration 552, loss = 6.52058518
# Iteration 553, loss = 6.23959184
# Iteration 554, loss = 5.97413066
# Iteration 555, loss = 5.72337079
# Iteration 556, loss = 5.48652428
# Iteration 557, loss = 5.26284395
# Iteration 558, loss = 5.05162134
# Iteration 559, loss = 4.85218482
# Iteration 560, loss = 4.66389772
# Iteration 561, loss = 4.48615657
# Iteration 562, loss = 4.31838945
# Iteration 563, loss = 4.16005441
# Iteration 564, loss = 4.01063793
# Iteration 565, loss = 3.86965350
# Iteration 566, loss = 3.73664027
# Iteration 567, loss = 3.61116169
# Iteration 568, loss = 3.49280435
# Iteration 569, loss = 3.38117673
# Iteration 570, loss = 3.27590814
# Iteration 571, loss = 3.17664761
# Iteration 572, loss = 3.08306289
# Iteration 573, loss = 2.99483951
# Iteration 574, loss = 2.91167983
# Iteration 575, loss = 2.83330219
# Iteration 576, loss = 2.75944007
# Iteration 577, loss = 2.68984135
# Iteration 578, loss = 2.62426747
# Iteration 579, loss = 2.56249282
# Iteration 580, loss = 2.50430401
# Iteration 581, loss = 2.44949925
# Iteration 582, loss = 2.39788773
# Iteration 583, loss = 2.34928904
# Iteration 584, loss = 2.30353264
# Iteration 585, loss = 2.26045735
# Iteration 586, loss = 2.21991080
# Iteration 587, loss = 2.18174902
# Iteration 588, loss = 2.14583598
# Iteration 589, loss = 2.11204314
# Iteration 590, loss = 2.08024909
# Iteration 591, loss = 2.05033914
# Iteration 592, loss = 2.02220498
# Iteration 593, loss = 1.99574431
# Iteration 594, loss = 1.97086057
# Iteration 595, loss = 1.94746256
# Iteration 596, loss = 1.92546421
# Iteration 597, loss = 1.90478426
# Iteration 598, loss = 1.88534605
# Iteration 599, loss = 1.86707719
# Iteration 600, loss = 1.84990944
# Iteration 601, loss = 1.83377835
# Iteration 602, loss = 1.81862319
# Iteration 603, loss = 1.80438662
# Iteration 604, loss = 1.79101460
# Iteration 605, loss = 1.77845616
# Iteration 606, loss = 1.76666324
# Iteration 607, loss = 1.75559054
# Iteration 608, loss = 1.74519535
# Iteration 609, loss = 1.73543741
# Iteration 610, loss = 1.72627878
# Iteration 611, loss = 1.71768373
# Iteration 612, loss = 1.70961858
# Iteration 613, loss = 1.70205158
# Iteration 614, loss = 1.69495287
# Iteration 615, loss = 1.68829429
# Iteration 616, loss = 1.68204933
# Iteration 617, loss = 1.67619304
# Iteration 618, loss = 1.67070191
# Iteration 619, loss = 1.66555383
# Iteration 620, loss = 1.66072797
# Iteration 621, loss = 1.65620474
# Iteration 622, loss = 1.65196570
# Iteration 623, loss = 1.64799350
# Iteration 624, loss = 1.64427181
# Iteration 625, loss = 1.64078529
# Iteration 626, loss = 1.63751949
# Iteration 627, loss = 1.63446084
# Iteration 628, loss = 1.63159656
# Iteration 629, loss = 1.62891464
# Iteration 630, loss = 1.62640381
# Iteration 631, loss = 1.62405345
# Iteration 632, loss = 1.62185359
# Iteration 633, loss = 1.61979487
# Iteration 634, loss = 1.61786847
# Iteration 635, loss = 1.61606614
# Iteration 636, loss = 1.61438011
# Iteration 637, loss = 1.61280307
# Iteration 638, loss = 1.61132817
# Iteration 639, loss = 1.60994899
# Iteration 640, loss = 1.60865948
# Iteration 641, loss = 1.60745397
# Iteration 642, loss = 1.60632715
# Iteration 643, loss = 1.60527401
# Iteration 644, loss = 1.60428986
# Iteration 645, loss = 1.60337032
# Iteration 646, loss = 1.60251126
# Iteration 647, loss = 1.60170880
# Iteration 648, loss = 1.60095933
# Iteration 649, loss = 1.60025943
# Iteration 650, loss = 1.59960591
# Iteration 651, loss = 1.59899579
# Iteration 652, loss = 1.59842626
# Iteration 653, loss = 1.59789469
# Iteration 654, loss = 1.59739862
# Iteration 655, loss = 1.59693575
# Iteration 656, loss = 1.59650390
# Iteration 657, loss = 1.59610106
# Iteration 658, loss = 1.59572533
# Iteration 659, loss = 1.59537494
# Iteration 660, loss = 1.59504821
# Iteration 661, loss = 1.59474360
# Iteration 662, loss = 1.59445965
# Iteration 663, loss = 1.59419499
# Iteration 664, loss = 1.59394834
# Iteration 665, loss = 1.59371852
# Iteration 666, loss = 1.59350440
# Iteration 667, loss = 1.59330494
# Iteration 668, loss = 1.59311916
# Iteration 669, loss = 1.59294614
# Iteration 670, loss = 1.59278504
# Iteration 671, loss = 1.59263505
# Iteration 672, loss = 1.59249543
# Iteration 673, loss = 1.59236547
# Iteration 674, loss = 1.59224453
# Iteration 675, loss = 1.59213199
# Iteration 676, loss = 1.59202729
# Iteration 677, loss = 1.59192989
# Iteration 678, loss = 1.59183929
# Iteration 679, loss = 1.59175504
# Iteration 680, loss = 1.59167670
# Iteration 681, loss = 1.59160386
# Iteration 682, loss = 1.59153615
# Iteration 683, loss = 1.59147321
# Iteration 684, loss = 1.59141472
# Iteration 685, loss = 1.59136037
# Iteration 686, loss = 1.59130986
# Iteration 687, loss = 1.59126295
# Iteration 688, loss = 1.59121937
# Iteration 689, loss = 1.59117889
# Iteration 690, loss = 1.59114130
# Iteration 691, loss = 1.59110640
# Iteration 692, loss = 1.59107399
# Iteration 693, loss = 1.59104391
# Iteration 694, loss = 1.59101598
# Iteration 695, loss = 1.59099007
# Iteration 696, loss = 1.59096602
# Iteration 697, loss = 1.59094370
# Iteration 698, loss = 1.59092299
# Iteration 699, loss = 1.59090378
# Iteration 700, loss = 1.59088596
# Iteration 701, loss = 1.59086942
# Iteration 702, loss = 1.59085409
# Iteration 703, loss = 1.59083987
# Iteration 704, loss = 1.59082668
# Iteration 705, loss = 1.59081445
# Iteration 706, loss = 1.59080311
# Iteration 707, loss = 1.59079259
# Iteration 708, loss = 1.59078284
# Iteration 709, loss = 1.59077379
# Iteration 710, loss = 1.59076541
# Iteration 711, loss = 1.59075763
# Iteration 712, loss = 1.59075042
# Iteration 713, loss = 1.59074374
# Iteration 714, loss = 1.59073754
# Iteration 715, loss = 1.59073179
# Iteration 716, loss = 1.59072646
# Iteration 717, loss = 1.59072151
# Iteration 718, loss = 1.59071692
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# (array([4.12260414]), -3.6741440524096074)

# %% [markdown]
# ###  [OPTIONAL] Qe) Neural Network with pre-scaling
#
# Now, the neurons in neural networks normally expects input data in the range `[0;1]` or sometimes in the range `[-1;1]`, meaning that for value outside this range the you put of the neuron will saturate to it's min or max value (also typical `0` or `1`).
#
# A concrete value of `X` is, say 22.000 USD, that is far away from what the MLP expects. To af fix to the problem in Qd) is to preprocess data by scaling it down to something more sensible.
#
# Try to scale X to a range of `[0;1]`, re-train the MLP, re-plot and find the new score from the rescaled input. Any better?

# %%
# TODO: add your code here..
#assert False, "TODO: try prescale data for the MPL...any better?"

from sklearn import preprocessing
import numpy as np

# X transformation
min_max_scaler = preprocessing.MinMaxScaler([0,1])
X_new = min_max_scaler.fit_transform(X)

mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(X_new, y.ravel())

#
# create an test matrix M, with the same dimensionality as X, and in the range [0;1] 
# and a step size of your choice
m=np.linspace(0, 1, 1000)
M=np.empty([m.shape[0],1])
M[:,0]=m

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(M) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")


# TODO: add your code here..
#assert False, "TODO: predict value for Cyprus and fetch the score() from the fitting."
pred = [[0.22587]]
y_pred = mlp.predict(pred)

y_pred, mlp.score(X_new, y)

# With the scaled input, it is much better
# Out:
# Iteration 1, loss = 16.53426974
# Iteration 2, loss = 16.48070974
# Iteration 3, loss = 16.42725542
# Iteration 4, loss = 16.37435879
# Iteration 5, loss = 16.32181772
# Iteration 6, loss = 16.26954654
# Iteration 7, loss = 16.21745704
# Iteration 8, loss = 16.16546414
# Iteration 9, loss = 16.11356375
# Iteration 10, loss = 16.06175355
# Iteration 11, loss = 16.01003223
# Iteration 12, loss = 15.95839910
# Iteration 13, loss = 15.90685384
# Iteration 14, loss = 15.85560048
# Iteration 15, loss = 15.80448290
# Iteration 16, loss = 15.75346365
# Iteration 17, loss = 15.70255436
# Iteration 18, loss = 15.65203513
# Iteration 19, loss = 15.60185607
# Iteration 20, loss = 15.55205828
# Iteration 21, loss = 15.50256265
# Iteration 22, loss = 15.45320846
# Iteration 23, loss = 15.40402516
# Iteration 24, loss = 15.35496072
# Iteration 25, loss = 15.30604266
# Iteration 26, loss = 15.25739829
# Iteration 27, loss = 15.20886267
# Iteration 28, loss = 15.16043091
# Iteration 29, loss = 15.11209865
# Iteration 30, loss = 15.06386205
# Iteration 31, loss = 15.01573266
# Iteration 32, loss = 14.96784330
# Iteration 33, loss = 14.92004800
# Iteration 34, loss = 14.87234320
# Iteration 35, loss = 14.82472572
# Iteration 36, loss = 14.77719269
# Iteration 37, loss = 14.72974152
# Iteration 38, loss = 14.68236987
# Iteration 39, loss = 14.63507561
# Iteration 40, loss = 14.58791565
# Iteration 41, loss = 14.54091052
# Iteration 42, loss = 14.49398447
# Iteration 43, loss = 14.44724377
# Iteration 44, loss = 14.40063554
# Iteration 45, loss = 14.35410885
# Iteration 46, loss = 14.30766065
# Iteration 47, loss = 14.26128817
# Iteration 48, loss = 14.21512155
# Iteration 49, loss = 14.16917642
# Iteration 50, loss = 14.12333123
# Iteration 51, loss = 14.07756721
# Iteration 52, loss = 14.03188071
# Iteration 53, loss = 13.98626839
# Iteration 54, loss = 13.94072719
# Iteration 55, loss = 13.89525433
# Iteration 56, loss = 13.84984725
# Iteration 57, loss = 13.80450363
# Iteration 58, loss = 13.75922132
# Iteration 59, loss = 13.71399834
# Iteration 60, loss = 13.66883288
# Iteration 61, loss = 13.62383851
# Iteration 62, loss = 13.57895003
# Iteration 63, loss = 13.53429173
# Iteration 64, loss = 13.49003974
# Iteration 65, loss = 13.44621651
# Iteration 66, loss = 13.40255766
# Iteration 67, loss = 13.35898866
# Iteration 68, loss = 13.31550288
# Iteration 69, loss = 13.27209431
# Iteration 70, loss = 13.22878171
# Iteration 71, loss = 13.18594415
# Iteration 72, loss = 13.14325625
# Iteration 73, loss = 13.10074582
# Iteration 74, loss = 13.05840268
# Iteration 75, loss = 13.01621920
# Iteration 76, loss = 12.97417291
# Iteration 77, loss = 12.93223024
# Iteration 78, loss = 12.89041999
# Iteration 79, loss = 12.84875400
# Iteration 80, loss = 12.80716399
# Iteration 81, loss = 12.76562634
# Iteration 82, loss = 12.72420623
# Iteration 83, loss = 12.68285492
# Iteration 84, loss = 12.64163192
# Iteration 85, loss = 12.60045515
# Iteration 86, loss = 12.55933208
# Iteration 87, loss = 12.51827131
# Iteration 88, loss = 12.47729259
# Iteration 89, loss = 12.43634931
# Iteration 90, loss = 12.39543921
# Iteration 91, loss = 12.35456028
# Iteration 92, loss = 12.31371072
# Iteration 93, loss = 12.27295865
# Iteration 94, loss = 12.23226348
# Iteration 95, loss = 12.19163290
# Iteration 96, loss = 12.15103284
# Iteration 97, loss = 12.11046142
# Iteration 98, loss = 12.06991697
# Iteration 99, loss = 12.02939798
# Iteration 100, loss = 11.98890311
# Iteration 101, loss = 11.94843116
# Iteration 102, loss = 11.90798106
# Iteration 103, loss = 11.86756600
# Iteration 104, loss = 11.82718929
# Iteration 105, loss = 11.78683351
# Iteration 106, loss = 11.74649783
# Iteration 107, loss = 11.70620151
# Iteration 108, loss = 11.66600074
# Iteration 109, loss = 11.62584235
# Iteration 110, loss = 11.58570747
# Iteration 111, loss = 11.54559491
# Iteration 112, loss = 11.50550361
# Iteration 113, loss = 11.46543263
# Iteration 114, loss = 11.42538115
# Iteration 115, loss = 11.38534842
# Iteration 116, loss = 11.34533382
# Iteration 117, loss = 11.30533676
# Iteration 118, loss = 11.26535675
# Iteration 119, loss = 11.22539337
# Iteration 120, loss = 11.18544625
# Iteration 121, loss = 11.14551508
# Iteration 122, loss = 11.10559959
# Iteration 123, loss = 11.06569956
# Iteration 124, loss = 11.02581483
# Iteration 125, loss = 10.98596536
# Iteration 126, loss = 10.94618946
# Iteration 127, loss = 10.90643347
# Iteration 128, loss = 10.86669676
# Iteration 129, loss = 10.82697874
# Iteration 130, loss = 10.78727894
# Iteration 131, loss = 10.74759694
# Iteration 132, loss = 10.70794030
# Iteration 133, loss = 10.66831610
# Iteration 134, loss = 10.62871036
# Iteration 135, loss = 10.58912271
# Iteration 136, loss = 10.54955289
# Iteration 137, loss = 10.51000065
# Iteration 138, loss = 10.47046582
# Iteration 139, loss = 10.43094829
# Iteration 140, loss = 10.39144795
# Iteration 141, loss = 10.35197634
# Iteration 142, loss = 10.31252850
# Iteration 143, loss = 10.27309894
# Iteration 144, loss = 10.23368760
# Iteration 145, loss = 10.19429445
# Iteration 146, loss = 10.15491951
# Iteration 147, loss = 10.11557019
# Iteration 148, loss = 10.07624721
# Iteration 149, loss = 10.03694353
# Iteration 150, loss = 9.99765920
# Iteration 151, loss = 9.95839430
# Iteration 152, loss = 9.91915885
# Iteration 153, loss = 9.87995061
# Iteration 154, loss = 9.84076307
# Iteration 155, loss = 9.80159632
# Iteration 156, loss = 9.76245051
# Iteration 157, loss = 9.72335131
# Iteration 158, loss = 9.68428982
# Iteration 159, loss = 9.64525247
# Iteration 160, loss = 9.60623915
# Iteration 161, loss = 9.56725280
# Iteration 162, loss = 9.52830388
# Iteration 163, loss = 9.48937977
# Iteration 164, loss = 9.45048049
# Iteration 165, loss = 9.41165639
# Iteration 166, loss = 9.37286522
# Iteration 167, loss = 9.33410290
# Iteration 168, loss = 9.29536917
# Iteration 169, loss = 9.25666384
# Iteration 170, loss = 9.21798679
# Iteration 171, loss = 9.17933798
# Iteration 172, loss = 9.14071742
# Iteration 173, loss = 9.10212517
# Iteration 174, loss = 9.06356136
# Iteration 175, loss = 9.02502613
# Iteration 176, loss = 8.98651971
# Iteration 177, loss = 8.94804232
# Iteration 178, loss = 8.90959425
# Iteration 179, loss = 8.87117581
# Iteration 180, loss = 8.83278733
# Iteration 181, loss = 8.79442918
# Iteration 182, loss = 8.75610175
# Iteration 183, loss = 8.71780545
# Iteration 184, loss = 8.67954072
# Iteration 185, loss = 8.64130801
# Iteration 186, loss = 8.60310779
# Iteration 187, loss = 8.56495667
# Iteration 188, loss = 8.52688068
# Iteration 189, loss = 8.48884218
# Iteration 190, loss = 8.45084126
# Iteration 191, loss = 8.41287808
# Iteration 192, loss = 8.37495284
# Iteration 193, loss = 8.33706578
# Iteration 194, loss = 8.29921721
# Iteration 195, loss = 8.26140743
# Iteration 196, loss = 8.22363682
# Iteration 197, loss = 8.18591572
# Iteration 198, loss = 8.14823545
# Iteration 199, loss = 8.11059703
# Iteration 200, loss = 8.07300697
# Iteration 201, loss = 8.03545895
# Iteration 202, loss = 7.99795340
# Iteration 203, loss = 7.96049078
# Iteration 204, loss = 7.92307157
# Iteration 205, loss = 7.88569626
# Iteration 206, loss = 7.84836537
# Iteration 207, loss = 7.81107944
# Iteration 208, loss = 7.77383902
# Iteration 209, loss = 7.73664467
# Iteration 210, loss = 7.69949696
# Iteration 211, loss = 7.66239650
# Iteration 212, loss = 7.62534388
# Iteration 213, loss = 7.58835633
# Iteration 214, loss = 7.55143035
# Iteration 215, loss = 7.51455585
# Iteration 216, loss = 7.47773321
# Iteration 217, loss = 7.44096285
# Iteration 218, loss = 7.40424523
# Iteration 219, loss = 7.36758083
# Iteration 220, loss = 7.33097013
# Iteration 221, loss = 7.29441366
# Iteration 222, loss = 7.25791196
# Iteration 223, loss = 7.22146558
# Iteration 224, loss = 7.18507509
# Iteration 225, loss = 7.14874107
# Iteration 226, loss = 7.11246410
# Iteration 227, loss = 7.07624480
# Iteration 228, loss = 7.04008377
# Iteration 229, loss = 7.00398164
# Iteration 230, loss = 6.96793903
# Iteration 231, loss = 6.93195659
# Iteration 232, loss = 6.89603495
# Iteration 233, loss = 6.86017475
# Iteration 234, loss = 6.82437665
# Iteration 235, loss = 6.78864130
# Iteration 236, loss = 6.75296936
# Iteration 237, loss = 6.71736149
# Iteration 238, loss = 6.68181835
# Iteration 239, loss = 6.64634061
# Iteration 240, loss = 6.61092893
# Iteration 241, loss = 6.57558397
# Iteration 242, loss = 6.54030642
# Iteration 243, loss = 6.50509693
# Iteration 244, loss = 6.46995618
# Iteration 245, loss = 6.43488484
# Iteration 246, loss = 6.39988356
# Iteration 247, loss = 6.36495303
# Iteration 248, loss = 6.33009390
# Iteration 249, loss = 6.29530864
# Iteration 250, loss = 6.26059955
# Iteration 251, loss = 6.22596407
# Iteration 252, loss = 6.19140285
# Iteration 253, loss = 6.15691652
# Iteration 254, loss = 6.12250571
# Iteration 255, loss = 6.08817107
# Iteration 256, loss = 6.05391325
# Iteration 257, loss = 6.01973286
# Iteration 258, loss = 5.98563112
# Iteration 259, loss = 5.95161133
# Iteration 260, loss = 5.91767079
# Iteration 261, loss = 5.88381015
# Iteration 262, loss = 5.85003004
# Iteration 263, loss = 5.81633110
# Iteration 264, loss = 5.78271396
# Iteration 265, loss = 5.74917927
# Iteration 266, loss = 5.71572763
# Iteration 267, loss = 5.68235969
# Iteration 268, loss = 5.64907605
# Iteration 269, loss = 5.61587735
# Iteration 270, loss = 5.58276419
# Iteration 271, loss = 5.54973719
# Iteration 272, loss = 5.51679696
# Iteration 273, loss = 5.48394409
# Iteration 274, loss = 5.45117919
# Iteration 275, loss = 5.41850286
# Iteration 276, loss = 5.38591569
# Iteration 277, loss = 5.35341827
# Iteration 278, loss = 5.32101119
# Iteration 279, loss = 5.28869502
# Iteration 280, loss = 5.25647034
# Iteration 281, loss = 5.22433773
# Iteration 282, loss = 5.19229775
# Iteration 283, loss = 5.16035097
# Iteration 284, loss = 5.12849795
# Iteration 285, loss = 5.09673924
# Iteration 286, loss = 5.06507540
# Iteration 287, loss = 5.03351382
# Iteration 288, loss = 5.00205699
# Iteration 289, loss = 4.97069758
# Iteration 290, loss = 4.93943600
# Iteration 291, loss = 4.90827264
# Iteration 292, loss = 4.87720793
# Iteration 293, loss = 4.84624229
# Iteration 294, loss = 4.81537614
# Iteration 295, loss = 4.78460991
# Iteration 296, loss = 4.75394405
# Iteration 297, loss = 4.72337898
# Iteration 298, loss = 4.69291514
# Iteration 299, loss = 4.66255297
# Iteration 300, loss = 4.63229291
# Iteration 301, loss = 4.60213540
# Iteration 302, loss = 4.57208086
# Iteration 303, loss = 4.54212974
# Iteration 304, loss = 4.51228247
# Iteration 305, loss = 4.48255991
# Iteration 306, loss = 4.45294568
# Iteration 307, loss = 4.42343806
# Iteration 308, loss = 4.39403727
# Iteration 309, loss = 4.36474355
# Iteration 310, loss = 4.33555717
# Iteration 311, loss = 4.30647837
# Iteration 312, loss = 4.27750746
# Iteration 313, loss = 4.24864471
# Iteration 314, loss = 4.21989042
# Iteration 315, loss = 4.19124489
# Iteration 316, loss = 4.16270842
# Iteration 317, loss = 4.13428133
# Iteration 318, loss = 4.10596391
# Iteration 319, loss = 4.07775650
# Iteration 320, loss = 4.04965939
# Iteration 321, loss = 4.02167290
# Iteration 322, loss = 3.99379735
# Iteration 323, loss = 3.96603305
# Iteration 324, loss = 3.93838031
# Iteration 325, loss = 3.91083943
# Iteration 326, loss = 3.88341073
# Iteration 327, loss = 3.85609451
# Iteration 328, loss = 3.82889106
# Iteration 329, loss = 3.80180069
# Iteration 330, loss = 3.77482368
# Iteration 331, loss = 3.74796033
# Iteration 332, loss = 3.72121091
# Iteration 333, loss = 3.69457572
# Iteration 334, loss = 3.66805502
# Iteration 335, loss = 3.64165632
# Iteration 336, loss = 3.61537860
# Iteration 337, loss = 3.58921692
# Iteration 338, loss = 3.56317145
# Iteration 339, loss = 3.53724232
# Iteration 340, loss = 3.51142970
# Iteration 341, loss = 3.48573374
# Iteration 342, loss = 3.46015462
# Iteration 343, loss = 3.43469249
# Iteration 344, loss = 3.40934751
# Iteration 345, loss = 3.38411986
# Iteration 346, loss = 3.35900969
# Iteration 347, loss = 3.33401718
# Iteration 348, loss = 3.30914246
# Iteration 349, loss = 3.28438572
# Iteration 350, loss = 3.25974709
# Iteration 351, loss = 3.23522673
# Iteration 352, loss = 3.21082480
# Iteration 353, loss = 3.18654142
# Iteration 354, loss = 3.16238676
# Iteration 355, loss = 3.13835343
# Iteration 356, loss = 3.11443983
# Iteration 357, loss = 3.09064596
# Iteration 358, loss = 3.06697186
# Iteration 359, loss = 3.04341756
# Iteration 360, loss = 3.01998309
# Iteration 361, loss = 2.99666849
# Iteration 362, loss = 2.97347379
# Iteration 363, loss = 2.95039904
# Iteration 364, loss = 2.92744428
# Iteration 365, loss = 2.90460954
# Iteration 366, loss = 2.88189485
# Iteration 367, loss = 2.85930027
# Iteration 368, loss = 2.83682581
# Iteration 369, loss = 2.81447151
# Iteration 370, loss = 2.79223739
# Iteration 371, loss = 2.77012349
# Iteration 372, loss = 2.74812981
# Iteration 373, loss = 2.72625638
# Iteration 374, loss = 2.70450320
# Iteration 375, loss = 2.68287030
# Iteration 376, loss = 2.66135765
# Iteration 377, loss = 2.63996528
# Iteration 378, loss = 2.61869316
# Iteration 379, loss = 2.59754129
# Iteration 380, loss = 2.57650964
# Iteration 381, loss = 2.55559821
# Iteration 382, loss = 2.53480695
# Iteration 383, loss = 2.51413583
# Iteration 384, loss = 2.49358483
# Iteration 385, loss = 2.47315388
# Iteration 386, loss = 2.45284294
# Iteration 387, loss = 2.43265195
# Iteration 388, loss = 2.41258085
# Iteration 389, loss = 2.39262958
# Iteration 390, loss = 2.37279805
# Iteration 391, loss = 2.35308620
# Iteration 392, loss = 2.33349392
# Iteration 393, loss = 2.31402354
# Iteration 394, loss = 2.29467736
# Iteration 395, loss = 2.27545090
# Iteration 396, loss = 2.25634397
# Iteration 397, loss = 2.23735641
# Iteration 398, loss = 2.21848804
# Iteration 399, loss = 2.19973869
# Iteration 400, loss = 2.18110819
# Iteration 401, loss = 2.16259636
# Iteration 402, loss = 2.14420302
# Iteration 403, loss = 2.12592800
# Iteration 404, loss = 2.10777111
# Iteration 405, loss = 2.08973216
# Iteration 406, loss = 2.07181097
# Iteration 407, loss = 2.05400735
# Iteration 408, loss = 2.03632109
# Iteration 409, loss = 2.01875200
# Iteration 410, loss = 2.00129987
# Iteration 411, loss = 1.98396450
# Iteration 412, loss = 1.96674566
# Iteration 413, loss = 1.94964316
# Iteration 414, loss = 1.93265676
# Iteration 415, loss = 1.91578624
# Iteration 416, loss = 1.89903136
# Iteration 417, loss = 1.88239190
# Iteration 418, loss = 1.86586761
# Iteration 419, loss = 1.84945824
# Iteration 420, loss = 1.83316356
# Iteration 421, loss = 1.81698330
# Iteration 422, loss = 1.80091720
# Iteration 423, loss = 1.78496501
# Iteration 424, loss = 1.76912645
# Iteration 425, loss = 1.75340124
# Iteration 426, loss = 1.73778912
# Iteration 427, loss = 1.72228980
# Iteration 428, loss = 1.70691038
# Iteration 429, loss = 1.69164466
# Iteration 430, loss = 1.67649137
# Iteration 431, loss = 1.66145015
# Iteration 432, loss = 1.64652063
# Iteration 433, loss = 1.63170244
# Iteration 434, loss = 1.61699520
# Iteration 435, loss = 1.60239857
# Iteration 436, loss = 1.58791216
# Iteration 437, loss = 1.57353563
# Iteration 438, loss = 1.55926859
# Iteration 439, loss = 1.54511068
# Iteration 440, loss = 1.53106154
# Iteration 441, loss = 1.51712079
# Iteration 442, loss = 1.50328806
# Iteration 443, loss = 1.48956298
# Iteration 444, loss = 1.47594517
# Iteration 445, loss = 1.46243425
# Iteration 446, loss = 1.44902984
# Iteration 447, loss = 1.43573156
# Iteration 448, loss = 1.42253903
# Iteration 449, loss = 1.40945185
# Iteration 450, loss = 1.39646962
# Iteration 451, loss = 1.38359197
# Iteration 452, loss = 1.37081849
# Iteration 453, loss = 1.35814877
# Iteration 454, loss = 1.34558242
# Iteration 455, loss = 1.33311903
# Iteration 456, loss = 1.32075819
# Iteration 457, loss = 1.30849949
# Iteration 458, loss = 1.29634251
# Iteration 459, loss = 1.28428683
# Iteration 460, loss = 1.27233204
# Iteration 461, loss = 1.26047770
# Iteration 462, loss = 1.24872339
# Iteration 463, loss = 1.23706869
# Iteration 464, loss = 1.22551315
# Iteration 465, loss = 1.21405635
# Iteration 466, loss = 1.20269784
# Iteration 467, loss = 1.19143718
# Iteration 468, loss = 1.18027393
# Iteration 469, loss = 1.16920764
# Iteration 470, loss = 1.15823787
# Iteration 471, loss = 1.14736415
# Iteration 472, loss = 1.13658603
# Iteration 473, loss = 1.12590307
# Iteration 474, loss = 1.11531479
# Iteration 475, loss = 1.10482074
# Iteration 476, loss = 1.09442045
# Iteration 477, loss = 1.08411345
# Iteration 478, loss = 1.07389928
# Iteration 479, loss = 1.06377746
# Iteration 480, loss = 1.05374753
# Iteration 481, loss = 1.04380900
# Iteration 482, loss = 1.03396140
# Iteration 483, loss = 1.02420424
# Iteration 484, loss = 1.01453706
# Iteration 485, loss = 1.00495936
# Iteration 486, loss = 0.99547065
# Iteration 487, loss = 0.98607046
# Iteration 488, loss = 0.97675829
# Iteration 489, loss = 0.96753366
# Iteration 490, loss = 0.95839606
# Iteration 491, loss = 0.94934501
# Iteration 492, loss = 0.94038002
# Iteration 493, loss = 0.93150058
# Iteration 494, loss = 0.92270620
# Iteration 495, loss = 0.91399638
# Iteration 496, loss = 0.90537062
# Iteration 497, loss = 0.89682842
# Iteration 498, loss = 0.88836927
# Iteration 499, loss = 0.87999268
# Iteration 500, loss = 0.87169813
# Iteration 501, loss = 0.86348512
# Iteration 502, loss = 0.85535315
# Iteration 503, loss = 0.84730498
# Iteration 504, loss = 0.83934038
# Iteration 505, loss = 0.83145566
# Iteration 506, loss = 0.82365028
# Iteration 507, loss = 0.81592367
# Iteration 508, loss = 0.80827528
# Iteration 509, loss = 0.80070457
# Iteration 510, loss = 0.79321099
# Iteration 511, loss = 0.78579401
# Iteration 512, loss = 0.77845308
# Iteration 513, loss = 0.77118767
# Iteration 514, loss = 0.76399725
# Iteration 515, loss = 0.75688128
# Iteration 516, loss = 0.74983924
# Iteration 517, loss = 0.74287058
# Iteration 518, loss = 0.73597480
# Iteration 519, loss = 0.72915136
# Iteration 520, loss = 0.72239975
# Iteration 521, loss = 0.71571942
# Iteration 522, loss = 0.70910987
# Iteration 523, loss = 0.70257058
# Iteration 524, loss = 0.69610102
# Iteration 525, loss = 0.68970068
# Iteration 526, loss = 0.68336903
# Iteration 527, loss = 0.67710557
# Iteration 528, loss = 0.67090978
# Iteration 529, loss = 0.66478114
# Iteration 530, loss = 0.65871914
# Iteration 531, loss = 0.65272327
# Iteration 532, loss = 0.64679301
# Iteration 533, loss = 0.64092786
# Iteration 534, loss = 0.63512731
# Iteration 535, loss = 0.62939084
# Iteration 536, loss = 0.62371796
# Iteration 537, loss = 0.61810815
# Iteration 538, loss = 0.61256091
# Iteration 539, loss = 0.60707574
# Iteration 540, loss = 0.60165214
# Iteration 541, loss = 0.59628959
# Iteration 542, loss = 0.59098761
# Iteration 543, loss = 0.58574569
# Iteration 544, loss = 0.58056333
# Iteration 545, loss = 0.57544005
# Iteration 546, loss = 0.57037534
# Iteration 547, loss = 0.56536870
# Iteration 548, loss = 0.56041966
# Iteration 549, loss = 0.55552771
# Iteration 550, loss = 0.55069237
# Iteration 551, loss = 0.54591315
# Iteration 552, loss = 0.54118956
# Iteration 553, loss = 0.53652111
# Iteration 554, loss = 0.53190733
# Iteration 555, loss = 0.52734773
# Iteration 556, loss = 0.52284184
# Iteration 557, loss = 0.51838917
# Iteration 558, loss = 0.51398924
# Iteration 559, loss = 0.50964158
# Iteration 560, loss = 0.50534573
# Iteration 561, loss = 0.50110120
# Iteration 562, loss = 0.49690752
# Iteration 563, loss = 0.49276424
# Iteration 564, loss = 0.48867088
# Iteration 565, loss = 0.48462697
# Iteration 566, loss = 0.48063207
# Iteration 567, loss = 0.47668570
# Iteration 568, loss = 0.47278741
# Iteration 569, loss = 0.46893674
# Iteration 570, loss = 0.46513325
# Iteration 571, loss = 0.46137646
# Iteration 572, loss = 0.45766595
# Iteration 573, loss = 0.45400125
# Iteration 574, loss = 0.45038193
# Iteration 575, loss = 0.44680754
# Iteration 576, loss = 0.44327763
# Iteration 577, loss = 0.43979177
# Iteration 578, loss = 0.43634953
# Iteration 579, loss = 0.43295046
# Iteration 580, loss = 0.42959414
# Iteration 581, loss = 0.42628014
# Iteration 582, loss = 0.42300802
# Iteration 583, loss = 0.41977736
# Iteration 584, loss = 0.41658775
# Iteration 585, loss = 0.41343875
# Iteration 586, loss = 0.41032995
# Iteration 587, loss = 0.40726094
# Iteration 588, loss = 0.40423130
# Iteration 589, loss = 0.40124062
# Iteration 590, loss = 0.39828849
# Iteration 591, loss = 0.39537450
# Iteration 592, loss = 0.39249826
# Iteration 593, loss = 0.38965935
# Iteration 594, loss = 0.38685739
# Iteration 595, loss = 0.38409198
# Iteration 596, loss = 0.38136272
# Iteration 597, loss = 0.37866921
# Iteration 598, loss = 0.37601109
# Iteration 599, loss = 0.37338794
# Iteration 600, loss = 0.37079941
# Iteration 601, loss = 0.36824509
# Iteration 602, loss = 0.36572462
# Iteration 603, loss = 0.36323762
# Iteration 604, loss = 0.36078371
# Iteration 605, loss = 0.35836254
# Iteration 606, loss = 0.35597371
# Iteration 607, loss = 0.35361689
# Iteration 608, loss = 0.35129169
# Iteration 609, loss = 0.34899777
# Iteration 610, loss = 0.34673476
# Iteration 611, loss = 0.34450230
# Iteration 612, loss = 0.34230006
# Iteration 613, loss = 0.34012768
# Iteration 614, loss = 0.33798480
# Iteration 615, loss = 0.33587110
# Iteration 616, loss = 0.33378622
# Iteration 617, loss = 0.33172983
# Iteration 618, loss = 0.32970160
# Iteration 619, loss = 0.32770118
# Iteration 620, loss = 0.32572826
# Iteration 621, loss = 0.32378249
# Iteration 622, loss = 0.32186357
# Iteration 623, loss = 0.31997115
# Iteration 624, loss = 0.31810494
# Iteration 625, loss = 0.31626459
# Iteration 626, loss = 0.31444982
# Iteration 627, loss = 0.31266029
# Iteration 628, loss = 0.31089571
# Iteration 629, loss = 0.30915576
# Iteration 630, loss = 0.30744014
# Iteration 631, loss = 0.30574856
# Iteration 632, loss = 0.30408070
# Iteration 633, loss = 0.30243629
# Iteration 634, loss = 0.30081502
# Iteration 635, loss = 0.29921660
# Iteration 636, loss = 0.29764074
# Iteration 637, loss = 0.29608717
# Iteration 638, loss = 0.29455560
# Iteration 639, loss = 0.29304574
# Iteration 640, loss = 0.29155732
# Iteration 641, loss = 0.29009007
# Iteration 642, loss = 0.28864371
# Iteration 643, loss = 0.28721797
# Iteration 644, loss = 0.28581259
# Iteration 645, loss = 0.28442730
# Iteration 646, loss = 0.28306185
# Iteration 647, loss = 0.28171596
# Iteration 648, loss = 0.28038939
# Iteration 649, loss = 0.27908187
# Iteration 650, loss = 0.27779317
# Iteration 651, loss = 0.27652302
# Iteration 652, loss = 0.27527118
# Iteration 653, loss = 0.27403741
# Iteration 654, loss = 0.27282147
# Iteration 655, loss = 0.27162311
# Iteration 656, loss = 0.27044210
# Iteration 657, loss = 0.26927821
# Iteration 658, loss = 0.26813120
# Iteration 659, loss = 0.26700084
# Iteration 660, loss = 0.26588691
# Iteration 661, loss = 0.26478918
# Iteration 662, loss = 0.26370743
# Iteration 663, loss = 0.26264144
# Iteration 664, loss = 0.26159099
# Iteration 665, loss = 0.26055587
# Iteration 666, loss = 0.25953586
# Iteration 667, loss = 0.25853076
# Iteration 668, loss = 0.25754034
# Iteration 669, loss = 0.25656442
# Iteration 670, loss = 0.25560278
# Iteration 671, loss = 0.25465522
# Iteration 672, loss = 0.25372155
# Iteration 673, loss = 0.25280156
# Iteration 674, loss = 0.25189507
# Iteration 675, loss = 0.25100188
# Iteration 676, loss = 0.25012179
# Iteration 677, loss = 0.24925463
# Iteration 678, loss = 0.24840020
# Iteration 679, loss = 0.24755833
# Iteration 680, loss = 0.24672882
# Iteration 681, loss = 0.24591151
# Iteration 682, loss = 0.24510620
# Iteration 683, loss = 0.24431274
# Iteration 684, loss = 0.24353094
# Iteration 685, loss = 0.24276063
# Iteration 686, loss = 0.24200164
# Iteration 687, loss = 0.24125382
# Iteration 688, loss = 0.24051698
# Iteration 689, loss = 0.23979097
# Iteration 690, loss = 0.23907563
# Iteration 691, loss = 0.23837080
# Iteration 692, loss = 0.23767632
# Iteration 693, loss = 0.23699204
# Iteration 694, loss = 0.23631779
# Iteration 695, loss = 0.23565344
# Iteration 696, loss = 0.23499883
# Iteration 697, loss = 0.23435382
# Iteration 698, loss = 0.23371825
# Iteration 699, loss = 0.23309199
# Iteration 700, loss = 0.23247489
# Iteration 701, loss = 0.23186681
# Iteration 702, loss = 0.23126761
# Iteration 703, loss = 0.23067716
# Iteration 704, loss = 0.23009532
# Iteration 705, loss = 0.22952196
# Iteration 706, loss = 0.22895695
# Iteration 707, loss = 0.22840015
# Iteration 708, loss = 0.22785144
# Iteration 709, loss = 0.22731070
# Iteration 710, loss = 0.22677779
# Iteration 711, loss = 0.22625260
# Iteration 712, loss = 0.22573500
# Iteration 713, loss = 0.22522488
# Iteration 714, loss = 0.22472211
# Iteration 715, loss = 0.22422658
# Iteration 716, loss = 0.22373817
# Iteration 717, loss = 0.22325678
# Iteration 718, loss = 0.22278228
# Iteration 719, loss = 0.22231457
# Iteration 720, loss = 0.22185354
# Iteration 721, loss = 0.22139908
# Iteration 722, loss = 0.22095109
# Iteration 723, loss = 0.22050945
# Iteration 724, loss = 0.22007408
# Iteration 725, loss = 0.21964487
# Iteration 726, loss = 0.21922171
# Iteration 727, loss = 0.21880451
# Iteration 728, loss = 0.21839317
# Iteration 729, loss = 0.21798759
# Iteration 730, loss = 0.21758769
# Iteration 731, loss = 0.21719336
# Iteration 732, loss = 0.21680452
# Iteration 733, loss = 0.21642107
# Iteration 734, loss = 0.21604292
# Iteration 735, loss = 0.21567000
# Iteration 736, loss = 0.21530220
# Iteration 737, loss = 0.21493945
# Iteration 738, loss = 0.21458166
# Iteration 739, loss = 0.21422875
# Iteration 740, loss = 0.21388063
# Iteration 741, loss = 0.21353723
# Iteration 742, loss = 0.21319847
# Iteration 743, loss = 0.21286426
# Iteration 744, loss = 0.21253453
# Iteration 745, loss = 0.21220921
# Iteration 746, loss = 0.21188822
# Iteration 747, loss = 0.21157149
# Iteration 748, loss = 0.21125894
# Iteration 749, loss = 0.21095050
# Iteration 750, loss = 0.21064610
# Iteration 751, loss = 0.21034567
# Iteration 752, loss = 0.21004915
# Iteration 753, loss = 0.20975647
# Iteration 754, loss = 0.20946756
# Iteration 755, loss = 0.20918235
# Iteration 756, loss = 0.20890079
# Iteration 757, loss = 0.20862287
# Iteration 758, loss = 0.20834874
# Iteration 759, loss = 0.20807807
# Iteration 760, loss = 0.20781083
# Iteration 761, loss = 0.20754693
# Iteration 762, loss = 0.20728633
# Iteration 763, loss = 0.20702895
# Iteration 764, loss = 0.20677475
# Iteration 765, loss = 0.20652367
# Iteration 766, loss = 0.20627565
# Iteration 767, loss = 0.20603063
# Iteration 768, loss = 0.20578856
# Iteration 769, loss = 0.20554938
# Iteration 770, loss = 0.20531305
# Iteration 771, loss = 0.20507952
# Iteration 772, loss = 0.20484872
# Iteration 773, loss = 0.20462062
# Iteration 774, loss = 0.20439516
# Iteration 775, loss = 0.20417230
# Iteration 776, loss = 0.20395199
# Iteration 777, loss = 0.20373418
# Iteration 778, loss = 0.20351883
# Iteration 779, loss = 0.20330589
# Iteration 780, loss = 0.20309532
# Iteration 781, loss = 0.20288707
# Iteration 782, loss = 0.20268111
# Iteration 783, loss = 0.20247738
# Iteration 784, loss = 0.20227586
# Iteration 785, loss = 0.20207650
# Iteration 786, loss = 0.20187925
# Iteration 787, loss = 0.20168409
# Iteration 788, loss = 0.20149097
# Iteration 789, loss = 0.20129986
# Iteration 790, loss = 0.20111071
# Iteration 791, loss = 0.20092349
# Iteration 792, loss = 0.20073817
# Iteration 793, loss = 0.20055471
# Iteration 794, loss = 0.20037308
# Iteration 795, loss = 0.20019324
# Iteration 796, loss = 0.20001516
# Iteration 797, loss = 0.19983880
# Iteration 798, loss = 0.19966414
# Iteration 799, loss = 0.19949114
# Iteration 800, loss = 0.19931977
# Iteration 801, loss = 0.19915000
# Iteration 802, loss = 0.19898180
# Iteration 803, loss = 0.19881515
# Iteration 804, loss = 0.19865000
# Iteration 805, loss = 0.19848634
# Iteration 806, loss = 0.19832413
# Iteration 807, loss = 0.19816335
# Iteration 808, loss = 0.19800397
# Iteration 809, loss = 0.19784597
# Iteration 810, loss = 0.19768931
# Iteration 811, loss = 0.19753398
# Iteration 812, loss = 0.19737994
# Iteration 813, loss = 0.19722718
# Iteration 814, loss = 0.19707566
# Iteration 815, loss = 0.19692537
# Iteration 816, loss = 0.19677628
# Iteration 817, loss = 0.19662837
# Iteration 818, loss = 0.19648161
# Iteration 819, loss = 0.19633599
# Iteration 820, loss = 0.19619148
# Iteration 821, loss = 0.19604805
# Iteration 822, loss = 0.19590570
# Iteration 823, loss = 0.19576439
# Iteration 824, loss = 0.19562412
# Iteration 825, loss = 0.19548485
# Iteration 826, loss = 0.19534657
# Iteration 827, loss = 0.19520926
# Iteration 828, loss = 0.19507289
# Iteration 829, loss = 0.19493747
# Iteration 830, loss = 0.19480295
# Iteration 831, loss = 0.19466933
# Iteration 832, loss = 0.19453659
# Iteration 833, loss = 0.19440471
# Iteration 834, loss = 0.19427368
# Iteration 835, loss = 0.19414347
# Iteration 836, loss = 0.19401408
# Iteration 837, loss = 0.19388548
# Iteration 838, loss = 0.19375766
# Iteration 839, loss = 0.19363060
# Iteration 840, loss = 0.19350430
# Iteration 841, loss = 0.19337873
# Iteration 842, loss = 0.19325388
# Iteration 843, loss = 0.19312974
# Iteration 844, loss = 0.19300629
# Iteration 845, loss = 0.19288352
# Iteration 846, loss = 0.19276141
# Iteration 847, loss = 0.19263996
# Iteration 848, loss = 0.19251914
# Iteration 849, loss = 0.19239895
# Iteration 850, loss = 0.19227938
# Iteration 851, loss = 0.19216041
# Iteration 852, loss = 0.19204202
# Iteration 853, loss = 0.19192422
# Iteration 854, loss = 0.19180698
# Iteration 855, loss = 0.19169030
# Iteration 856, loss = 0.19157416
# Iteration 857, loss = 0.19145855
# Iteration 858, loss = 0.19134347
# Iteration 859, loss = 0.19122890
# Iteration 860, loss = 0.19111483
# Iteration 861, loss = 0.19100267
# Iteration 862, loss = 0.19089157
# Iteration 863, loss = 0.19078106
# Iteration 864, loss = 0.19067112
# Iteration 865, loss = 0.19056173
# Iteration 866, loss = 0.19045287
# Iteration 867, loss = 0.19034452
# Iteration 868, loss = 0.19023666
# Iteration 869, loss = 0.19012928
# Iteration 870, loss = 0.19002237
# Iteration 871, loss = 0.18991590
# Iteration 872, loss = 0.18980987
# Iteration 873, loss = 0.18970427
# Iteration 874, loss = 0.18959907
# Iteration 875, loss = 0.18949428
# Iteration 876, loss = 0.18938987
# Iteration 877, loss = 0.18928584
# Iteration 878, loss = 0.18918218
# Iteration 879, loss = 0.18907888
# Iteration 880, loss = 0.18897593
# Iteration 881, loss = 0.18887332
# Iteration 882, loss = 0.18877104
# Iteration 883, loss = 0.18866909
# Iteration 884, loss = 0.18856745
# Iteration 885, loss = 0.18846612
# Iteration 886, loss = 0.18836509
# Iteration 887, loss = 0.18826436
# Iteration 888, loss = 0.18816392
# Iteration 889, loss = 0.18806376
# Iteration 890, loss = 0.18796387
# Iteration 891, loss = 0.18786425
# Iteration 892, loss = 0.18776490
# Iteration 893, loss = 0.18766580
# Iteration 894, loss = 0.18756695
# Iteration 895, loss = 0.18746835
# Iteration 896, loss = 0.18736999
# Iteration 897, loss = 0.18727187
# Iteration 898, loss = 0.18717416
# Iteration 899, loss = 0.18707674
# Iteration 900, loss = 0.18697956
# Iteration 901, loss = 0.18688261
# Iteration 902, loss = 0.18678588
# Iteration 903, loss = 0.18668937
# Iteration 904, loss = 0.18659308
# Iteration 905, loss = 0.18649699
# Iteration 906, loss = 0.18640111
# Iteration 907, loss = 0.18630543
# Iteration 908, loss = 0.18620993
# Iteration 909, loss = 0.18611463
# Iteration 910, loss = 0.18601951
# Iteration 911, loss = 0.18592456
# Iteration 912, loss = 0.18582979
# Iteration 913, loss = 0.18573520
# Iteration 914, loss = 0.18564077
# Iteration 915, loss = 0.18554650
# Iteration 916, loss = 0.18545239
# Iteration 917, loss = 0.18535844
# Iteration 918, loss = 0.18526465
# Iteration 919, loss = 0.18517100
# Iteration 920, loss = 0.18507750
# Iteration 921, loss = 0.18498414
# Iteration 922, loss = 0.18489092
# Iteration 923, loss = 0.18479784
# Iteration 924, loss = 0.18470489
# Iteration 925, loss = 0.18461207
# Iteration 926, loss = 0.18451938
# Iteration 927, loss = 0.18442682
# Iteration 928, loss = 0.18433439
# Iteration 929, loss = 0.18424207
# Iteration 930, loss = 0.18414987
# Iteration 931, loss = 0.18405779
# Iteration 932, loss = 0.18396582
# Iteration 933, loss = 0.18387397
# Iteration 934, loss = 0.18378222
# Iteration 935, loss = 0.18369059
# Iteration 936, loss = 0.18359905
# Iteration 937, loss = 0.18350762
# Iteration 938, loss = 0.18341630
# Iteration 939, loss = 0.18332507
# Iteration 940, loss = 0.18323394
# Iteration 941, loss = 0.18314290
# Iteration 942, loss = 0.18305196
# Iteration 943, loss = 0.18296111
# Iteration 944, loss = 0.18287035
# Iteration 945, loss = 0.18277968
# Iteration 946, loss = 0.18268910
# Iteration 947, loss = 0.18259860
# Iteration 948, loss = 0.18250819
# Iteration 949, loss = 0.18241786
# Iteration 950, loss = 0.18232761
# Iteration 951, loss = 0.18223744
# Iteration 952, loss = 0.18214735
# Iteration 953, loss = 0.18205734
# Iteration 954, loss = 0.18196740
# Iteration 955, loss = 0.18187754
# Iteration 956, loss = 0.18178774
# Iteration 957, loss = 0.18169802
# Iteration 958, loss = 0.18160837
# Iteration 959, loss = 0.18151879
# Iteration 960, loss = 0.18142928
# Iteration 961, loss = 0.18133984
# Iteration 962, loss = 0.18125046
# Iteration 963, loss = 0.18116114
# Iteration 964, loss = 0.18107189
# Iteration 965, loss = 0.18098271
# Iteration 966, loss = 0.18089358
# Iteration 967, loss = 0.18080452
# Iteration 968, loss = 0.18071551
# Iteration 969, loss = 0.18062657
# Iteration 970, loss = 0.18053768
# Iteration 971, loss = 0.18044885
# Iteration 972, loss = 0.18036007
# Iteration 973, loss = 0.18027135
# Iteration 974, loss = 0.18018269
# Iteration 975, loss = 0.18009408
# Iteration 976, loss = 0.18000552
# Iteration 977, loss = 0.17991701
# Iteration 978, loss = 0.17982856
# Iteration 979, loss = 0.17974016
# Iteration 980, loss = 0.17965180
# Iteration 981, loss = 0.17956350
# Iteration 982, loss = 0.17947525
# Iteration 983, loss = 0.17938704
# Iteration 984, loss = 0.17929888
# Iteration 985, loss = 0.17921077
# Iteration 986, loss = 0.17912270
# Iteration 987, loss = 0.17903468
# Iteration 988, loss = 0.17894671
# Iteration 989, loss = 0.17885878
# Iteration 990, loss = 0.17877089
# Iteration 991, loss = 0.17868305
# Iteration 992, loss = 0.17859525
# Iteration 993, loss = 0.17850750
# Iteration 994, loss = 0.17841978
# Iteration 995, loss = 0.17833211
# Iteration 996, loss = 0.17824448
# Iteration 997, loss = 0.17815689
# Iteration 998, loss = 0.17806934
# Iteration 999, loss = 0.17798182
# Iteration 1000, loss = 0.17789435
# Iteration 1001, loss = 0.17780692
# Iteration 1002, loss = 0.17771953
# Iteration 1003, loss = 0.17763217
# Iteration 1004, loss = 0.17754485
# Iteration 1005, loss = 0.17745757
# Iteration 1006, loss = 0.17737033
# Iteration 1007, loss = 0.17728313
# Iteration 1008, loss = 0.17719596
# Iteration 1009, loss = 0.17710882
# Iteration 1010, loss = 0.17702173
# Iteration 1011, loss = 0.17693467
# Iteration 1012, loss = 0.17684764
# Iteration 1013, loss = 0.17676065
# Iteration 1014, loss = 0.17667370
# Iteration 1015, loss = 0.17658677
# Iteration 1016, loss = 0.17649989
# Iteration 1017, loss = 0.17641304
# Iteration 1018, loss = 0.17632622
# Iteration 1019, loss = 0.17623943
# Iteration 1020, loss = 0.17615268
# Iteration 1021, loss = 0.17606596
# Iteration 1022, loss = 0.17597928
# Iteration 1023, loss = 0.17589262
# Iteration 1024, loss = 0.17580601
# Iteration 1025, loss = 0.17571942
# Iteration 1026, loss = 0.17563286
# Iteration 1027, loss = 0.17554634
# Iteration 1028, loss = 0.17545985
# Iteration 1029, loss = 0.17537339
# Iteration 1030, loss = 0.17528696
# Iteration 1031, loss = 0.17520057
# Iteration 1032, loss = 0.17511420
# Iteration 1033, loss = 0.17502787
# Iteration 1034, loss = 0.17494156
# Iteration 1035, loss = 0.17485529
# Iteration 1036, loss = 0.17476905
# Iteration 1037, loss = 0.17468284
# Iteration 1038, loss = 0.17459666
# Iteration 1039, loss = 0.17451051
# Iteration 1040, loss = 0.17442439
# Iteration 1041, loss = 0.17433830
# Iteration 1042, loss = 0.17425224
# Iteration 1043, loss = 0.17416622
# Iteration 1044, loss = 0.17408022
# Iteration 1045, loss = 0.17399425
# Iteration 1046, loss = 0.17390831
# Iteration 1047, loss = 0.17382240
# Iteration 1048, loss = 0.17373652
# Iteration 1049, loss = 0.17365067
# Iteration 1050, loss = 0.17356485
# Iteration 1051, loss = 0.17347906
# Iteration 1052, loss = 0.17339330
# Iteration 1053, loss = 0.17330756
# Iteration 1054, loss = 0.17322186
# Iteration 1055, loss = 0.17313619
# Iteration 1056, loss = 0.17305054
# Iteration 1057, loss = 0.17296493
# Iteration 1058, loss = 0.17287934
# Iteration 1059, loss = 0.17279378
# Iteration 1060, loss = 0.17270825
# Iteration 1061, loss = 0.17262276
# Iteration 1062, loss = 0.17253729
# Iteration 1063, loss = 0.17245184
# Iteration 1064, loss = 0.17236643
# Iteration 1065, loss = 0.17228105
# Iteration 1066, loss = 0.17219569
# Iteration 1067, loss = 0.17211037
# Iteration 1068, loss = 0.17202507
# Iteration 1069, loss = 0.17193980
# Iteration 1070, loss = 0.17185457
# Iteration 1071, loss = 0.17176936
# Iteration 1072, loss = 0.17168418
# Iteration 1073, loss = 0.17159902
# Iteration 1074, loss = 0.17151390
# Iteration 1075, loss = 0.17142881
# Iteration 1076, loss = 0.17134374
# Iteration 1077, loss = 0.17125870
# Iteration 1078, loss = 0.17117368
# Iteration 1079, loss = 0.17108857
# Iteration 1080, loss = 0.17100349
# Iteration 1081, loss = 0.17091842
# Iteration 1082, loss = 0.17083337
# Iteration 1083, loss = 0.17074835
# Iteration 1084, loss = 0.17066334
# Iteration 1085, loss = 0.17057836
# Iteration 1086, loss = 0.17049341
# Iteration 1087, loss = 0.17040847
# Iteration 1088, loss = 0.17032356
# Iteration 1089, loss = 0.17023868
# Iteration 1090, loss = 0.17015382
# Iteration 1091, loss = 0.17006899
# Iteration 1092, loss = 0.16998418
# Iteration 1093, loss = 0.16989940
# Iteration 1094, loss = 0.16981464
# Iteration 1095, loss = 0.16972992
# Iteration 1096, loss = 0.16964522
# Iteration 1097, loss = 0.16956054
# Iteration 1098, loss = 0.16947590
# Iteration 1099, loss = 0.16939128
# Iteration 1100, loss = 0.16930670
# Iteration 1101, loss = 0.16922214
# Iteration 1102, loss = 0.16913761
# Iteration 1103, loss = 0.16905310
# Iteration 1104, loss = 0.16896863
# Iteration 1105, loss = 0.16888418
# Iteration 1106, loss = 0.16879977
# Iteration 1107, loss = 0.16871538
# Iteration 1108, loss = 0.16863102
# Iteration 1109, loss = 0.16854670
# Iteration 1110, loss = 0.16846240
# Iteration 1111, loss = 0.16837813
# Iteration 1112, loss = 0.16829389
# Iteration 1113, loss = 0.16820968
# Iteration 1114, loss = 0.16812550
# Iteration 1115, loss = 0.16804135
# Iteration 1116, loss = 0.16795723
# Iteration 1117, loss = 0.16787314
# Iteration 1118, loss = 0.16778908
# Iteration 1119, loss = 0.16770505
# Iteration 1120, loss = 0.16762105
# Iteration 1121, loss = 0.16753708
# Iteration 1122, loss = 0.16745314
# Iteration 1123, loss = 0.16736923
# Iteration 1124, loss = 0.16728535
# Iteration 1125, loss = 0.16720150
# Iteration 1126, loss = 0.16711769
# Iteration 1127, loss = 0.16703390
# Iteration 1128, loss = 0.16695015
# Iteration 1129, loss = 0.16686642
# Iteration 1130, loss = 0.16678273
# Iteration 1131, loss = 0.16669907
# Iteration 1132, loss = 0.16661543
# Iteration 1133, loss = 0.16653183
# Iteration 1134, loss = 0.16644826
# Iteration 1135, loss = 0.16636472
# Iteration 1136, loss = 0.16628122
# Iteration 1137, loss = 0.16619774
# Iteration 1138, loss = 0.16611430
# Iteration 1139, loss = 0.16603088
# Iteration 1140, loss = 0.16594750
# Iteration 1141, loss = 0.16586415
# Iteration 1142, loss = 0.16578083
# Iteration 1143, loss = 0.16569755
# Iteration 1144, loss = 0.16561429
# Iteration 1145, loss = 0.16553107
# Iteration 1146, loss = 0.16544788
# Iteration 1147, loss = 0.16536472
# Iteration 1148, loss = 0.16528159
# Iteration 1149, loss = 0.16519850
# Iteration 1150, loss = 0.16511543
# Iteration 1151, loss = 0.16503240
# Iteration 1152, loss = 0.16494940
# Iteration 1153, loss = 0.16486644
# Iteration 1154, loss = 0.16478350
# Iteration 1155, loss = 0.16470060
# Iteration 1156, loss = 0.16461773
# Iteration 1157, loss = 0.16453489
# Iteration 1158, loss = 0.16445209
# Iteration 1159, loss = 0.16436932
# Iteration 1160, loss = 0.16428658
# Iteration 1161, loss = 0.16420387
# Iteration 1162, loss = 0.16412120
# Iteration 1163, loss = 0.16403856
# Iteration 1164, loss = 0.16395595
# Iteration 1165, loss = 0.16387338
# Iteration 1166, loss = 0.16379084
# Iteration 1167, loss = 0.16370833
# Iteration 1168, loss = 0.16362585
# Iteration 1169, loss = 0.16354341
# Iteration 1170, loss = 0.16346100
# Iteration 1171, loss = 0.16337863
# Iteration 1172, loss = 0.16329629
# Iteration 1173, loss = 0.16321398
# Iteration 1174, loss = 0.16313170
# Iteration 1175, loss = 0.16304946
# Iteration 1176, loss = 0.16296726
# Iteration 1177, loss = 0.16288508
# Iteration 1178, loss = 0.16280294
# Iteration 1179, loss = 0.16272084
# Iteration 1180, loss = 0.16263877
# Iteration 1181, loss = 0.16255673
# Iteration 1182, loss = 0.16247473
# Iteration 1183, loss = 0.16239276
# Iteration 1184, loss = 0.16231082
# Iteration 1185, loss = 0.16222892
# Iteration 1186, loss = 0.16214706
# Iteration 1187, loss = 0.16206522
# Iteration 1188, loss = 0.16198343
# Iteration 1189, loss = 0.16190166
# Iteration 1190, loss = 0.16181994
# Iteration 1191, loss = 0.16173824
# Iteration 1192, loss = 0.16165658
# Iteration 1193, loss = 0.16157496
# Iteration 1194, loss = 0.16149337
# Iteration 1195, loss = 0.16141182
# Iteration 1196, loss = 0.16133030
# Iteration 1197, loss = 0.16124881
# Iteration 1198, loss = 0.16116736
# Iteration 1199, loss = 0.16108595
# Iteration 1200, loss = 0.16100457
# Iteration 1201, loss = 0.16092323
# Iteration 1202, loss = 0.16084192
# Iteration 1203, loss = 0.16076065
# Iteration 1204, loss = 0.16067941
# Iteration 1205, loss = 0.16059821
# Iteration 1206, loss = 0.16051704
# Iteration 1207, loss = 0.16043591
# Iteration 1208, loss = 0.16035482
# Iteration 1209, loss = 0.16027376
# Iteration 1210, loss = 0.16019273
# Iteration 1211, loss = 0.16011175
# Iteration 1212, loss = 0.16003079
# Iteration 1213, loss = 0.15994988
# Iteration 1214, loss = 0.15986900
# Iteration 1215, loss = 0.15978816
# Iteration 1216, loss = 0.15970735
# Iteration 1217, loss = 0.15962658
# Iteration 1218, loss = 0.15954585
# Iteration 1219, loss = 0.15946515
# Iteration 1220, loss = 0.15938449
# Iteration 1221, loss = 0.15930386
# Iteration 1222, loss = 0.15922327
# Iteration 1223, loss = 0.15914272
# Iteration 1224, loss = 0.15906221
# Iteration 1225, loss = 0.15898173
# Iteration 1226, loss = 0.15890129
# Iteration 1227, loss = 0.15882088
# Iteration 1228, loss = 0.15874051
# Iteration 1229, loss = 0.15866018
# Iteration 1230, loss = 0.15857989
# Iteration 1231, loss = 0.15849963
# Iteration 1232, loss = 0.15841941
# Iteration 1233, loss = 0.15833923
# Iteration 1234, loss = 0.15825909
# Iteration 1235, loss = 0.15817898
# Iteration 1236, loss = 0.15809891
# Iteration 1237, loss = 0.15801888
# Iteration 1238, loss = 0.15793888
# Iteration 1239, loss = 0.15785892
# Iteration 1240, loss = 0.15777901
# Iteration 1241, loss = 0.15769912
# Iteration 1242, loss = 0.15761928
# Iteration 1243, loss = 0.15753947
# Iteration 1244, loss = 0.15745970
# Iteration 1245, loss = 0.15737997
# Iteration 1246, loss = 0.15730028
# Iteration 1247, loss = 0.15722063
# Iteration 1248, loss = 0.15714101
# Iteration 1249, loss = 0.15706143
# Iteration 1250, loss = 0.15698189
# Iteration 1251, loss = 0.15690239
# Iteration 1252, loss = 0.15682293
# Iteration 1253, loss = 0.15674350
# Iteration 1254, loss = 0.15666411
# Iteration 1255, loss = 0.15658477
# Iteration 1256, loss = 0.15650546
# Iteration 1257, loss = 0.15642619
# Iteration 1258, loss = 0.15634695
# Iteration 1259, loss = 0.15626776
# Iteration 1260, loss = 0.15618861
# Iteration 1261, loss = 0.15610949
# Iteration 1262, loss = 0.15603041
# Iteration 1263, loss = 0.15595138
# Iteration 1264, loss = 0.15587238
# Iteration 1265, loss = 0.15579342
# Iteration 1266, loss = 0.15571450
# Iteration 1267, loss = 0.15563562
# Iteration 1268, loss = 0.15555678
# Iteration 1269, loss = 0.15547797
# Iteration 1270, loss = 0.15539921
# Iteration 1271, loss = 0.15532049
# Iteration 1272, loss = 0.15524180
# Iteration 1273, loss = 0.15516316
# Iteration 1274, loss = 0.15508455
# Iteration 1275, loss = 0.15500599
# Iteration 1276, loss = 0.15492746
# Iteration 1277, loss = 0.15484897
# Iteration 1278, loss = 0.15477053
# Iteration 1279, loss = 0.15469212
# Iteration 1280, loss = 0.15461375
# Iteration 1281, loss = 0.15453543
# Iteration 1282, loss = 0.15445714
# Iteration 1283, loss = 0.15437890
# Iteration 1284, loss = 0.15430069
# Iteration 1285, loss = 0.15422252
# Iteration 1286, loss = 0.15414440
# Iteration 1287, loss = 0.15406631
# Iteration 1288, loss = 0.15398827
# Iteration 1289, loss = 0.15391026
# Iteration 1290, loss = 0.15383230
# Iteration 1291, loss = 0.15375437
# Iteration 1292, loss = 0.15367649
# Iteration 1293, loss = 0.15359865
# Iteration 1294, loss = 0.15352085
# Iteration 1295, loss = 0.15344309
# Iteration 1296, loss = 0.15336537
# Iteration 1297, loss = 0.15328769
# Iteration 1298, loss = 0.15321005
# Iteration 1299, loss = 0.15313245
# Iteration 1300, loss = 0.15305489
# Iteration 1301, loss = 0.15297738
# Iteration 1302, loss = 0.15289990
# Iteration 1303, loss = 0.15282247
# Iteration 1304, loss = 0.15274508
# Iteration 1305, loss = 0.15266773
# Iteration 1306, loss = 0.15259042
# Iteration 1307, loss = 0.15251315
# Iteration 1308, loss = 0.15243573
# Iteration 1309, loss = 0.15235831
# Iteration 1310, loss = 0.15228091
# Iteration 1311, loss = 0.15220353
# Iteration 1312, loss = 0.15212618
# Iteration 1313, loss = 0.15204886
# Iteration 1314, loss = 0.15197156
# Iteration 1315, loss = 0.15189429
# Iteration 1316, loss = 0.15181706
# Iteration 1317, loss = 0.15173985
# Iteration 1318, loss = 0.15166268
# Iteration 1319, loss = 0.15158554
# Iteration 1320, loss = 0.15150844
# Iteration 1321, loss = 0.15143137
# Iteration 1322, loss = 0.15135435
# Iteration 1323, loss = 0.15127735
# Iteration 1324, loss = 0.15120040
# Iteration 1325, loss = 0.15112348
# Iteration 1326, loss = 0.15104661
# Iteration 1327, loss = 0.15096977
# Iteration 1328, loss = 0.15089297
# Iteration 1329, loss = 0.15081621
# Iteration 1330, loss = 0.15073949
# Iteration 1331, loss = 0.15066282
# Iteration 1332, loss = 0.15058618
# Iteration 1333, loss = 0.15050959
# Iteration 1334, loss = 0.15043304
# Iteration 1335, loss = 0.15035653
# Iteration 1336, loss = 0.15028006
# Iteration 1337, loss = 0.15020363
# Iteration 1338, loss = 0.15012725
# Iteration 1339, loss = 0.15005184
# Iteration 1340, loss = 0.14997683
# Iteration 1341, loss = 0.14990194
# Iteration 1342, loss = 0.14982714
# Iteration 1343, loss = 0.14975244
# Iteration 1344, loss = 0.14967783
# Iteration 1345, loss = 0.14960331
# Iteration 1346, loss = 0.14952886
# Iteration 1347, loss = 0.14945450
# Iteration 1348, loss = 0.14938020
# Iteration 1349, loss = 0.14930598
# Iteration 1350, loss = 0.14923182
# Iteration 1351, loss = 0.14915773
# Iteration 1352, loss = 0.14908371
# Iteration 1353, loss = 0.14900974
# Iteration 1354, loss = 0.14893583
# Iteration 1355, loss = 0.14886198
# Iteration 1356, loss = 0.14878819
# Iteration 1357, loss = 0.14871445
# Iteration 1358, loss = 0.14864077
# Iteration 1359, loss = 0.14856714
# Iteration 1360, loss = 0.14849356
# Iteration 1361, loss = 0.14842003
# Iteration 1362, loss = 0.14834655
# Iteration 1363, loss = 0.14827312
# Iteration 1364, loss = 0.14819974
# Iteration 1365, loss = 0.14812640
# Iteration 1366, loss = 0.14805312
# Iteration 1367, loss = 0.14797988
# Iteration 1368, loss = 0.14790669
# Iteration 1369, loss = 0.14783355
# Iteration 1370, loss = 0.14776045
# Iteration 1371, loss = 0.14768740
# Iteration 1372, loss = 0.14761439
# Iteration 1373, loss = 0.14754143
# Iteration 1374, loss = 0.14746852
# Iteration 1375, loss = 0.14739565
# Iteration 1376, loss = 0.14732282
# Iteration 1377, loss = 0.14725004
# Iteration 1378, loss = 0.14717731
# Iteration 1379, loss = 0.14710462
# Iteration 1380, loss = 0.14703198
# Iteration 1381, loss = 0.14695938
# Iteration 1382, loss = 0.14688682
# Iteration 1383, loss = 0.14681431
# Iteration 1384, loss = 0.14674184
# Iteration 1385, loss = 0.14666942
# Iteration 1386, loss = 0.14659704
# Iteration 1387, loss = 0.14652471
# Iteration 1388, loss = 0.14645242
# Iteration 1389, loss = 0.14638018
# Iteration 1390, loss = 0.14630798
# Iteration 1391, loss = 0.14623582
# Iteration 1392, loss = 0.14616371
# Iteration 1393, loss = 0.14609165
# Iteration 1394, loss = 0.14601962
# Iteration 1395, loss = 0.14594765
# Iteration 1396, loss = 0.14587572
# Iteration 1397, loss = 0.14580383
# Iteration 1398, loss = 0.14573198
# Iteration 1399, loss = 0.14566018
# Iteration 1400, loss = 0.14558843
# Iteration 1401, loss = 0.14551672
# Iteration 1402, loss = 0.14544506
# Iteration 1403, loss = 0.14537344
# Iteration 1404, loss = 0.14530186
# Iteration 1405, loss = 0.14523033
# Iteration 1406, loss = 0.14515884
# Iteration 1407, loss = 0.14508740
# Iteration 1408, loss = 0.14501601
# Iteration 1409, loss = 0.14494466
# Iteration 1410, loss = 0.14487335
# Iteration 1411, loss = 0.14480209
# Iteration 1412, loss = 0.14473087
# Iteration 1413, loss = 0.14465970
# Iteration 1414, loss = 0.14458858
# Iteration 1415, loss = 0.14451749
# Iteration 1416, loss = 0.14444646
# Iteration 1417, loss = 0.14437547
# Iteration 1418, loss = 0.14430452
# Iteration 1419, loss = 0.14423362
# Iteration 1420, loss = 0.14416277
# Iteration 1421, loss = 0.14409196
# Iteration 1422, loss = 0.14402120
# Iteration 1423, loss = 0.14395048
# Iteration 1424, loss = 0.14387980
# Iteration 1425, loss = 0.14380926
# Iteration 1426, loss = 0.14373974
# Iteration 1427, loss = 0.14367028
# Iteration 1428, loss = 0.14360086
# Iteration 1429, loss = 0.14353148
# Iteration 1430, loss = 0.14346215
# Iteration 1431, loss = 0.14339286
# Iteration 1432, loss = 0.14332362
# Iteration 1433, loss = 0.14325443
# Iteration 1434, loss = 0.14318528
# Iteration 1435, loss = 0.14311617
# Iteration 1436, loss = 0.14304711
# Iteration 1437, loss = 0.14297810
# Iteration 1438, loss = 0.14290913
# Iteration 1439, loss = 0.14284021
# ...
# Iteration 2327, loss = 0.10148826
# Iteration 2328, loss = 0.10146320
# Iteration 2329, loss = 0.10143818
# Iteration 2330, loss = 0.10141320
# Iteration 2331, loss = 0.10138827
# Iteration 2332, loss = 0.10136337
# Iteration 2333, loss = 0.10133852
# Iteration 2334, loss = 0.10131371
# Iteration 2335, loss = 0.10128895
# Iteration 2336, loss = 0.10126422
# Iteration 2337, loss = 0.10123954
# Iteration 2338, loss = 0.10121489
# Iteration 2339, loss = 0.10119029
# Iteration 2340, loss = 0.10116573
# Iteration 2341, loss = 0.10114122
# Iteration 2342, loss = 0.10111674
# Iteration 2343, loss = 0.10109231
# Iteration 2344, loss = 0.10106791
# Iteration 2345, loss = 0.10104356
# Iteration 2346, loss = 0.10101925
# Iteration 2347, loss = 0.10099498
# Iteration 2348, loss = 0.10097075
# Iteration 2349, loss = 0.10094657
# Iteration 2350, loss = 0.10092242
# Iteration 2351, loss = 0.10089832
# Iteration 2352, loss = 0.10087425
# Iteration 2353, loss = 0.10085023
# Iteration 2354, loss = 0.10082625
# Iteration 2355, loss = 0.10080231
# Iteration 2356, loss = 0.10077841
# Iteration 2357, loss = 0.10075456
# Iteration 2358, loss = 0.10073074
# Iteration 2359, loss = 0.10070696
# Iteration 2360, loss = 0.10068323
# Iteration 2361, loss = 0.10065953
# Iteration 2362, loss = 0.10063588
# Iteration 2363, loss = 0.10061227
# Iteration 2364, loss = 0.10058870
# Iteration 2365, loss = 0.10056517
# Iteration 2366, loss = 0.10054168
# Iteration 2367, loss = 0.10051823
# Iteration 2368, loss = 0.10049482
# Iteration 2369, loss = 0.10047145
# Iteration 2370, loss = 0.10044812
# Iteration 2371, loss = 0.10042483
# Iteration 2372, loss = 0.10040159
# Iteration 2373, loss = 0.10037838
# Iteration 2374, loss = 0.10035521
# Iteration 2375, loss = 0.10033209
# Iteration 2376, loss = 0.10030900
# Iteration 2377, loss = 0.10028596
# Iteration 2378, loss = 0.10026295
# Iteration 2379, loss = 0.10023999
# Iteration 2380, loss = 0.10021706
# Iteration 2381, loss = 0.10019418
# Iteration 2382, loss = 0.10017133
# Iteration 2383, loss = 0.10014853
# Iteration 2384, loss = 0.10012576
# Iteration 2385, loss = 0.10010304
# Iteration 2386, loss = 0.10008035
# Iteration 2387, loss = 0.10005771
# Iteration 2388, loss = 0.10003510
# Iteration 2389, loss = 0.10001254
# Iteration 2390, loss = 0.09999001
# Iteration 2391, loss = 0.09996753
# Iteration 2392, loss = 0.09994508
# Iteration 2393, loss = 0.09992268
# Iteration 2394, loss = 0.09990031
# Iteration 2395, loss = 0.09987798
# Iteration 2396, loss = 0.09985569
# Iteration 2397, loss = 0.09983345
# Iteration 2398, loss = 0.09981124
# Iteration 2399, loss = 0.09978907
# Iteration 2400, loss = 0.09976694
# Iteration 2401, loss = 0.09974485
# Iteration 2402, loss = 0.09972280
# Iteration 2403, loss = 0.09970079
# Iteration 2404, loss = 0.09967882
# Iteration 2405, loss = 0.09965688
# Iteration 2406, loss = 0.09963499
# Iteration 2407, loss = 0.09961314
# Iteration 2408, loss = 0.09959132
# Iteration 2409, loss = 0.09956954
# Iteration 2410, loss = 0.09954781
# Iteration 2411, loss = 0.09952611
# Iteration 2412, loss = 0.09950445
# Iteration 2413, loss = 0.09948283
# Iteration 2414, loss = 0.09946125
# Iteration 2415, loss = 0.09943970
# Iteration 2416, loss = 0.09941820
# Iteration 2417, loss = 0.09939674
# Iteration 2418, loss = 0.09937531
# Iteration 2419, loss = 0.09935392
# Iteration 2420, loss = 0.09933257
# Iteration 2421, loss = 0.09931126
# Iteration 2422, loss = 0.09928999
# Iteration 2423, loss = 0.09926876
# Iteration 2424, loss = 0.09924756
# Iteration 2425, loss = 0.09922641
# Iteration 2426, loss = 0.09920529
# Iteration 2427, loss = 0.09918421
# Iteration 2428, loss = 0.09916317
# Iteration 2429, loss = 0.09914217
# Iteration 2430, loss = 0.09912120
# Iteration 2431, loss = 0.09910028
# Iteration 2432, loss = 0.09907939
# Iteration 2433, loss = 0.09905854
# Iteration 2434, loss = 0.09903773
# Iteration 2435, loss = 0.09901695
# Iteration 2436, loss = 0.09899622
# Iteration 2437, loss = 0.09897552
# Iteration 2438, loss = 0.09895486
# Iteration 2439, loss = 0.09893424
# Iteration 2440, loss = 0.09891366
# Iteration 2441, loss = 0.09889311
# Iteration 2442, loss = 0.09887260
# Iteration 2443, loss = 0.09885213
# Iteration 2444, loss = 0.09883170
# Iteration 2445, loss = 0.09881131
# Iteration 2446, loss = 0.09879095
# Iteration 2447, loss = 0.09877063
# Iteration 2448, loss = 0.09875035
# Iteration 2449, loss = 0.09873010
# Iteration 2450, loss = 0.09870990
# Iteration 2451, loss = 0.09868973
# Iteration 2452, loss = 0.09866960
# Iteration 2453, loss = 0.09864950
# Iteration 2454, loss = 0.09862944
# Iteration 2455, loss = 0.09860942
# Iteration 2456, loss = 0.09858944
# Iteration 2457, loss = 0.09856950
# Iteration 2458, loss = 0.09854959
# Iteration 2459, loss = 0.09852972
# Iteration 2460, loss = 0.09850988
# Iteration 2461, loss = 0.09849009
# Iteration 2462, loss = 0.09847033
# Iteration 2463, loss = 0.09845061
# Iteration 2464, loss = 0.09843092
# Iteration 2465, loss = 0.09841127
# Iteration 2466, loss = 0.09839166
# Iteration 2467, loss = 0.09837209
# Iteration 2468, loss = 0.09835255
# Iteration 2469, loss = 0.09833305
# Iteration 2470, loss = 0.09831358
# Iteration 2471, loss = 0.09829415
# Iteration 2472, loss = 0.09827476
# Iteration 2473, loss = 0.09825541
# Iteration 2474, loss = 0.09823609
# Iteration 2475, loss = 0.09821681
# Iteration 2476, loss = 0.09819756
# Iteration 2477, loss = 0.09817835
# Iteration 2478, loss = 0.09815918
# Iteration 2479, loss = 0.09814005
# Iteration 2480, loss = 0.09812095
# Iteration 2481, loss = 0.09810188
# Iteration 2482, loss = 0.09808286
# Iteration 2483, loss = 0.09806387
# Iteration 2484, loss = 0.09804491
# Iteration 2485, loss = 0.09802599
# Iteration 2486, loss = 0.09800711
# Iteration 2487, loss = 0.09798826
# Iteration 2488, loss = 0.09796945
# Iteration 2489, loss = 0.09795068
# Iteration 2490, loss = 0.09793194
# Iteration 2491, loss = 0.09791324
# Iteration 2492, loss = 0.09789457
# Iteration 2493, loss = 0.09787594
# Iteration 2494, loss = 0.09785735
# Iteration 2495, loss = 0.09783879
# Iteration 2496, loss = 0.09782026
# Iteration 2497, loss = 0.09780178
# Iteration 2498, loss = 0.09778332
# Iteration 2499, loss = 0.09776491
# Iteration 2500, loss = 0.09774653
# Iteration 2501, loss = 0.09772818
# Iteration 2502, loss = 0.09770987
# Iteration 2503, loss = 0.09769160
# Iteration 2504, loss = 0.09767336
# Iteration 2505, loss = 0.09765515
# Iteration 2506, loss = 0.09763698
# Iteration 2507, loss = 0.09761885
# Iteration 2508, loss = 0.09760075
# Iteration 2509, loss = 0.09758269
# Iteration 2510, loss = 0.09756466
# Iteration 2511, loss = 0.09754667
# Iteration 2512, loss = 0.09752871
# Iteration 2513, loss = 0.09751079
# Iteration 2514, loss = 0.09749290
# Iteration 2515, loss = 0.09747505
# Iteration 2516, loss = 0.09745723
# Iteration 2517, loss = 0.09743945
# Iteration 2518, loss = 0.09742170
# Iteration 2519, loss = 0.09740398
# Iteration 2520, loss = 0.09738631
# Iteration 2521, loss = 0.09736866
# Iteration 2522, loss = 0.09735105
# Iteration 2523, loss = 0.09733348
# Iteration 2524, loss = 0.09731594
# Iteration 2525, loss = 0.09729843
# Iteration 2526, loss = 0.09728096
# Iteration 2527, loss = 0.09726352
# Iteration 2528, loss = 0.09724612
# Iteration 2529, loss = 0.09722875
# Iteration 2530, loss = 0.09721142
# Iteration 2531, loss = 0.09719412
# Iteration 2532, loss = 0.09717686
# Iteration 2533, loss = 0.09715963
# Iteration 2534, loss = 0.09714243
# Iteration 2535, loss = 0.09712527
# Iteration 2536, loss = 0.09710814
# Iteration 2537, loss = 0.09709104
# Iteration 2538, loss = 0.09707398
# Iteration 2539, loss = 0.09705696
# Iteration 2540, loss = 0.09703996
# Iteration 2541, loss = 0.09702300
# Iteration 2542, loss = 0.09700608
# Iteration 2543, loss = 0.09698919
# Iteration 2544, loss = 0.09697233
# Iteration 2545, loss = 0.09695551
# Iteration 2546, loss = 0.09693872
# Iteration 2547, loss = 0.09692196
# Iteration 2548, loss = 0.09690524
# Iteration 2549, loss = 0.09688855
# Iteration 2550, loss = 0.09687189
# Iteration 2551, loss = 0.09685527
# Iteration 2552, loss = 0.09683868
# Iteration 2553, loss = 0.09682213
# Iteration 2554, loss = 0.09680561
# Iteration 2555, loss = 0.09678912
# Iteration 2556, loss = 0.09677266
# Iteration 2557, loss = 0.09675624
# Iteration 2558, loss = 0.09673985
# Iteration 2559, loss = 0.09672350
# Iteration 2560, loss = 0.09670717
# Iteration 2561, loss = 0.09669088
# Iteration 2562, loss = 0.09667463
# Iteration 2563, loss = 0.09665840
# Iteration 2564, loss = 0.09664221
# Iteration 2565, loss = 0.09662606
# Iteration 2566, loss = 0.09660993
# Iteration 2567, loss = 0.09659384
# Iteration 2568, loss = 0.09657778
# Iteration 2569, loss = 0.09656175
# Iteration 2570, loss = 0.09654576
# Iteration 2571, loss = 0.09652980
# Iteration 2572, loss = 0.09651387
# Iteration 2573, loss = 0.09649797
# Iteration 2574, loss = 0.09648211
# Iteration 2575, loss = 0.09646628
# Iteration 2576, loss = 0.09645048
# Iteration 2577, loss = 0.09643471
# Iteration 2578, loss = 0.09641898
# Iteration 2579, loss = 0.09640328
# Iteration 2580, loss = 0.09638761
# Iteration 2581, loss = 0.09637197
# Iteration 2582, loss = 0.09635637
# Iteration 2583, loss = 0.09634079
# Iteration 2584, loss = 0.09632525
# Iteration 2585, loss = 0.09630975
# Iteration 2586, loss = 0.09629427
# Iteration 2587, loss = 0.09627883
# Iteration 2588, loss = 0.09626341
# Iteration 2589, loss = 0.09624803
# Iteration 2590, loss = 0.09623268
# Iteration 2591, loss = 0.09621737
# Iteration 2592, loss = 0.09620208
# Iteration 2593, loss = 0.09618683
# Iteration 2594, loss = 0.09617161
# Iteration 2595, loss = 0.09615642
# Iteration 2596, loss = 0.09614126
# Iteration 2597, loss = 0.09612613
# Iteration 2598, loss = 0.09611104
# Iteration 2599, loss = 0.09609597
# Iteration 2600, loss = 0.09608094
# Iteration 2601, loss = 0.09606594
# Iteration 2602, loss = 0.09605097
# Iteration 2603, loss = 0.09603603
# Iteration 2604, loss = 0.09602113
# Iteration 2605, loss = 0.09600625
# Iteration 2606, loss = 0.09599141
# Iteration 2607, loss = 0.09597659
# Iteration 2608, loss = 0.09596181
# Iteration 2609, loss = 0.09594706
# Iteration 2610, loss = 0.09593234
# Iteration 2611, loss = 0.09591765
# Iteration 2612, loss = 0.09590299
# Iteration 2613, loss = 0.09588837
# Iteration 2614, loss = 0.09587377
# Iteration 2615, loss = 0.09585921
# Iteration 2616, loss = 0.09584467
# Iteration 2617, loss = 0.09583017
# Iteration 2618, loss = 0.09581570
# Iteration 2619, loss = 0.09580125
# Iteration 2620, loss = 0.09578684
# Iteration 2621, loss = 0.09577246
# Iteration 2622, loss = 0.09575811
# Iteration 2623, loss = 0.09574379
# Iteration 2624, loss = 0.09572950
# Iteration 2625, loss = 0.09571524
# Iteration 2626, loss = 0.09570101
# Iteration 2627, loss = 0.09568681
# Iteration 2628, loss = 0.09567265
# Iteration 2629, loss = 0.09565851
# Iteration 2630, loss = 0.09564440
# Iteration 2631, loss = 0.09563032
# Iteration 2632, loss = 0.09561628
# Iteration 2633, loss = 0.09560226
# Iteration 2634, loss = 0.09558827
# Iteration 2635, loss = 0.09557431
# Iteration 2636, loss = 0.09556039
# Iteration 2637, loss = 0.09554649
# Iteration 2638, loss = 0.09553262
# Iteration 2639, loss = 0.09551879
# Iteration 2640, loss = 0.09550498
# Iteration 2641, loss = 0.09549120
# Iteration 2642, loss = 0.09547745
# Iteration 2643, loss = 0.09546373
# Iteration 2644, loss = 0.09545004
# Iteration 2645, loss = 0.09543638
# Iteration 2646, loss = 0.09542276
# Iteration 2647, loss = 0.09540915
# Iteration 2648, loss = 0.09539558
# Iteration 2649, loss = 0.09538204
# Iteration 2650, loss = 0.09536853
# Iteration 2651, loss = 0.09535505
# Iteration 2652, loss = 0.09534159
# Iteration 2653, loss = 0.09532817
# Iteration 2654, loss = 0.09531478
# Iteration 2655, loss = 0.09530141
# Iteration 2656, loss = 0.09528807
# Iteration 2657, loss = 0.09527477
# Iteration 2658, loss = 0.09526149
# Iteration 2659, loss = 0.09524824
# Iteration 2660, loss = 0.09523502
# Iteration 2661, loss = 0.09522183
# Iteration 2662, loss = 0.09520866
# Iteration 2663, loss = 0.09519553
# Iteration 2664, loss = 0.09518243
# Iteration 2665, loss = 0.09516935
# Iteration 2666, loss = 0.09515630
# Iteration 2667, loss = 0.09514328
# Iteration 2668, loss = 0.09513029
# Iteration 2669, loss = 0.09511733
# Iteration 2670, loss = 0.09510440
# Iteration 2671, loss = 0.09509150
# Iteration 2672, loss = 0.09507862
# Iteration 2673, loss = 0.09506577
# Iteration 2674, loss = 0.09505295
# Iteration 2675, loss = 0.09504016
# Iteration 2676, loss = 0.09502740
# Iteration 2677, loss = 0.09501467
# Iteration 2678, loss = 0.09500196
# Iteration 2679, loss = 0.09498928
# Iteration 2680, loss = 0.09497663
# Iteration 2681, loss = 0.09496401
# Iteration 2682, loss = 0.09495142
# Iteration 2683, loss = 0.09493885
# Iteration 2684, loss = 0.09492632
# Iteration 2685, loss = 0.09491381
# Iteration 2686, loss = 0.09490133
# Iteration 2687, loss = 0.09488887
# Iteration 2688, loss = 0.09487645
# Iteration 2689, loss = 0.09486405
# Iteration 2690, loss = 0.09485168
# Iteration 2691, loss = 0.09483934
# Iteration 2692, loss = 0.09482702
# Iteration 2693, loss = 0.09481473
# Iteration 2694, loss = 0.09480247
# Iteration 2695, loss = 0.09479024
# Iteration 2696, loss = 0.09477804
# Iteration 2697, loss = 0.09476586
# Iteration 2698, loss = 0.09475371
# Iteration 2699, loss = 0.09474159
# Iteration 2700, loss = 0.09472949
# Iteration 2701, loss = 0.09471742
# Iteration 2702, loss = 0.09470538
# Iteration 2703, loss = 0.09469337
# Iteration 2704, loss = 0.09468138
# Iteration 2705, loss = 0.09466943
# Iteration 2706, loss = 0.09465749
# Iteration 2707, loss = 0.09464559
# Iteration 2708, loss = 0.09463371
# Iteration 2709, loss = 0.09462186
# Iteration 2710, loss = 0.09461003
# Iteration 2711, loss = 0.09459824
# Iteration 2712, loss = 0.09458647
# Iteration 2713, loss = 0.09457472
# Iteration 2714, loss = 0.09456301
# Iteration 2715, loss = 0.09455132
# Iteration 2716, loss = 0.09453965
# Iteration 2717, loss = 0.09452802
# Iteration 2718, loss = 0.09451641
# Iteration 2719, loss = 0.09450482
# Iteration 2720, loss = 0.09449326
# Iteration 2721, loss = 0.09448173
# Iteration 2722, loss = 0.09447023
# Iteration 2723, loss = 0.09445875
# Iteration 2724, loss = 0.09444730
# Iteration 2725, loss = 0.09443587
# Iteration 2726, loss = 0.09442448
# Iteration 2727, loss = 0.09441310
# Iteration 2728, loss = 0.09440176
# Iteration 2729, loss = 0.09439043
# Iteration 2730, loss = 0.09437914
# Iteration 2731, loss = 0.09436787
# Iteration 2732, loss = 0.09435663
# Iteration 2733, loss = 0.09434541
# Iteration 2734, loss = 0.09433422
# Iteration 2735, loss = 0.09432306
# Iteration 2736, loss = 0.09431192
# Iteration 2737, loss = 0.09430081
# Iteration 2738, loss = 0.09428972
# Iteration 2739, loss = 0.09427866
# Iteration 2740, loss = 0.09426762
# Iteration 2741, loss = 0.09425661
# Iteration 2742, loss = 0.09424563
# Iteration 2743, loss = 0.09423467
# Iteration 2744, loss = 0.09422373
# Iteration 2745, loss = 0.09421283
# Iteration 2746, loss = 0.09420194
# Iteration 2747, loss = 0.09419109
# Iteration 2748, loss = 0.09418026
# Iteration 2749, loss = 0.09416945
# Iteration 2750, loss = 0.09415867
# Iteration 2751, loss = 0.09414791
# Iteration 2752, loss = 0.09413718
# Iteration 2753, loss = 0.09412648
# Iteration 2754, loss = 0.09411580
# Iteration 2755, loss = 0.09410514
# Iteration 2756, loss = 0.09409451
# Iteration 2757, loss = 0.09408390
# Iteration 2758, loss = 0.09407332
# Iteration 2759, loss = 0.09406277
# Iteration 2760, loss = 0.09405224
# Iteration 2761, loss = 0.09404173
# Iteration 2762, loss = 0.09403125
# Iteration 2763, loss = 0.09402080
# Iteration 2764, loss = 0.09401036
# Iteration 2765, loss = 0.09399996
# Iteration 2766, loss = 0.09398958
# Iteration 2767, loss = 0.09397922
# Iteration 2768, loss = 0.09396888
# Iteration 2769, loss = 0.09395858
# Iteration 2770, loss = 0.09394829
# Iteration 2771, loss = 0.09393803
# Iteration 2772, loss = 0.09392780
# Iteration 2773, loss = 0.09391759
# Iteration 2774, loss = 0.09390740
# Iteration 2775, loss = 0.09389724
# Iteration 2776, loss = 0.09388710
# Iteration 2777, loss = 0.09387699
# Iteration 2778, loss = 0.09386690
# Iteration 2779, loss = 0.09385683
# Iteration 2780, loss = 0.09384679
# Iteration 2781, loss = 0.09383677
# Iteration 2782, loss = 0.09382678
# Iteration 2783, loss = 0.09381681
# Iteration 2784, loss = 0.09380686
# Iteration 2785, loss = 0.09379694
# Iteration 2786, loss = 0.09378704
# Iteration 2787, loss = 0.09377717
# Iteration 2788, loss = 0.09376732
# Iteration 2789, loss = 0.09375749
# Iteration 2790, loss = 0.09374769
# Iteration 2791, loss = 0.09373791
# Iteration 2792, loss = 0.09372815
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# (array([5.72991806]), 0.7246613040130181)

# %% [markdown]
# REVISIONS||
# :- | :-
# 2018-12-18| CEF, initial.
# 2019-01-24| CEF, spell checked and update.
# 2019-01-30| CEF, removed reset -f, did not work on all PC's.
# 2019-08-20| CEF, E19 ITMAL update.
# 2019-08-26| CEF, minor mod to NN exercise.
# 2019-08-28| CEF, fixed dataset dir issue, datapath"../datasets" changed to "./datasets".
# 2020-01-25| CEF, F20 ITMAL update.
# 2020-08-06| CEF, E20 ITMAL update, minor fix of ls to dir and added exception to datasets load, udpated figs paths.
# 2020-09-24| CEF, updated text to R2, Qa exe.
# 2020-09-28| CEF, updated R2 and theta extraction, use python attributes, moved revision table. Added comment about MLP.
# 2021-01-12| CEF, updated Qe.
# 2021-02-08| CEF, added ls for Mac/Linux to dir command cell.
# 2021-08-02| CEF, update to E21 ITMAL.
# 2021-08-03| CEF, fixed ref to p21 => p.22.
# 2022-01-25| CEF, update to F22 SWMAL.
# 2022-08-30| CEF, update to v1 changes.
# 2023-08-30| CEF, minor table update for.
# 2023-09-01| CEF, fixed ref to p.22 => p.28, changed LaTeX mbox and newcommand (VSCode error) to textrm/mathrm and renewcommand.
