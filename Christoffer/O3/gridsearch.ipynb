# %% [markdown]
#     # SWMAL Exercise
#
#
# ## Hyperparameters and Gridsearch
#
# When instantiating a Scikit-learn model in python most or all constructor parameters have _default_ values. These values are not part of the internal model and are hence called ___hyperparameters___---in contrast to _normal_ model parameters, for example the neuron weights, $\mathbf w$, for an `MLP` model.
#
# ### Manual Tuning Hyperparameters
#
# Below is an example of the python constructor for the support-vector classifier `sklearn.svm.SVC`, with say the `kernel` hyperparameter having the default value `'rbf'`. If you should choose, what would you set it to other than `'rbf'`?
#
# ```python
# class sklearn.svm.SVC(
#     C=1.0,
#     kernel=’rbf’,
#     degree=3,
#     gamma=’auto_deprecated’,
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape=’ovr’,
#     random_state=None
#   )
# ```
#
# The default values might be a sensible general starting point, but for your data, you might want to optimize the hyperparameters to yield a better result.
#
# To be able to set `kernel` to a sensible value you need to go into the documentation for the `SVC` and understand what the kernel parameter represents, and what values it can be set to, and you need to understand the consequences of setting `kernel` to something different than the default...and the story repeats for every other hyperparameter!
#
# ### Brute Force  Search
#
# An alternative to this structured, but time-consuming approach, is just to __brute-force__ a search of interesting hyperparameters, and  choose the 'best' parameters according to a fit-predict and some score, say 'f1'.
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L09/Figs/gridsearch.png"  alt="WARNING: could not get image from server."  style="width:350px">
# <small><em>
#     <center> Conceptual graphical view of grid search for two distinct hyperparameters. </center>
#     <center> Notice that you would normally search hyperparameters like `alpha` with an exponential range, say [0.01, 0.1, 1, 10] or similar.</center>
# </em></small>
#
# Now, you just pick out some hyperparameters, that you figure are important, set them to a suitable range, say
#
# ```python
#     'kernel':('linear', 'rbf'),
#     'C':[1, 10]
# ```
# and fire up a full (grid) search on this hyperparameter set, that will try out all your specified combination of `kernel` and `C` for the model, and then prints the hyperparameter set with the highest score...
#
# The demo code below sets up some of our well known 'hello-world' data and then run a _grid search_ on a particular model, here a _support-vector classifier_ (SVC)
#
# Other models and datasets  ('mnist', 'iris', 'moon') can also be examined.
#
# ### Qa Explain GridSearchCV
#
# There are two code cells below: 1) function setup, 2) the actual grid-search.
#
# Review the code cells and write a __short__ summary. Mainly focus on __cell 2__, but dig into cell 1 if you find it interesting (notice the use of local-function, a nifty feature in python).
#
# In detail, examine the lines:
#
# ```python
# grid_tuned = GridSearchCV(model, tuning_parameters, ..
# grid_tuned.fit(X_train, y_train)
# ..
# FullReport(grid_tuned , X_test, y_test, time_gridsearch)
# ```
# and write a short description of how the `GridSeachCV` works: explain how the search parameter set is created and the overall search mechanism is functioning (without going into too much detail).
#
# What role does the parameter `scoring='f1_micro'` play in the `GridSearchCV`, and what does `n_jobs=-1` mean?

# %%
# TODO: Qa, code review..cell 1) function setup

from time import time
import numpy as np
import sys

from sklearn import svm
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import datasets
import sys,os
sys.path.append(R'../../UndervisningsGit/GITMAL')

from libitmal import dataloaders as itmaldataloaders # Needed for load of iris, moon and mnist

currmode="N/A" # GLOBAL var!

def SearchReport(model): 
    
    def GetBestModelCTOR(model, best_params):
        def GetParams(best_params):
            ret_str=""          
            for key in sorted(best_params):
                value = best_params[key]
                temp_str = "'" if str(type(value))=="<class 'str'>" else ""
                if len(ret_str)>0:
                    ret_str += ','
                ret_str += f'{key}={temp_str}{value}{temp_str}'  
            return ret_str          
        try:
            param_str = GetParams(best_params)
            return type(model).__name__ + '(' + param_str + ')' 
        except:
            return "N/A(1)"
        
    print("\nBest model set found on train set:")
    print()
    print(f"\tbest parameters={model.best_params_}")
    print(f"\tbest '{model.scoring}' score={model.best_score_}")
    print(f"\tbest index={model.best_index_}")
    print()
    print(f"Best estimator CTOR:")
    print(f"\t{model.best_estimator_}")
    print()
    try:
        print(f"Grid scores ('{model.scoring}') on development set:")
        means = model.cv_results_['mean_test_score']
        stds  = model.cv_results_['std_test_score']
        i=0
        for mean, std, params in zip(means, stds, model.cv_results_['params']):
            print("\t[%2d]: %0.3f (+/-%0.03f) for %r" % (i, mean, std * 2, params))
            i += 1
    except:
        print("WARNING: the random search do not provide means/stds")
    
    global currmode                
    assert "f1_micro"==str(model.scoring), f"come on, we need to fix the scoring to be able to compare model-fits! Your scoreing={str(model.scoring)}...remember to add scoring='f1_micro' to the search"   
    return f"best: dat={currmode}, score={model.best_score_:0.5f}, model={GetBestModelCTOR(model.estimator,model.best_params_)}", model.best_estimator_ 

def ClassificationReport(model, X_test, y_test, target_names=None):
    assert X_test.shape[0]==y_test.shape[0]
    print("\nDetailed classification report:")
    print("\tThe model is trained on the full development set.")
    print("\tThe scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, model.predict(X_test)                 
    print(classification_report(y_true, y_pred, target_names=target_names))
    print()
    
def FullReport(model, X_test, y_test, t):
    print(f"SEARCH TIME: {t:0.2f} sec")
    beststr, bestmodel = SearchReport(model)
    ClassificationReport(model, X_test, y_test)    
    print(f"CTOR for best model: {bestmodel}\n")
    print(f"{beststr}\n")
    return beststr, bestmodel
    
def LoadAndSetupData(mode, test_size=0.3):
    assert test_size>=0.0 and test_size<=1.0
    
    def ShapeToString(Z):
        n = Z.ndim
        s = "("
        for i in range(n):
            s += f"{Z.shape[i]:5d}"
            if i+1!=n:
                s += ";"
        return s+")"

    global currmode
    currmode=mode
    print(f"DATA: {currmode}..")
    
    if mode=='moon':
        X, y = itmaldataloaders.MOON_GetDataSet(n_samples=5000, noise=0.2)
        itmaldataloaders.MOON_Plot(X, y)
    elif mode=='mnist':
        X, y = itmaldataloaders.MNIST_GetDataSet(load_mode=0)
        if X.ndim==3:
            X=np.reshape(X, (X.shape[0], -1))
    elif mode=='iris':
        X, y = itmaldataloaders.IRIS_GetDataSet()
    else:
        raise ValueError(f"could not load data for that particular mode='{mode}', only 'moon'/'mnist'/'iris' supported")
        
    print(f'  org. data:  X.shape      ={ShapeToString(X)}, y.shape      ={ShapeToString(y)}')

    assert X.ndim==2
    assert X.shape[0]==y.shape[0]
    assert y.ndim==1 or (y.ndim==2 and y.shape[1]==0)    
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=0, shuffle=True
    )
    
    print(f'  train data: X_train.shape={ShapeToString(X_train)}, y_train.shape={ShapeToString(y_train)}')
    print(f'  test data:  X_test.shape ={ShapeToString(X_test)}, y_test.shape ={ShapeToString(y_test)}')
    print()
    
    return X_train, X_test, y_train, y_test

def TryKerasImport(verbose=True):
    
    kerasok = True
    try:
        import keras as keras_try
    except:
        kerasok = False

    tensorflowkerasok = True
    try:
        import tensorflow.keras as tensorflowkeras_try
    except:
        tensorflowkerasok = False
        
    ok = kerasok or tensorflowkerasok
    
    if not ok and verbose:
        if not kerasok:
            print("WARNING: importing 'keras' failed", file=sys.stderr)
        if not tensorflowkerasok:
            print("WARNING: importing 'tensorflow.keras' failed", file=sys.stderr)

    return ok
    
print(f"OK(function setup" + ("" if TryKerasImport() else ", hope MNIST loads works because it seems you miss the installation of Keras or Tensorflow!") + ")")
# Out:
# OK(function setup)

# %%
# TODO: Qa, code review..cell 2) the actual grid-search

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = svm.SVC(
    gamma=0.001
)  # NOTE: gamma="scale" does not work in older Scikit-learn frameworks,
# FIX:  replace with model = svm.SVC(gamma=0.001)

tuning_parameters = {
    'kernel': ('linear', 'rbf'), 
    'C': [0.1, 1, 10]
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
grid_tuned = GridSearchCV(model,
                          tuning_parameters,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1)

start = time()
grid_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
# SEARCH TIME: 2.33 sec
#
# Best model set found on train set:
#
# 	best parameters={'C': 1, 'kernel': 'linear'}
# 	best 'f1_micro' score=0.9714285714285715
# 	best index=2
#
# Best estimator CTOR:
# 	SVC(C=1, gamma=0.001, kernel='linear')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.962 (+/-0.093) for {'C': 0.1, 'kernel': 'linear'}
# 	[ 1]: 0.371 (+/-0.038) for {'C': 0.1, 'kernel': 'rbf'}
# 	[ 2]: 0.971 (+/-0.047) for {'C': 1, 'kernel': 'linear'}
# 	[ 3]: 0.695 (+/-0.047) for {'C': 1, 'kernel': 'rbf'}
# 	[ 4]: 0.952 (+/-0.085) for {'C': 10, 'kernel': 'linear'}
# 	[ 5]: 0.924 (+/-0.097) for {'C': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SVC(C=1, gamma=0.001, kernel='linear')
#
# best: dat=iris, score=0.97143, model=SVC(C=1,kernel='linear')
#
# OK(grid-search)

# %% [markdown]
# ### Qb Hyperparameter Grid Search using an SDG classifier
#
# Now, replace the `svm.SVC` model with an `SGDClassifier` and a suitable set of the hyperparameters for that model.
#
# You need at least four or five different hyperparameters from the `SGDClassifier` in the search-space before it begins to take considerable compute time doing the full grid search.
#
# So, repeat the search with the `SGDClassifier`, and be sure to add enough hyperparameters to the grid-search, such that the search takes a considerable time to run, that is a couple of minutes or up to some hours..

# %%
# TODO: grid search

model = SGDClassifier() #Instantiate mdoel with default params. 

tuning_parameters_SGD = {
    'loss': ['hinge', 'modified_huber', 'squared_hinge', 'squared_error'],
    'penalty': ['l2', 'l1', 'elasticnet'],
    'alpha': [0.0001, 0.001, 0.01, 0.1],
    'learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
    'eta0': [0.0001, 0.001, 0.01, 0.1],
    'max_iter': [1000, 2000, 3000],
    'tol': [1e-3, 1e-4, 1e-5]
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
grid_tuned_SGD = GridSearchCV(model,
                          tuning_parameters_SGD,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1)

start = time()
grid_tuned_SGD.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned_SGD, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# SEARCH TIME: 21.03 sec
#
# Best model set found on train set:
#
# 	best parameters={'alpha': 0.1, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	best 'f1_micro' score=1.0
# 	best index=5351
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.1, eta0=0.0001, loss='squared_hinge', penalty='l1',
#               tol=1e-05)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[ 1]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[ 2]: 0.724 (+/-0.093) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[ 3]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[ 4]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[ 5]: 0.714 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[ 6]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[ 7]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[ 8]: 0.771 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[ 9]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[10]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[11]: 0.724 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[12]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[13]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[14]: 0.705 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[15]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[16]: 0.705 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[17]: 0.705 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[18]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[19]: 0.705 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[20]: 0.771 (+/-0.152) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[21]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[22]: 0.714 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[23]: 0.733 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[24]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[25]: 0.714 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[26]: 0.714 (+/-0.000) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[27]: 0.762 (+/-0.120) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[28]: 0.895 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[29]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[30]: 0.781 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[31]: 0.867 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[32]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[33]: 0.819 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[34]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[35]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[36]: 0.790 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[37]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[38]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[39]: 0.810 (+/-0.104) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[40]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[41]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[42]: 0.781 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[43]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[44]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[45]: 0.810 (+/-0.148) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[46]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[47]: 0.905 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[48]: 0.752 (+/-0.175) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[49]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[50]: 0.914 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[51]: 0.781 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[52]: 0.876 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[53]: 0.867 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[54]: 0.771 (+/-0.152) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[55]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[56]: 0.886 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[57]: 0.790 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[58]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[59]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[60]: 0.762 (+/-0.120) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[61]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[62]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[63]: 0.781 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[64]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[65]: 0.895 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[66]: 0.800 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[67]: 0.886 (+/-0.155) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[68]: 0.914 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[69]: 0.819 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[70]: 0.848 (+/-0.111) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[71]: 0.886 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[72]: 0.781 (+/-0.155) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[73]: 0.886 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[74]: 0.876 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[75]: 0.771 (+/-0.175) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[76]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[77]: 0.914 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[78]: 0.800 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[79]: 0.886 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[80]: 0.886 (+/-0.097) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[81]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[82]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[83]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[84]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[85]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[86]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[87]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[88]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[89]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[90]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[91]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[92]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[93]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[94]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[95]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[96]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[97]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[98]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[99]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[100]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[101]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[102]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[103]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[104]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[105]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[106]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[107]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'constant', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[108]: 0.800 (+/-0.291) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[109]: 0.819 (+/-0.220) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[110]: 0.762 (+/-0.248) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[111]: 0.819 (+/-0.212) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[112]: 0.838 (+/-0.177) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[113]: 0.829 (+/-0.245) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[114]: 0.657 (+/-0.368) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[115]: 0.886 (+/-0.177) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[116]: 0.810 (+/-0.319) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[117]: 0.743 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[118]: 0.733 (+/-0.260) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[119]: 0.857 (+/-0.200) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[120]: 0.857 (+/-0.209) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[121]: 0.895 (+/-0.194) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[122]: 0.905 (+/-0.060) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[123]: 0.743 (+/-0.457) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[124]: 0.724 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[125]: 0.848 (+/-0.236) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[126]: 0.819 (+/-0.244) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[127]: 0.876 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[128]: 0.800 (+/-0.152) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[129]: 0.838 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[130]: 0.810 (+/-0.301) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[131]: 0.800 (+/-0.220) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[132]: 0.829 (+/-0.166) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[133]: 0.733 (+/-0.328) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[134]: 0.876 (+/-0.214) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[135]: 0.810 (+/-0.248) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[136]: 0.819 (+/-0.185) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[137]: 0.686 (+/-0.424) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[138]: 0.876 (+/-0.143) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[139]: 0.790 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[140]: 0.876 (+/-0.166) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[141]: 0.857 (+/-0.181) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[142]: 0.705 (+/-0.164) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[143]: 0.714 (+/-0.276) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[144]: 0.695 (+/-0.354) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[145]: 0.657 (+/-0.258) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[146]: 0.857 (+/-0.256) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[147]: 0.781 (+/-0.187) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[148]: 0.895 (+/-0.185) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[149]: 0.857 (+/-0.104) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[150]: 0.762 (+/-0.263) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[151]: 0.781 (+/-0.166) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[152]: 0.733 (+/-0.129) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[153]: 0.686 (+/-0.339) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[154]: 0.838 (+/-0.205) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[155]: 0.857 (+/-0.225) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[156]: 0.790 (+/-0.238) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[157]: 0.886 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[158]: 0.790 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[159]: 0.705 (+/-0.220) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[160]: 0.752 (+/-0.212) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[161]: 0.790 (+/-0.129) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[162]: 0.762 (+/-0.241) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[163]: 0.838 (+/-0.260) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[164]: 0.829 (+/-0.166) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[165]: 0.867 (+/-0.175) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[166]: 0.838 (+/-0.205) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[167]: 0.800 (+/-0.212) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[168]: 0.886 (+/-0.114) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[169]: 0.943 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[170]: 0.876 (+/-0.187) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[171]: 0.790 (+/-0.238) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[172]: 0.886 (+/-0.196) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[173]: 0.781 (+/-0.245) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[174]: 0.924 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[175]: 0.838 (+/-0.177) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[176]: 0.867 (+/-0.212) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[177]: 0.667 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[178]: 0.867 (+/-0.164) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[179]: 0.790 (+/-0.260) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[180]: 0.933 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[181]: 0.790 (+/-0.311) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[182]: 0.810 (+/-0.200) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[183]: 0.895 (+/-0.152) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[184]: 0.924 (+/-0.114) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[185]: 0.867 (+/-0.185) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[186]: 0.743 (+/-0.473) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[187]: 0.810 (+/-0.217) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[188]: 0.867 (+/-0.251) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[189]: 0.495 (+/-0.364) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[190]: 0.362 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[191]: 0.343 (+/-0.432) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[192]: 0.343 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[193]: 0.324 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[194]: 0.390 (+/-0.285) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[195]: 0.267 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[196]: 0.343 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[197]: 0.286 (+/-0.170) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[198]: 0.343 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[199]: 0.333 (+/-0.000) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[200]: 0.324 (+/-0.071) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[201]: 0.324 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[202]: 0.390 (+/-0.236) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[203]: 0.362 (+/-0.177) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[204]: 0.371 (+/-0.298) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[205]: 0.324 (+/-0.279) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[206]: 0.257 (+/-0.267) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[207]: 0.257 (+/-0.260) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[208]: 0.371 (+/-0.203) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[209]: 0.429 (+/-0.289) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[210]: 0.333 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[211]: 0.333 (+/-0.085) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[212]: 0.267 (+/-0.230) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[213]: 0.381 (+/-0.148) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[214]: 0.257 (+/-0.267) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[215]: 0.448 (+/-0.293) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'optimal', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[216]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[217]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[218]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[219]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[220]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[221]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[222]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[223]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[224]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[225]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[226]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[227]: 0.686 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[228]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[229]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[230]: 0.686 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[231]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[232]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[233]: 0.686 (+/-0.076) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[234]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[235]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[236]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[237]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[238]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[239]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[240]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[241]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[242]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[243]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[244]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[245]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[246]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[247]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[248]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[249]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[250]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[251]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[252]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[253]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[254]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[255]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[256]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[257]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[258]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[259]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[260]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[261]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[262]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[263]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[264]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[265]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[266]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[267]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[268]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[269]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[270]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[271]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[272]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[273]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[274]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[275]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[276]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[277]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[278]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[279]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[280]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[281]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[282]: 0.371 (+/-0.038) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[283]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[284]: 0.695 (+/-0.047) for {'alpha': 0.0001, 'eta0': 0.0001, 'learning_rate': 'invscaling', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# ...
# 	[6820]: 0.800 (+/-0.038) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6821]: 0.781 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6822]: 0.819 (+/-0.111) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[6823]: 0.819 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6824]: 0.790 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6825]: 0.762 (+/-0.060) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[6826]: 0.752 (+/-0.038) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6827]: 0.752 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6828]: 0.829 (+/-0.097) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6829]: 0.781 (+/-0.155) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6830]: 0.790 (+/-0.097) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6831]: 0.943 (+/-0.093) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[6832]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6833]: 0.943 (+/-0.093) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6834]: 0.952 (+/-0.104) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[6835]: 0.962 (+/-0.111) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6836]: 0.962 (+/-0.111) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6837]: 0.943 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6838]: 0.924 (+/-0.166) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6839]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6840]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[6841]: 0.962 (+/-0.038) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6842]: 0.952 (+/-0.104) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6843]: 0.971 (+/-0.076) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[6844]: 0.952 (+/-0.104) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6845]: 0.971 (+/-0.076) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6846]: 0.952 (+/-0.104) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6847]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6848]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6849]: 0.952 (+/-0.060) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[6850]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6851]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6852]: 0.962 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[6853]: 0.981 (+/-0.047) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6854]: 0.962 (+/-0.111) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6855]: 0.943 (+/-0.093) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6856]: 0.924 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6857]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6858]: 0.924 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[6859]: 0.924 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6860]: 0.924 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6861]: 0.952 (+/-0.060) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[6862]: 0.943 (+/-0.093) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6863]: 0.952 (+/-0.060) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6864]: 0.933 (+/-0.222) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6865]: 0.914 (+/-0.164) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6866]: 0.943 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6867]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[6868]: 0.943 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6869]: 0.933 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6870]: 0.943 (+/-0.093) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[6871]: 0.933 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6872]: 0.943 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6873]: 0.914 (+/-0.152) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6874]: 0.933 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6875]: 0.895 (+/-0.203) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6876]: 0.943 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[6877]: 0.933 (+/-0.222) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6878]: 0.933 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6879]: 0.962 (+/-0.038) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[6880]: 0.933 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6881]: 0.971 (+/-0.047) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6882]: 0.914 (+/-0.126) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6883]: 0.895 (+/-0.185) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6884]: 0.943 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_hinge', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6885]: 0.314 (+/-0.129) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.001}
# 	[6886]: 0.324 (+/-0.220) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6887]: 0.295 (+/-0.185) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6888]: 0.324 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.001}
# 	[6889]: 0.333 (+/-0.159) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6890]: 0.324 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6891]: 0.352 (+/-0.166) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6892]: 0.343 (+/-0.164) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6893]: 0.314 (+/-0.177) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 1000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6894]: 0.343 (+/-0.126) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.001}
# 	[6895]: 0.371 (+/-0.194) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6896]: 0.295 (+/-0.185) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6897]: 0.295 (+/-0.212) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.001}
# 	[6898]: 0.286 (+/-0.159) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6899]: 0.324 (+/-0.185) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6900]: 0.248 (+/-0.071) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6901]: 0.314 (+/-0.187) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6902]: 0.390 (+/-0.164) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 2000, 'penalty': 'elasticnet', 'tol': 1e-05}
# 	[6903]: 0.400 (+/-0.155) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.001}
# 	[6904]: 0.314 (+/-0.196) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 0.0001}
# 	[6905]: 0.257 (+/-0.143) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l2', 'tol': 1e-05}
# 	[6906]: 0.324 (+/-0.185) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.001}
# 	[6907]: 0.343 (+/-0.140) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 0.0001}
# 	[6908]: 0.352 (+/-0.076) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'l1', 'tol': 1e-05}
# 	[6909]: 0.229 (+/-0.038) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.001}
# 	[6910]: 0.229 (+/-0.212) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 0.0001}
# 	[6911]: 0.362 (+/-0.205) for {'alpha': 0.1, 'eta0': 0.1, 'learning_rate': 'adaptive', 'loss': 'squared_error', 'max_iter': 3000, 'penalty': 'elasticnet', 'tol': 1e-05}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.89      0.94        18
#            2       0.85      1.00      0.92        11
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.1, eta0=0.0001, loss='squared_hinge', penalty='l1',
#               tol=1e-05)
#
# best: dat=iris, score=1.00000, model=SGDClassifier(alpha=0.1,eta0=0.0001,learning_rate='optimal',loss='squared_hinge',max_iter=1000,penalty='l1',tol=1e-05)
#
# OK(grid-search)

# %% [markdown]
# ### Qc Hyperparameter Random  Search using an SDG classifier
#
# Now, add code to run a `RandomizedSearchCV` instead.
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L09/Figs/randomsearch.png" alt="WARNING: could not get image from server."  style="width:350px" >
# <small><em>
#     <center> Conceptual graphical view of randomized search for two distinct hyperparameters. </center>
# </em></small>
#
# Use these default parameters for the random search, similar to the default parameters for the grid search
#
# ```python
# random_tuned = RandomizedSearchCV(
#     model,
#     tuning_parameters,
#     n_iter=20,
#     random_state=42,
#     cv=CV,
#     scoring='f1_micro',
#     verbose=VERBOSE,
#     n_jobs=-1
# )
# ```
#
# but with the two new parameters, `n_iter` and `random_state` added. Since the search-type is now random, the `random_state` gives sense, but essential to random search is the new `n_tier` parameter.
#
# So: investigate the `n_iter` parameter...in code and write a conceptual explanation  in text.
#
# Comparison of time (seconds) to complete `GridSearch` versus `RandomizedSearchCV`, does not necessarily give any sense, if your grid search completes in a few seconds (as for the iris tiny-data). You need a search that runs for minutes, hours, or days.
#
# But you could compare the best-tuned parameter set and best scoring for the two methods. Is the random search best model close to the grid search?

# %%
# TODO:

random_tuned = RandomizedSearchCV(
    model,
    tuning_parameters_SGD,
    n_iter=20,
    random_state=42,
    cv=CV,
    scoring='f1_micro',
    verbose=VERBOSE,
    n_jobs=-1
)

# Run RandomizedSearchCV for the model
start = time()
random_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b1, m1 = FullReport(random_tuned, X_test, y_test, t)
print('OK(random-search)')
# Out:
# SEARCH TIME: 2.42 sec
#
# Best model set found on train set:
#
# 	best parameters={'tol': 0.001, 'penalty': 'l1', 'max_iter': 3000, 'loss': 'squared_hinge', 'learning_rate': 'optimal', 'eta0': 0.01, 'alpha': 0.1}
# 	best 'f1_micro' score=1.0
# 	best index=12
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.1, eta0=0.01, loss='squared_hinge', max_iter=3000,
#               penalty='l1')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.695 (+/-0.047) for {'tol': 1e-05, 'penalty': 'l1', 'max_iter': 3000, 'loss': 'squared_error', 'learning_rate': 'adaptive', 'eta0': 0.001, 'alpha': 0.0001}
# 	[ 1]: 0.295 (+/-0.126) for {'tol': 1e-05, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'squared_error', 'learning_rate': 'optimal', 'eta0': 0.0001, 'alpha': 0.1}
# 	[ 2]: 0.762 (+/-0.120) for {'tol': 0.001, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'modified_huber', 'learning_rate': 'constant', 'eta0': 0.0001, 'alpha': 0.1}
# 	[ 3]: 0.695 (+/-0.047) for {'tol': 0.0001, 'penalty': 'elasticnet', 'max_iter': 1000, 'loss': 'hinge', 'learning_rate': 'constant', 'eta0': 0.0001, 'alpha': 0.1}
# 	[ 4]: 0.371 (+/-0.038) for {'tol': 0.0001, 'penalty': 'l2', 'max_iter': 3000, 'loss': 'squared_error', 'learning_rate': 'invscaling', 'eta0': 0.0001, 'alpha': 0.01}
# 	[ 5]: 0.743 (+/-0.166) for {'tol': 1e-05, 'penalty': 'l1', 'max_iter': 2000, 'loss': 'squared_hinge', 'learning_rate': 'constant', 'eta0': 0.1, 'alpha': 0.001}
# 	[ 6]: 0.800 (+/-0.185) for {'tol': 0.0001, 'penalty': 'l2', 'max_iter': 2000, 'loss': 'hinge', 'learning_rate': 'optimal', 'eta0': 0.001, 'alpha': 0.1}
# 	[ 7]: 0.695 (+/-0.047) for {'tol': 0.0001, 'penalty': 'l2', 'max_iter': 1000, 'loss': 'hinge', 'learning_rate': 'invscaling', 'eta0': 0.01, 'alpha': 0.1}
# 	[ 8]: 0.905 (+/-0.120) for {'tol': 0.0001, 'penalty': 'elasticnet', 'max_iter': 1000, 'loss': 'modified_huber', 'learning_rate': 'constant', 'eta0': 0.001, 'alpha': 0.0001}
# 	[ 9]: 0.905 (+/-0.159) for {'tol': 0.001, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'modified_huber', 'learning_rate': 'optimal', 'eta0': 0.0001, 'alpha': 0.1}
# 	[10]: 0.733 (+/-0.177) for {'tol': 0.0001, 'penalty': 'elasticnet', 'max_iter': 3000, 'loss': 'squared_error', 'learning_rate': 'constant', 'eta0': 0.01, 'alpha': 0.01}
# 	[11]: 0.848 (+/-0.111) for {'tol': 0.0001, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'squared_hinge', 'learning_rate': 'adaptive', 'eta0': 0.0001, 'alpha': 0.1}
# 	[12]: 1.000 (+/-0.000) for {'tol': 0.001, 'penalty': 'l1', 'max_iter': 3000, 'loss': 'squared_hinge', 'learning_rate': 'optimal', 'eta0': 0.01, 'alpha': 0.1}
# 	[13]: 0.324 (+/-0.152) for {'tol': 0.001, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'squared_error', 'learning_rate': 'adaptive', 'eta0': 0.1, 'alpha': 0.001}
# 	[14]: 0.895 (+/-0.327) for {'tol': 0.001, 'penalty': 'l1', 'max_iter': 2000, 'loss': 'modified_huber', 'learning_rate': 'optimal', 'eta0': 0.1, 'alpha': 0.001}
# 	[15]: 0.914 (+/-0.071) for {'tol': 0.001, 'penalty': 'l1', 'max_iter': 1000, 'loss': 'hinge', 'learning_rate': 'adaptive', 'eta0': 0.01, 'alpha': 0.001}
# 	[16]: 0.752 (+/-0.164) for {'tol': 0.0001, 'penalty': 'l1', 'max_iter': 3000, 'loss': 'hinge', 'learning_rate': 'optimal', 'eta0': 0.0001, 'alpha': 0.0001}
# 	[17]: 0.933 (+/-0.097) for {'tol': 1e-05, 'penalty': 'l2', 'max_iter': 2000, 'loss': 'squared_hinge', 'learning_rate': 'adaptive', 'eta0': 0.1, 'alpha': 0.0001}
# 	[18]: 0.771 (+/-0.071) for {'tol': 0.0001, 'penalty': 'l1', 'max_iter': 2000, 'loss': 'hinge', 'learning_rate': 'adaptive', 'eta0': 0.001, 'alpha': 0.0001}
# 	[19]: 0.695 (+/-0.047) for {'tol': 0.001, 'penalty': 'elasticnet', 'max_iter': 2000, 'loss': 'hinge', 'learning_rate': 'invscaling', 'eta0': 0.001, 'alpha': 0.001}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.1, eta0=0.01, loss='squared_hinge', max_iter=3000,
#               penalty='l1')
#
# best: dat=iris, score=1.00000, model=SGDClassifier(alpha=0.1,eta0=0.01,learning_rate='optimal',loss='squared_hinge',max_iter=3000,penalty='l1',tol=0.001)
#
# OK(random-search)

# %% [markdown]
# ## Qd MNIST Search Quest II
#
# Finally, a search-quest competition: __who can find the best model+hyperparameters for the MNIST dataset?__
#
# You change to the MNIST data by calling `LoadAndSetupData('mnist')`, and this is a completely other ball-game that the iris _tiny-data_: it's much larger (but still far from _big-data_)!
#
# * You might opt for the exhaustive grid search, or use the faster but-less optimal random search...your choice.
#
# * You are free to pick any classifier in Scikit-learn, even algorithms we have not discussed yet---__except Neural Networks and KNeighborsClassifier!__.
#
# * Keep the score function at `f1_micro`, otherwise, we will be comparing 'æbler og pærer'.
#
# * And, you may also want to scale your input data for some models to perform better.
#
# * __REMEMBER__, DO NOT USE any Neural Network models. This also means not to use any `Keras` or `Tensorflow` models...since they outperform most other models, and there are also too many examples on the internet to cut-and-paste from!
#
# Check your result by printing the first _return_ value from `FullReport()`
# ```python
# b1, m1 = FullReport(random_tuned , X_test, y_test, time_randomsearch)
# print(b1)
# ```
# that will display a result like
# ```
# best: dat=mnist, score=0.90780, model=SGDClassifier(alpha=1.0,eta0=0.0001,learning_rate='invscaling')
# ```
# and paste your currently best model into the message box, for ITMAL group 09 like
# ```
# Grp09: best: dat=mnist, score=0.90780, model=SGDClassifier(alpha=1.0,eta0=0.0001,learning_rate='invscaling')
#
# Grp09: CTOR for best model: SGDClassifier(alpha=1.0, average=False, class_weight=None, early_stopping=False,
#               epsilon=0.1, eta0=0.0001, fit_intercept=True, l1_ratio=0.15,
#               learning_rate='invscaling', loss='hinge', max_iter=1000,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# ```
#
# on Brightspace: "L09: Regularisering, optimering og søgning" | "Qd MNIST Search Quest"
#
# > https://itundervisning.ase.au.dk/itmal_quest/index.php
#
# and, check if your score (for MNIST) is better than the currently best score. Republish if you get a better score than your own previously best. Deadline for submission of scores is the same as the deadline for the O3 journal handin.
#
# Remember to provide an ITMAL group name manually, so we can identify a winner: the 1. st price is  cake!
#
# For the journal hand-in, report your progress in scoring choosing different models, hyperparameters to search and how you might need to preprocess your data...and note, that the journal will not be accepted unless it contains information about Your results published on the Brightspace 'Search Quest II' page!

# %%
from sklearn.ensemble import HistGradientBoostingClassifier




#Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'mnist')  # 'iris', 'moon', or 'mnist'

# Use HistGradientBoostingRegressor
model = HistGradientBoostingClassifier()

# Setup search parameters
tuning_parameters = {
    'loss': ['log_loss'],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_iter': [100, 200, 300],
    'max_leaf_nodes': [31, 63, 127],
    'l2_regularization': [0.0, 0.1, 0.5],
    'max_bins': [2, 128, 255],
}


CV = 5
VERBOSE = 0

# Run randomsearch for the model
grid_tuned = RandomizedSearchCV(
    model,
    tuning_parameters,
    n_iter=1,
    random_state=42,
    cv=CV,
    scoring='f1_micro',
    verbose=VERBOSE,
    n_jobs=-1
)


start = time()
grid_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print(b0)
print('OK(grid-search)')
# Out:
# DATA: mnist..
#   org. data:  X.shape      =(70000;  784), y.shape      =(70000)
#   train data: X_train.shape=(49000;  784), y_train.shape=(49000)
#   test data:  X_test.shape =(21000;  784), y_test.shape =(21000)
# SEARCH TIME: 952.43 sec
#
# Best model set found on train set:
#
# 	best parameters={'max_leaf_nodes': 31, 'max_iter': 200, 'max_bins': 255, 'loss': 'log_loss', 'learning_rate': 0.01, 'l2_regularization': 0.1}
# 	best 'f1_micro' score=0.9519591836734694
# 	best index=0
#
# Best estimator CTOR:
# 	HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.01,
#                                max_iter=200)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.952 (+/-0.003) for {'max_leaf_nodes': 31, 'max_iter': 200, 'max_bins': 255, 'loss': 'log_loss', 'learning_rate': 0.01, 'l2_regularization': 0.1}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2077
#            1       0.98      0.98      0.98      2385
#            2       0.94      0.95      0.95      2115
#            3       0.95      0.93      0.94      2117
#            4       0.94      0.95      0.95      2004
#            5       0.95      0.93      0.94      1900
#            6       0.97      0.96      0.96      2045
#            7       0.96      0.94      0.95      2189
#            8       0.91      0.94      0.93      2042
#            9       0.92      0.93      0.92      2126
#
#     accuracy                           0.95     21000
#    macro avg       0.95      0.95      0.95     21000
# weighted avg       0.95      0.95      0.95     21000
#
#
# CTOR for best model: HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.01,
#                                max_iter=200)
#
# best: dat=mnist, score=0.95196, model=HistGradientBoostingClassifier(l2_regularization=0.1,learning_rate=0.01,loss='log_loss',max_bins=255,max_iter=200,max_leaf_nodes=31)
#
# best: dat=mnist, score=0.95196, model=HistGradientBoostingClassifier(l2_regularization=0.1,learning_rate=0.01,loss='log_loss',max_bins=255,max_iter=200,max_leaf_nodes=31)
# OK(grid-search)

# %%
# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print(b0)
print('OK(grid-search)')
# Out:
# SEARCH TIME: 21.03 sec
#
# Best model set found on train set:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Report result
# ----> 2 b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
#       3 print(b0)
#       4 print('OK(grid-search)')
#
# Cell In[3], line 74, in FullReport(model, X_test, y_test, t)
#      72 def FullReport(model, X_test, y_test, t):
#      73     print(f"SEARCH TIME: {t:0.2f} sec")
# ---> 74     beststr, bestmodel = SearchReport(model)
#      75     ClassificationReport(model, X_test, y_test)
#      76     print(f"CTOR for best model: {bestmodel}\n")
#
# Cell In[3], line 40, in SearchReport(model)
#      38 print("\nBest model set found on train set:")
#      39 print()
# ---> 40 print(f"\tbest parameters={model.best_params_}")
#      41 print(f"\tbest '{model.scoring}' score={model.best_score_}")
#      42 print(f"\tbest index={model.best_index_}")
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# REVISIONS||
# :-|:-
# 2018-03-01| CEF, initial.
# 2018-03-05| CEF, updated.
# 2018-03-06| CEF, updated and spell checked.
# 2018-03-06| CEF, major overhaul of functions.
# 2018-03-06| CEF, fixed problem with MNIST load and Keras.
# 2018-03-07| CEF, modified report functions and changed Qc+d.
# 2018-03-11| CEF, updated Qd.
# 2018-03-12| CEF, added grid and random search figs and added bullets to Qd.
# 2018-03-13| CEF, fixed SVC and gamma issue, and changed dataload to be in fetchmode (non-keras).
# 2019-10-15| CEF, updated for ITMAL E19
# 2019-10-19| CEF, minor text update.
# 2019-10-23| CEF, changed demo model i Qd) from MLPClassifier to SVC.
# 2020-03-14| CEF, updated to ITMAL F20.
# 2020-10-20| CEF, updated to ITMAL E20.
# 2020-10-27| CEF, type fixes and minor update.
# 2020-10-28| CEF, added extra journal hand-in specs for Search Quest II, Qd.
# 2020-10-30| CEF, added non-use of KNeighborsClassifier to Search Quest II, Qd.
# 2020-11-19| CEF, changed load_mode=2 (Keras) to load_mode=0 (auto) for MNIST loader.
# 2021-03-17| CEF, updated to ITMAL F21.
# 2021-10-31| CEF, updated to ITMAL E21.
# 2021-11-05| CEF, removed iid=True paramter from GridSearchCV(), not present in current version of Scikit-learn (0.24.1).
# 2022-03-31| CEF, updated to SWMAL F22.
# 2022-08-30| CEF, updating to v1 changes.
# 2022-11-04| CEF, updated link to Brightspace, Search Quest II.
# 2022-11-04| CEF, fixed error "TypeError: classification_report() takes 2 position..".
# 2022-11-11| CEF, elaborated on Search Quest II deadline.
# 2023-03-24| CEF, updated link and updated to SWMAL F23.
