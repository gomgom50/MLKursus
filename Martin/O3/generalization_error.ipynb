# %% [markdown]
# # SWMAL Exercise
#
# ## Generalization Error
#
# In this exercise, we need to explain all important overall concepts in training. Let's begin with Figure 5.3 from Deep Learning (Ian Goodfellow, et. al. [DL]), that pretty much sums it all up
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L08/Figs/dl_generalization_error.png" alt="WARNING: could not get image from server." style="height:500px">
#
#
# ### Qa) On Generalization Error
#
# Write a detailed description of figure 5.3 (above) for your hand-in.
#
# All concepts in the figure must be explained
#
# * training/generalization error,
# * underfit/overfit zone,
# * optimal capacity,
# * generalization gab,
# * and the two axes: x/capacity, y/error.

# %%
# TODO: ...in text
#assert False, "TODO: write some text.."

# %% [markdown]
# ### Qb A MSE-Epoch/Error Plot
#
# Next, we look at a SGD model for fitting polynomial, that is _polynomial regression_ similar to what Géron describes in [HOML] ("Polynomial Regression" + "Learning Curves").
#
# Review the code below for plotting the RMSE vs. the iteration number or epoch below (three cells, part I/II/III).
#
# Write a short description of the code, and comment on the important points in the generation of the (R)MSE array.
#
# The training phase output lots of lines like
#
# > `epoch= 104, mse_train=1.50, mse_val=2.37` <br>
# > `epoch= 105, mse_train=1.49, mse_val=2.35`
#
# What is an ___epoch___ and what is `mse_train` and `mse_val`?
#
# NOTE$_1$: the generalization plot figure 5.3 in [DL] (above) and the plots below have different x-axis, and are not to be compared directly!
#
# NOTE$_2$: notice that a 90 degree polynomial is used for the polynomial regression. This is just to produce a model with an extremly high capacity.

# %%
# Run code: Qb(part I)
# NOTE: modified code from [GITHOML], 04_training_linear_models.ipynb

# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

np.random.seed(42)

def GenerateData():
    m = 100
    X = 6 * np.random.rand(m, 1) - 3
    y = 2 + X + 0.5 * X**2 + np.random.randn(m, 1)
    return X, y

X, y = GenerateData()
X_train, X_val, y_train, y_val = \
    train_test_split( \
        X[:50], y[:50].ravel(), \
        test_size=0.5, \
        random_state=10)

print("X_train.shape=",X_train.shape)
print("X_val  .shape=",X_val.shape)
print("y_train.shape=",y_train.shape)
print("y_val  .shape=",y_val.shape)

poly_scaler = Pipeline([
        ("poly_features", PolynomialFeatures(degree=90, include_bias=False)),
        ("std_scaler", StandardScaler()),
    ])

X_train_poly_scaled = poly_scaler.fit_transform(X_train)
X_val_poly_scaled   = poly_scaler.transform(X_val)

X_new=np.linspace(-3, 3, 100).reshape(100, 1)
plt.plot(X, y, "b.", label="All X-y Data")
plt.xlabel("$x_1$", fontsize=18, )
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()

print('OK')
# Out:
# X_train.shape= (25, 1)
# X_val  .shape= (25, 1)
# y_train.shape= (25,)
# y_val  .shape= (25,)
# OK

# %%
# Run code: Qb(part II)

def Train(X_train, y_train, X_val, y_val, n_epochs, verbose=False):
    print("Training...n_epochs=",n_epochs)
    
    train_errors, val_errors = [], []
    
    sgd_reg = SGDRegressor(max_iter=1000,
                           penalty=None,
                           eta0=0.0005,
                           warm_start=True,
                           early_stopping=False,
                           learning_rate="constant",
                           tol=0,#-float("inf")
                           random_state=42)

    for epoch in range(n_epochs):
        
        sgd_reg.fit(X_train, y_train)
        
        y_train_predict = sgd_reg.predict(X_train)
        y_val_predict   = sgd_reg.predict(X_val)

        mse_train=mean_squared_error(y_train, y_train_predict)
        mse_val  =mean_squared_error(y_val  , y_val_predict)

        train_errors.append(mse_train)
        val_errors  .append(mse_val)
        if verbose:
            print(f"  epoch={epoch:4d}, mse_train={mse_train:4.2f}, mse_val={mse_val:4.2f}")

    return train_errors, val_errors

n_epochs = 500
train_errors, val_errors = Train(X_train_poly_scaled, y_train, X_val_poly_scaled, y_val, n_epochs, True)



print('OK')
# Out:
# Training...n_epochs= 500
#   epoch=   0, mse_train=0.57, mse_val=1.63
#   epoch=   1, mse_train=0.56, mse_val=1.69
#   epoch=   2, mse_train=0.55, mse_val=1.76
#   epoch=   3, mse_train=0.55, mse_val=1.82
#   epoch=   4, mse_train=0.54, mse_val=1.89
#   epoch=   5, mse_train=0.54, mse_val=1.95
#   epoch=   6, mse_train=0.54, mse_val=2.01
#   epoch=   7, mse_train=0.53, mse_val=2.07
#   epoch=   8, mse_train=0.53, mse_val=2.13
#   epoch=   9, mse_train=0.53, mse_val=2.18
#   epoch=  10, mse_train=0.52, mse_val=2.23
#   epoch=  11, mse_train=0.52, mse_val=2.28
#   epoch=  12, mse_train=0.52, mse_val=2.32
#   epoch=  13, mse_train=0.52, mse_val=2.36
#   epoch=  14, mse_train=0.52, mse_val=2.40
#   epoch=  15, mse_train=0.51, mse_val=2.44
#   epoch=  16, mse_train=0.51, mse_val=2.47
#   epoch=  17, mse_train=0.51, mse_val=2.50
#   epoch=  18, mse_train=0.51, mse_val=2.53
#   epoch=  19, mse_train=0.51, mse_val=2.56
#   epoch=  20, mse_train=0.51, mse_val=2.58
#   epoch=  21, mse_train=0.51, mse_val=2.60
#   epoch=  22, mse_train=0.51, mse_val=2.62
#   epoch=  23, mse_train=0.51, mse_val=2.63
#   epoch=  24, mse_train=0.51, mse_val=2.65
#   epoch=  25, mse_train=0.51, mse_val=2.66
#   epoch=  26, mse_train=0.51, mse_val=2.67
#   epoch=  27, mse_train=0.50, mse_val=2.67
#   epoch=  28, mse_train=0.50, mse_val=2.68
#   epoch=  29, mse_train=0.50, mse_val=2.68
#   epoch=  30, mse_train=0.50, mse_val=2.68
#   epoch=  31, mse_train=0.50, mse_val=2.68
#   epoch=  32, mse_train=0.50, mse_val=2.68
#   epoch=  33, mse_train=0.50, mse_val=2.68
#   epoch=  34, mse_train=0.50, mse_val=2.68
#   epoch=  35, mse_train=0.50, mse_val=2.67
#   epoch=  36, mse_train=0.50, mse_val=2.66
#   epoch=  37, mse_train=0.50, mse_val=2.66
#   epoch=  38, mse_train=0.50, mse_val=2.65
#   epoch=  39, mse_train=0.50, mse_val=2.64
#   epoch=  40, mse_train=0.50, mse_val=2.63
#   epoch=  41, mse_train=0.50, mse_val=2.61
#   epoch=  42, mse_train=0.50, mse_val=2.60
#   epoch=  43, mse_train=0.50, mse_val=2.59
#   epoch=  44, mse_train=0.50, mse_val=2.57
#   epoch=  45, mse_train=0.50, mse_val=2.56
#   epoch=  46, mse_train=0.50, mse_val=2.54
#   epoch=  47, mse_train=0.50, mse_val=2.52
#   epoch=  48, mse_train=0.50, mse_val=2.51
#   epoch=  49, mse_train=0.50, mse_val=2.49
#   epoch=  50, mse_train=0.50, mse_val=2.47
#   epoch=  51, mse_train=0.50, mse_val=2.45
#   epoch=  52, mse_train=0.50, mse_val=2.43
#   epoch=  53, mse_train=0.50, mse_val=2.41
#   epoch=  54, mse_train=0.50, mse_val=2.39
#   epoch=  55, mse_train=0.50, mse_val=2.37
#   epoch=  56, mse_train=0.50, mse_val=2.35
#   epoch=  57, mse_train=0.50, mse_val=2.33
#   epoch=  58, mse_train=0.50, mse_val=2.30
#   epoch=  59, mse_train=0.50, mse_val=2.28
#   epoch=  60, mse_train=0.50, mse_val=2.26
#   epoch=  61, mse_train=0.49, mse_val=2.24
#   epoch=  62, mse_train=0.49, mse_val=2.21
#   epoch=  63, mse_train=0.49, mse_val=2.19
#   epoch=  64, mse_train=0.49, mse_val=2.17
#   epoch=  65, mse_train=0.49, mse_val=2.14
#   epoch=  66, mse_train=0.49, mse_val=2.12
#   epoch=  67, mse_train=0.49, mse_val=2.10
#   epoch=  68, mse_train=0.49, mse_val=2.07
#   epoch=  69, mse_train=0.49, mse_val=2.05
#   epoch=  70, mse_train=0.49, mse_val=2.02
#   epoch=  71, mse_train=0.49, mse_val=2.00
#   epoch=  72, mse_train=0.49, mse_val=1.98
#   epoch=  73, mse_train=0.49, mse_val=1.95
#   epoch=  74, mse_train=0.49, mse_val=1.93
#   epoch=  75, mse_train=0.49, mse_val=1.90
#   epoch=  76, mse_train=0.49, mse_val=1.88
#   epoch=  77, mse_train=0.49, mse_val=1.85
#   epoch=  78, mse_train=0.49, mse_val=1.83
#   epoch=  79, mse_train=0.49, mse_val=1.81
#   epoch=  80, mse_train=0.49, mse_val=1.78
#   epoch=  81, mse_train=0.49, mse_val=1.76
#   epoch=  82, mse_train=0.49, mse_val=1.74
#   epoch=  83, mse_train=0.49, mse_val=1.71
#   epoch=  84, mse_train=0.49, mse_val=1.69
#   epoch=  85, mse_train=0.49, mse_val=1.66
#   epoch=  86, mse_train=0.49, mse_val=1.64
#   epoch=  87, mse_train=0.49, mse_val=1.62
#   epoch=  88, mse_train=0.49, mse_val=1.60
#   epoch=  89, mse_train=0.49, mse_val=1.57
#   epoch=  90, mse_train=0.49, mse_val=1.55
#   epoch=  91, mse_train=0.49, mse_val=1.53
#   epoch=  92, mse_train=0.49, mse_val=1.51
#   epoch=  93, mse_train=0.49, mse_val=1.48
#   epoch=  94, mse_train=0.49, mse_val=1.46
#   epoch=  95, mse_train=0.49, mse_val=1.44
#   epoch=  96, mse_train=0.49, mse_val=1.42
#   epoch=  97, mse_train=0.49, mse_val=1.40
#   epoch=  98, mse_train=0.49, mse_val=1.38
#   epoch=  99, mse_train=0.49, mse_val=1.36
#   epoch= 100, mse_train=0.49, mse_val=1.34
#   epoch= 101, mse_train=0.49, mse_val=1.32
#   epoch= 102, mse_train=0.49, mse_val=1.30
#   epoch= 103, mse_train=0.49, mse_val=1.28
#   epoch= 104, mse_train=0.49, mse_val=1.26
#   epoch= 105, mse_train=0.49, mse_val=1.24
#   epoch= 106, mse_train=0.49, mse_val=1.22
#   epoch= 107, mse_train=0.49, mse_val=1.21
#   epoch= 108, mse_train=0.49, mse_val=1.19
#   epoch= 109, mse_train=0.49, mse_val=1.17
#   epoch= 110, mse_train=0.49, mse_val=1.15
#   epoch= 111, mse_train=0.49, mse_val=1.14
#   epoch= 112, mse_train=0.49, mse_val=1.12
#   epoch= 113, mse_train=0.49, mse_val=1.11
#   epoch= 114, mse_train=0.49, mse_val=1.09
#   epoch= 115, mse_train=0.49, mse_val=1.08
#   epoch= 116, mse_train=0.49, mse_val=1.06
#   epoch= 117, mse_train=0.49, mse_val=1.05
#   epoch= 118, mse_train=0.49, mse_val=1.03
#   epoch= 119, mse_train=0.49, mse_val=1.02
#   epoch= 120, mse_train=0.49, mse_val=1.01
#   epoch= 121, mse_train=0.49, mse_val=0.99
#   epoch= 122, mse_train=0.49, mse_val=0.98
#   epoch= 123, mse_train=0.49, mse_val=0.97
#   epoch= 124, mse_train=0.49, mse_val=0.96
#   epoch= 125, mse_train=0.49, mse_val=0.94
#   epoch= 126, mse_train=0.49, mse_val=0.93
#   epoch= 127, mse_train=0.49, mse_val=0.92
#   epoch= 128, mse_train=0.49, mse_val=0.91
#   epoch= 129, mse_train=0.49, mse_val=0.90
#   epoch= 130, mse_train=0.49, mse_val=0.89
#   epoch= 131, mse_train=0.49, mse_val=0.89
#   epoch= 132, mse_train=0.49, mse_val=0.88
#   epoch= 133, mse_train=0.49, mse_val=0.87
#   epoch= 134, mse_train=0.49, mse_val=0.86
#   epoch= 135, mse_train=0.49, mse_val=0.86
#   epoch= 136, mse_train=0.49, mse_val=0.85
#   epoch= 137, mse_train=0.49, mse_val=0.84
#   epoch= 138, mse_train=0.49, mse_val=0.84
#   epoch= 139, mse_train=0.49, mse_val=0.83
#   epoch= 140, mse_train=0.49, mse_val=0.83
#   epoch= 141, mse_train=0.49, mse_val=0.82
#   epoch= 142, mse_train=0.49, mse_val=0.82
#   epoch= 143, mse_train=0.49, mse_val=0.82
#   epoch= 144, mse_train=0.49, mse_val=0.81
#   epoch= 145, mse_train=0.49, mse_val=0.81
#   epoch= 146, mse_train=0.49, mse_val=0.81
#   epoch= 147, mse_train=0.49, mse_val=0.81
#   epoch= 148, mse_train=0.49, mse_val=0.80
#   epoch= 149, mse_train=0.49, mse_val=0.80
#   epoch= 150, mse_train=0.49, mse_val=0.80
#   epoch= 151, mse_train=0.49, mse_val=0.80
#   epoch= 152, mse_train=0.49, mse_val=0.81
#   epoch= 153, mse_train=0.49, mse_val=0.81
#   epoch= 154, mse_train=0.49, mse_val=0.81
#   epoch= 155, mse_train=0.49, mse_val=0.81
#   epoch= 156, mse_train=0.49, mse_val=0.81
#   epoch= 157, mse_train=0.49, mse_val=0.82
#   epoch= 158, mse_train=0.49, mse_val=0.82
#   epoch= 159, mse_train=0.49, mse_val=0.82
#   epoch= 160, mse_train=0.49, mse_val=0.83
#   epoch= 161, mse_train=0.49, mse_val=0.83
#   epoch= 162, mse_train=0.49, mse_val=0.84
#   epoch= 163, mse_train=0.48, mse_val=0.84
#   epoch= 164, mse_train=0.48, mse_val=0.85
#   epoch= 165, mse_train=0.48, mse_val=0.86
#   epoch= 166, mse_train=0.48, mse_val=0.87
#   epoch= 167, mse_train=0.48, mse_val=0.87
#   epoch= 168, mse_train=0.48, mse_val=0.88
#   epoch= 169, mse_train=0.48, mse_val=0.89
#   epoch= 170, mse_train=0.48, mse_val=0.90
#   epoch= 171, mse_train=0.48, mse_val=0.91
#   epoch= 172, mse_train=0.48, mse_val=0.92
#   epoch= 173, mse_train=0.48, mse_val=0.93
#   epoch= 174, mse_train=0.48, mse_val=0.94
#   epoch= 175, mse_train=0.48, mse_val=0.95
#   epoch= 176, mse_train=0.48, mse_val=0.97
#   epoch= 177, mse_train=0.48, mse_val=0.98
#   epoch= 178, mse_train=0.48, mse_val=0.99
#   epoch= 179, mse_train=0.48, mse_val=1.01
#   epoch= 180, mse_train=0.48, mse_val=1.02
#   epoch= 181, mse_train=0.48, mse_val=1.04
#   epoch= 182, mse_train=0.48, mse_val=1.05
#   epoch= 183, mse_train=0.48, mse_val=1.07
#   epoch= 184, mse_train=0.48, mse_val=1.08
#   epoch= 185, mse_train=0.48, mse_val=1.10
#   epoch= 186, mse_train=0.48, mse_val=1.12
#   epoch= 187, mse_train=0.48, mse_val=1.13
#   epoch= 188, mse_train=0.48, mse_val=1.15
#   epoch= 189, mse_train=0.48, mse_val=1.17
#   epoch= 190, mse_train=0.48, mse_val=1.19
#   epoch= 191, mse_train=0.48, mse_val=1.21
#   epoch= 192, mse_train=0.48, mse_val=1.23
#   epoch= 193, mse_train=0.48, mse_val=1.25
#   epoch= 194, mse_train=0.48, mse_val=1.27
#   epoch= 195, mse_train=0.48, mse_val=1.29
#   epoch= 196, mse_train=0.48, mse_val=1.31
#   epoch= 197, mse_train=0.48, mse_val=1.34
#   epoch= 198, mse_train=0.48, mse_val=1.36
#   epoch= 199, mse_train=0.48, mse_val=1.38
#   epoch= 200, mse_train=0.48, mse_val=1.41
#   epoch= 201, mse_train=0.48, mse_val=1.43
#   epoch= 202, mse_train=0.48, mse_val=1.46
#   epoch= 203, mse_train=0.48, mse_val=1.48
#   epoch= 204, mse_train=0.48, mse_val=1.51
#   epoch= 205, mse_train=0.48, mse_val=1.53
#   epoch= 206, mse_train=0.48, mse_val=1.56
#   epoch= 207, mse_train=0.48, mse_val=1.59
#   epoch= 208, mse_train=0.48, mse_val=1.62
#   epoch= 209, mse_train=0.48, mse_val=1.64
#   epoch= 210, mse_train=0.48, mse_val=1.67
#   epoch= 211, mse_train=0.48, mse_val=1.70
#   epoch= 212, mse_train=0.48, mse_val=1.73
#   epoch= 213, mse_train=0.48, mse_val=1.76
#   epoch= 214, mse_train=0.48, mse_val=1.79
#   epoch= 215, mse_train=0.48, mse_val=1.82
#   epoch= 216, mse_train=0.48, mse_val=1.85
#   epoch= 217, mse_train=0.48, mse_val=1.89
#   epoch= 218, mse_train=0.48, mse_val=1.92
#   epoch= 219, mse_train=0.48, mse_val=1.95
#   epoch= 220, mse_train=0.48, mse_val=1.98
#   epoch= 221, mse_train=0.48, mse_val=2.02
#   epoch= 222, mse_train=0.48, mse_val=2.05
#   epoch= 223, mse_train=0.48, mse_val=2.09
#   epoch= 224, mse_train=0.48, mse_val=2.12
#   epoch= 225, mse_train=0.48, mse_val=2.16
#   epoch= 226, mse_train=0.48, mse_val=2.19
#   epoch= 227, mse_train=0.48, mse_val=2.23
#   epoch= 228, mse_train=0.48, mse_val=2.27
#   epoch= 229, mse_train=0.48, mse_val=2.31
#   epoch= 230, mse_train=0.48, mse_val=2.34
#   epoch= 231, mse_train=0.48, mse_val=2.38
#   epoch= 232, mse_train=0.48, mse_val=2.42
#   epoch= 233, mse_train=0.48, mse_val=2.46
#   epoch= 234, mse_train=0.48, mse_val=2.50
#   epoch= 235, mse_train=0.48, mse_val=2.54
#   epoch= 236, mse_train=0.48, mse_val=2.58
#   epoch= 237, mse_train=0.48, mse_val=2.62
#   epoch= 238, mse_train=0.48, mse_val=2.66
#   epoch= 239, mse_train=0.48, mse_val=2.70
#   epoch= 240, mse_train=0.48, mse_val=2.75
#   epoch= 241, mse_train=0.48, mse_val=2.79
#   epoch= 242, mse_train=0.48, mse_val=2.83
#   epoch= 243, mse_train=0.48, mse_val=2.88
#   epoch= 244, mse_train=0.48, mse_val=2.92
#   epoch= 245, mse_train=0.48, mse_val=2.96
#   epoch= 246, mse_train=0.48, mse_val=3.01
#   epoch= 247, mse_train=0.48, mse_val=3.05
#   epoch= 248, mse_train=0.48, mse_val=3.10
#   epoch= 249, mse_train=0.48, mse_val=3.15
#   epoch= 250, mse_train=0.48, mse_val=3.19
#   epoch= 251, mse_train=0.48, mse_val=3.24
#   epoch= 252, mse_train=0.48, mse_val=3.29
#   epoch= 253, mse_train=0.48, mse_val=3.34
#   epoch= 254, mse_train=0.48, mse_val=3.38
#   epoch= 255, mse_train=0.48, mse_val=3.43
#   epoch= 256, mse_train=0.48, mse_val=3.48
#   epoch= 257, mse_train=0.48, mse_val=3.53
#   epoch= 258, mse_train=0.48, mse_val=3.58
#   epoch= 259, mse_train=0.48, mse_val=3.63
#   epoch= 260, mse_train=0.48, mse_val=3.68
#   epoch= 261, mse_train=0.48, mse_val=3.73
#   epoch= 262, mse_train=0.48, mse_val=3.79
#   epoch= 263, mse_train=0.48, mse_val=3.84
#   epoch= 264, mse_train=0.48, mse_val=3.89
#   epoch= 265, mse_train=0.48, mse_val=3.94
#   epoch= 266, mse_train=0.48, mse_val=4.00
#   epoch= 267, mse_train=0.48, mse_val=4.05
#   epoch= 268, mse_train=0.48, mse_val=4.11
#   epoch= 269, mse_train=0.48, mse_val=4.16
#   epoch= 270, mse_train=0.48, mse_val=4.22
#   epoch= 271, mse_train=0.48, mse_val=4.27
#   epoch= 272, mse_train=0.48, mse_val=4.33
#   epoch= 273, mse_train=0.48, mse_val=4.38
#   epoch= 274, mse_train=0.48, mse_val=4.44
#   epoch= 275, mse_train=0.48, mse_val=4.50
#   epoch= 276, mse_train=0.48, mse_val=4.55
#   epoch= 277, mse_train=0.48, mse_val=4.61
#   epoch= 278, mse_train=0.48, mse_val=4.67
#   epoch= 279, mse_train=0.48, mse_val=4.73
#   epoch= 280, mse_train=0.48, mse_val=4.79
#   epoch= 281, mse_train=0.48, mse_val=4.85
#   epoch= 282, mse_train=0.48, mse_val=4.91
#   epoch= 283, mse_train=0.48, mse_val=4.97
#   epoch= 284, mse_train=0.48, mse_val=5.03
#   epoch= 285, mse_train=0.48, mse_val=5.09
#   epoch= 286, mse_train=0.48, mse_val=5.15
#   epoch= 287, mse_train=0.48, mse_val=5.21
#   epoch= 288, mse_train=0.48, mse_val=5.27
#   epoch= 289, mse_train=0.48, mse_val=5.34
#   epoch= 290, mse_train=0.48, mse_val=5.40
#   epoch= 291, mse_train=0.48, mse_val=5.46
#   epoch= 292, mse_train=0.48, mse_val=5.53
#   epoch= 293, mse_train=0.48, mse_val=5.59
#   epoch= 294, mse_train=0.48, mse_val=5.65
#   epoch= 295, mse_train=0.48, mse_val=5.72
#   epoch= 296, mse_train=0.48, mse_val=5.78
#   epoch= 297, mse_train=0.48, mse_val=5.85
#   epoch= 298, mse_train=0.48, mse_val=5.92
#   epoch= 299, mse_train=0.48, mse_val=5.98
#   epoch= 300, mse_train=0.48, mse_val=6.05
#   epoch= 301, mse_train=0.48, mse_val=6.12
#   epoch= 302, mse_train=0.48, mse_val=6.18
#   epoch= 303, mse_train=0.48, mse_val=6.25
#   epoch= 304, mse_train=0.48, mse_val=6.32
#   epoch= 305, mse_train=0.48, mse_val=6.39
#   epoch= 306, mse_train=0.48, mse_val=6.46
#   epoch= 307, mse_train=0.48, mse_val=6.53
#   epoch= 308, mse_train=0.48, mse_val=6.60
#   epoch= 309, mse_train=0.48, mse_val=6.67
#   epoch= 310, mse_train=0.48, mse_val=6.74
#   epoch= 311, mse_train=0.48, mse_val=6.81
#   epoch= 312, mse_train=0.48, mse_val=6.88
#   epoch= 313, mse_train=0.48, mse_val=6.95
#   epoch= 314, mse_train=0.48, mse_val=7.02
#   epoch= 315, mse_train=0.48, mse_val=7.09
#   epoch= 316, mse_train=0.48, mse_val=7.17
#   epoch= 317, mse_train=0.48, mse_val=7.24
#   epoch= 318, mse_train=0.48, mse_val=7.31
#   epoch= 319, mse_train=0.48, mse_val=7.39
#   epoch= 320, mse_train=0.48, mse_val=7.46
#   epoch= 321, mse_train=0.48, mse_val=7.53
#   epoch= 322, mse_train=0.48, mse_val=7.61
#   epoch= 323, mse_train=0.48, mse_val=7.68
#   epoch= 324, mse_train=0.48, mse_val=7.76
#   epoch= 325, mse_train=0.48, mse_val=7.83
#   epoch= 326, mse_train=0.48, mse_val=7.91
#   epoch= 327, mse_train=0.48, mse_val=7.99
#   epoch= 328, mse_train=0.48, mse_val=8.06
#   epoch= 329, mse_train=0.48, mse_val=8.14
#   epoch= 330, mse_train=0.48, mse_val=8.22
#   epoch= 331, mse_train=0.48, mse_val=8.29
#   epoch= 332, mse_train=0.48, mse_val=8.37
#   epoch= 333, mse_train=0.48, mse_val=8.45
#   epoch= 334, mse_train=0.48, mse_val=8.53
#   epoch= 335, mse_train=0.48, mse_val=8.61
#   epoch= 336, mse_train=0.48, mse_val=8.69
#   epoch= 337, mse_train=0.48, mse_val=8.77
#   epoch= 338, mse_train=0.48, mse_val=8.85
#   epoch= 339, mse_train=0.48, mse_val=8.93
#   epoch= 340, mse_train=0.48, mse_val=9.01
#   epoch= 341, mse_train=0.48, mse_val=9.09
#   epoch= 342, mse_train=0.48, mse_val=9.17
#   epoch= 343, mse_train=0.48, mse_val=9.25
#   epoch= 344, mse_train=0.48, mse_val=9.34
#   epoch= 345, mse_train=0.48, mse_val=9.42
#   epoch= 346, mse_train=0.48, mse_val=9.50
#   epoch= 347, mse_train=0.48, mse_val=9.58
#   epoch= 348, mse_train=0.48, mse_val=9.67
#   epoch= 349, mse_train=0.48, mse_val=9.75
#   epoch= 350, mse_train=0.48, mse_val=9.83
#   epoch= 351, mse_train=0.48, mse_val=9.92
#   epoch= 352, mse_train=0.48, mse_val=10.00
#   epoch= 353, mse_train=0.48, mse_val=10.09
#   epoch= 354, mse_train=0.48, mse_val=10.17
#   epoch= 355, mse_train=0.48, mse_val=10.26
#   epoch= 356, mse_train=0.48, mse_val=10.34
#   epoch= 357, mse_train=0.48, mse_val=10.43
#   epoch= 358, mse_train=0.48, mse_val=10.52
#   epoch= 359, mse_train=0.48, mse_val=10.60
#   epoch= 360, mse_train=0.48, mse_val=10.69
#   epoch= 361, mse_train=0.48, mse_val=10.78
#   epoch= 362, mse_train=0.48, mse_val=10.87
#   epoch= 363, mse_train=0.48, mse_val=10.95
#   epoch= 364, mse_train=0.48, mse_val=11.04
#   epoch= 365, mse_train=0.48, mse_val=11.13
#   epoch= 366, mse_train=0.48, mse_val=11.22
#   epoch= 367, mse_train=0.48, mse_val=11.31
#   epoch= 368, mse_train=0.48, mse_val=11.40
#   epoch= 369, mse_train=0.48, mse_val=11.49
#   epoch= 370, mse_train=0.48, mse_val=11.58
#   epoch= 371, mse_train=0.48, mse_val=11.67
#   epoch= 372, mse_train=0.48, mse_val=11.76
#   epoch= 373, mse_train=0.48, mse_val=11.85
#   epoch= 374, mse_train=0.48, mse_val=11.94
#   epoch= 375, mse_train=0.48, mse_val=12.03
#   epoch= 376, mse_train=0.48, mse_val=12.13
#   epoch= 377, mse_train=0.48, mse_val=12.22
#   epoch= 378, mse_train=0.48, mse_val=12.31
#   epoch= 379, mse_train=0.48, mse_val=12.40
#   epoch= 380, mse_train=0.48, mse_val=12.50
#   epoch= 381, mse_train=0.47, mse_val=12.59
#   epoch= 382, mse_train=0.47, mse_val=12.69
#   epoch= 383, mse_train=0.47, mse_val=12.78
#   epoch= 384, mse_train=0.47, mse_val=12.87
#   epoch= 385, mse_train=0.47, mse_val=12.97
#   epoch= 386, mse_train=0.47, mse_val=13.06
#   epoch= 387, mse_train=0.47, mse_val=13.16
#   epoch= 388, mse_train=0.47, mse_val=13.25
#   epoch= 389, mse_train=0.47, mse_val=13.35
#   epoch= 390, mse_train=0.47, mse_val=13.45
#   epoch= 391, mse_train=0.47, mse_val=13.54
#   epoch= 392, mse_train=0.47, mse_val=13.64
#   epoch= 393, mse_train=0.47, mse_val=13.74
#   epoch= 394, mse_train=0.47, mse_val=13.83
#   epoch= 395, mse_train=0.47, mse_val=13.93
#   epoch= 396, mse_train=0.47, mse_val=14.03
#   epoch= 397, mse_train=0.47, mse_val=14.13
#   epoch= 398, mse_train=0.47, mse_val=14.23
#   epoch= 399, mse_train=0.47, mse_val=14.32
#   epoch= 400, mse_train=0.47, mse_val=14.42
#   epoch= 401, mse_train=0.47, mse_val=14.52
#   epoch= 402, mse_train=0.47, mse_val=14.62
#   epoch= 403, mse_train=0.47, mse_val=14.72
#   epoch= 404, mse_train=0.47, mse_val=14.82
#   epoch= 405, mse_train=0.47, mse_val=14.92
#   epoch= 406, mse_train=0.47, mse_val=15.02
#   epoch= 407, mse_train=0.47, mse_val=15.12
#   epoch= 408, mse_train=0.47, mse_val=15.22
#   epoch= 409, mse_train=0.47, mse_val=15.33
#   epoch= 410, mse_train=0.47, mse_val=15.43
#   epoch= 411, mse_train=0.47, mse_val=15.53
#   epoch= 412, mse_train=0.47, mse_val=15.63
#   epoch= 413, mse_train=0.47, mse_val=15.73
#   epoch= 414, mse_train=0.47, mse_val=15.84
#   epoch= 415, mse_train=0.47, mse_val=15.94
#   epoch= 416, mse_train=0.47, mse_val=16.04
#   epoch= 417, mse_train=0.47, mse_val=16.15
#   epoch= 418, mse_train=0.47, mse_val=16.25
#   epoch= 419, mse_train=0.47, mse_val=16.36
#   epoch= 420, mse_train=0.47, mse_val=16.46
#   epoch= 421, mse_train=0.47, mse_val=16.56
#   epoch= 422, mse_train=0.47, mse_val=16.67
#   epoch= 423, mse_train=0.47, mse_val=16.77
#   epoch= 424, mse_train=0.47, mse_val=16.88
#   epoch= 425, mse_train=0.47, mse_val=16.99
#   epoch= 426, mse_train=0.47, mse_val=17.09
#   epoch= 427, mse_train=0.47, mse_val=17.20
#   epoch= 428, mse_train=0.47, mse_val=17.31
#   epoch= 429, mse_train=0.47, mse_val=17.41
#   epoch= 430, mse_train=0.47, mse_val=17.52
#   epoch= 431, mse_train=0.47, mse_val=17.63
#   epoch= 432, mse_train=0.47, mse_val=17.73
#   epoch= 433, mse_train=0.47, mse_val=17.84
#   epoch= 434, mse_train=0.47, mse_val=17.95
#   epoch= 435, mse_train=0.47, mse_val=18.06
#   epoch= 436, mse_train=0.47, mse_val=18.17
#   epoch= 437, mse_train=0.47, mse_val=18.28
#   epoch= 438, mse_train=0.47, mse_val=18.39
#   epoch= 439, mse_train=0.47, mse_val=18.49
#   epoch= 440, mse_train=0.47, mse_val=18.60
#   epoch= 441, mse_train=0.47, mse_val=18.71
#   epoch= 442, mse_train=0.47, mse_val=18.82
#   epoch= 443, mse_train=0.47, mse_val=18.93
#   epoch= 444, mse_train=0.47, mse_val=19.05
#   epoch= 445, mse_train=0.47, mse_val=19.16
#   epoch= 446, mse_train=0.47, mse_val=19.27
#   epoch= 447, mse_train=0.47, mse_val=19.38
#   epoch= 448, mse_train=0.47, mse_val=19.49
#   epoch= 449, mse_train=0.47, mse_val=19.60
#   epoch= 450, mse_train=0.47, mse_val=19.71
#   epoch= 451, mse_train=0.47, mse_val=19.83
#   epoch= 452, mse_train=0.47, mse_val=19.94
#   epoch= 453, mse_train=0.47, mse_val=20.05
#   epoch= 454, mse_train=0.47, mse_val=20.17
#   epoch= 455, mse_train=0.47, mse_val=20.28
#   epoch= 456, mse_train=0.47, mse_val=20.39
#   epoch= 457, mse_train=0.47, mse_val=20.51
#   epoch= 458, mse_train=0.47, mse_val=20.62
#   epoch= 459, mse_train=0.47, mse_val=20.74
#   epoch= 460, mse_train=0.47, mse_val=20.85
#   epoch= 461, mse_train=0.47, mse_val=20.97
#   epoch= 462, mse_train=0.47, mse_val=21.08
#   epoch= 463, mse_train=0.47, mse_val=21.20
#   epoch= 464, mse_train=0.47, mse_val=21.31
#   epoch= 465, mse_train=0.47, mse_val=21.43
#   epoch= 466, mse_train=0.47, mse_val=21.54
#   epoch= 467, mse_train=0.47, mse_val=21.66
#   epoch= 468, mse_train=0.47, mse_val=21.78
#   epoch= 469, mse_train=0.47, mse_val=21.89
#   epoch= 470, mse_train=0.47, mse_val=22.01
#   epoch= 471, mse_train=0.47, mse_val=22.13
#   epoch= 472, mse_train=0.47, mse_val=22.25
#   epoch= 473, mse_train=0.47, mse_val=22.36
#   epoch= 474, mse_train=0.47, mse_val=22.48
#   epoch= 475, mse_train=0.47, mse_val=22.60
#   epoch= 476, mse_train=0.47, mse_val=22.72
#   epoch= 477, mse_train=0.47, mse_val=22.84
#   epoch= 478, mse_train=0.47, mse_val=22.96
#   epoch= 479, mse_train=0.47, mse_val=23.07
#   epoch= 480, mse_train=0.47, mse_val=23.19
#   epoch= 481, mse_train=0.47, mse_val=23.31
#   epoch= 482, mse_train=0.47, mse_val=23.43
#   epoch= 483, mse_train=0.47, mse_val=23.55
#   epoch= 484, mse_train=0.47, mse_val=23.67
#   epoch= 485, mse_train=0.47, mse_val=23.79
#   epoch= 486, mse_train=0.47, mse_val=23.92
#   epoch= 487, mse_train=0.47, mse_val=24.04
#   epoch= 488, mse_train=0.47, mse_val=24.16
#   epoch= 489, mse_train=0.47, mse_val=24.28
#   epoch= 490, mse_train=0.47, mse_val=24.40
#   epoch= 491, mse_train=0.47, mse_val=24.52
#   epoch= 492, mse_train=0.47, mse_val=24.65
#   epoch= 493, mse_train=0.47, mse_val=24.77
#   epoch= 494, mse_train=0.47, mse_val=24.89
#   epoch= 495, mse_train=0.47, mse_val=25.01
#   epoch= 496, mse_train=0.47, mse_val=25.14
#   epoch= 497, mse_train=0.47, mse_val=25.26
#   epoch= 498, mse_train=0.47, mse_val=25.38
#   epoch= 499, mse_train=0.47, mse_val=25.51
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 40
#      38 # Get a layer's filters
#      39 layer_name = "conv2d"  # Replace with the desired layer name
# ---> 40 filters, biases = model.get_layer(layer_name).get_weights()
#      42 # Visualize filters as heatmaps
#      43 fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(15, 8))
#
# NameError: name 'model' is not defined

# %%
# Run code: Qb(part III)

best_epoch = np.argmin(val_errors)
best_val_rmse = np.sqrt(val_errors[best_epoch])

plt.figure(figsize=(10,5))
plt.annotate('Best model',
             xy=(best_epoch, best_val_rmse),
             xytext=(best_epoch, best_val_rmse + 1),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=16,
            )

best_val_rmse -= 0.03  # just to make the graph look better
plt.plot([0, n_epochs], [best_val_rmse, best_val_rmse], "k:", linewidth=2)
plt.plot(np.sqrt(train_errors), "b--", linewidth=2, label="Training set")
plt.plot(np.sqrt(val_errors), "g-", linewidth=3, label="Validation set")
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("RMSE", fontsize=14)
plt.show()

print('OK')
# Out:
# OK

# %%
# TODO: code review..
assert False, "TODO: code review in text form"

# %% [markdown]
# ### Qc)  Early Stopping
#
# How would you implement ___early stopping___, in the code above?
#
# Write an explanation of the early stopping concept...that is, just write some pseudo code that 'implements' the early stopping.
#
# OPTIONAL: also implement your early stopping pseudo code in Python, and get it to work with the code above (and not just flipping the hyperparameter to `early_stopping=True` on the `SGDRegressor`).

# %%
# TODO: early stopping..
assert False, "TODO: explain early stopping"

# %% [markdown]
# ### Qd) Explain the Polynomial RMSE-Capacity plot
#
# Now we revisit the concepts from `capacity_under_overfitting.ipynb` notebook and the polynomial fitting with a given capacity (polynomial degree).
#
# Peek into the cell below (code similar to what we saw in `capacity_under_overfitting.ipynb`), and explain the generated RMSE-Capacity plot. Why does the _training error_ keep dropping, while the _CV-error_ drops until around capacity 3, and then begin to rise again?
#
# What does the x-axis _Capacity_ and y-axis _RMSE_ represent?
#
# Try increasing the model capacity. What happens when you do plots for `degrees` larger than around 10? Relate this with what you found via Qa+b in `capacity_under_overfitting.ipynb`.

# %%
# Run and review this code
# NOTE: modified code from [GITHOML], 04_training_linear_models.ipynb

# %matplotlib inline

from math import sqrt
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

def true_fun(X):
    return np.cos(1.5 * np.pi * X)

def GenerateData():
    n_samples = 30
    #degrees = [1, 4, 15]
    degrees = range(1,8)

    X = np.sort(np.random.rand(n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    return X, y, degrees

np.random.seed(0)
X, y, degrees  = GenerateData()

print("Iterating...degrees=",degrees)
capacities, rmses_training, rmses_validation= [], [], []
for i in range(len(degrees)):
    d=degrees[i]
    
    polynomial_features = PolynomialFeatures(degree=d, include_bias=False)
    
    linear_regression = LinearRegression()
    pipeline = Pipeline([
            ("polynomial_features", polynomial_features),
            ("linear_regression", linear_regression)
        ])
    
    Z = X[:, np.newaxis]
    pipeline.fit(Z, y)
    
    p = pipeline.predict(Z)
    train_rms = mean_squared_error(y,p)

    # Evaluate the models using crossvalidation
    scores = cross_val_score(pipeline, Z, y, scoring="neg_mean_squared_error", cv=10)
    score_mean = -scores.mean()
    
    rmse_training=sqrt(train_rms)
    rmse_validation=sqrt(score_mean)
    
    print(f"  degree={d:4d}, rmse_training={rmse_training:4.2f}, rmse_cv={rmse_validation:4.2f}")
    
    capacities      .append(d)
    rmses_training  .append(rmse_training)
    rmses_validation.append(rmse_validation)
    
plt.figure(figsize=(7,4))
plt.plot(capacities, rmses_training,  "b--", linewidth=2, label="training RMSE")
plt.plot(capacities, rmses_validation,"g-",  linewidth=2, label="validation RMSE")
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Capacity", fontsize=14)
plt.ylabel("RMSE", fontsize=14)
plt.show()

print('OK')

# %%
# TODO: investigate..
assert False, "TODO: ...answer in text form"

# %% [markdown]
# REVISIONS||
# :-|:-
# 2018-12-19| CEF, initial.
# 2018-02-14| CEF, major update and put in sync with under/overfitting exe.
# 2018-02-20| CEF, fixed revision table malformatting.
# 2018-02-25| CEF, minor text updates, and made Qc optional.
# 2018-02-25| CEF, updated code, made more functions.
# 2018-03-11| CEF, corrected RSME to RMSE.
# 2019-10-08| CEF, updated to ITMAL E19.
# 2020-03-14| CEF, updated to ITMAL F20.
# 2020-10-15| CEF, updated to ITMAL E20.
# 2020-11-17| CEF, added comment on 90 degree polynomial, made early stopping a pseudo code exe.
# 2021-03-22| CEF, changed crossref from "capacity_under_overfitting.ipynb Qc" to Qa+b in QdExplain the Polynomial RMSE-Capacity Plot.
# 2021-03-23| CEF, changed 'cv RMSE' legend to 'validation RMSE'.
# 2021-10-31| CEF, updated to ITMAL E21.
# 2022-03-25| CEF, updated to SWMAL F22.
# 2023-03-16| CEF, minor update to SWMAL F23.
